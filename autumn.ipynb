# %%
import numpy as np
import pandas as pd
from PyEMD import CEEMDAN
from vmdpy import VMD
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Dropout
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial Unicode MS', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# --------------------------- 1. 数据加载与预处理 ---------------------------
def load_data(filepath):
    df = pd.read_excel(filepath, sheet_name='datas')
    df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', dayfirst=True)
    df.set_index('date', inplace=True)
    full_date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    return df.reindex(full_date_range).ffill()

df = load_data('C:/Users/18320/Desktop/carbon-Yunnan.xlsx')
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.values)

# --------------------------- 2. 固定参数设置 ---------------------------
# CEEMDAN参数
CEEMDAN_EPSILON = 0.01
CEEMDAN_ETA = 0.05

# VMD参数（用于高频模态二次分解）
VMD_ALPHA = 1200
VMD_K = 3

# BiLSTM参数
LSTM_UNITS = 128
GRU_UNITS = 128
DROPOUT_RATE = 0.3
LEARNING_RATE = 0.001
N_STEPS = 24
EPOCHS = 100
BATCH_SIZE = 32

# 聚类参数
N_CLUSTERS = 3

# --------------------------- 3. 分解函数 ---------------------------
def ceemdan_decomposition(signal, epsilon, eta):
    """CEEMDAN分解"""
    ceemdan = CEEMDAN(epsilon=epsilon, 
                     eta=eta,
                     noise_strength=0.05,
                     ensemble_size=50)
    imfs = ceemdan.ceemdan(signal.flatten())
    return np.array(imfs).T

def vmd_decomposition(signal, alpha, K):
    """VMD分解"""
    imfs, _, _ = VMD(signal.flatten(), alpha=alpha, K=K, tau=0, DC=0, init=1, tol=1e-6)
    return imfs

# --------------------------- 4. IMF聚类函数 ---------------------------
def cluster_imfs(imfs, n_clusters=3):
    """基于频率特性对IMF进行聚类"""
    n_imfs = imfs.shape[1]
    features = []
    
    for i in range(n_imfs):
        imf = imfs[:, i]
        # 计算过零率（高频特征）
        zero_crossings = np.sum(np.diff(np.sign(imf)) != 0) / len(imf)
        
        # 计算能量（幅值特征）
        energy = np.sum(imf**2)
        
        # 计算自相关第一个零点（周期性特征）
        autocorr = np.correlate(imf, imf, mode='full')
        autocorr = autocorr[len(autocorr)//2:]
        first_zero = np.argmax(autocorr < 0.1 * autocorr[0]) if np.any(autocorr < 0.1 * autocorr[0]) else len(autocorr)-1
        
        features.append([zero_crossings, energy, first_zero])
    
    features = np.array(features)
    
    # 标准化特征
    feature_scaler = MinMaxScaler()
    normalized_features = feature_scaler.fit_transform(features)
    
    # K-means聚类
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(normalized_features)
    
    return labels, features, kmeans

# --------------------------- 5. IMF合并函数（新增）---------------------------
def merge_imfs_by_cluster(imfs, labels):
    """将同一聚类内的IMF合并为一个分量"""
    n_clusters = np.max(labels) + 1
    merged_components = []
    
    for cluster_id in range(n_clusters):
        # 找到属于当前聚类的所有IMF索引
        cluster_indices = np.where(labels == cluster_id)[0]
        
        if len(cluster_indices) > 0:
            # 将同一聚类内的IMF相加合并
            merged_component = np.sum(imfs[:, cluster_indices], axis=1)
            merged_components.append(merged_component)
    
    return np.array(merged_components).T

# --------------------------- 6. 高频模态VMD二次分解 ---------------------------
def refine_high_frequency_components(merged_components, labels, original_imfs, vmd_alpha, vmd_k):
    """对高频聚类分量进行VMD二次分解"""
    # 找到高频聚类（过零率最高的聚类）
    cluster_features = []
    for i in range(np.max(labels)+1):
        cluster_indices = np.where(labels == i)[0]
        if len(cluster_indices) > 0:
            # 使用原始IMF计算过零率
            avg_zero_crossing = np.mean([np.sum(np.diff(np.sign(original_imfs[:, idx])) != 0) / len(original_imfs) for idx in cluster_indices])
            cluster_features.append(avg_zero_crossing)
        else:
            cluster_features.append(0)
    
    high_freq_cluster = np.argmax(cluster_features)
    
    # 对高频聚类分量进行VMD二次分解
    refined_components = []
    for i in range(merged_components.shape[1]):
        if i == high_freq_cluster:
            # 对高频分量进行VMD分解
            vmd_imfs = vmd_decomposition(merged_components[:, i], vmd_alpha, vmd_k)
            refined_components.extend(vmd_imfs)
        else:
            # 非高频分量保持不变
            refined_components.append(merged_components[:, i])
    
    return np.array(refined_components).T, high_freq_cluster

# --------------------------- 7. 评估函数 ---------------------------
def evaluate(y_true, y_pred):
    """评估函数，计算多个指标"""
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_true - y_pred) / np.maximum(np.abs(y_true), 1e-10))) * 100
    r2 = r2_score(y_true, y_pred)
    
    return {
        'MSE': mse,
        'MAE': mae,
        'RMSE': rmse,
        'MAPE': mape,
        'R2': r2
    }

# --------------------------- 8. 模型定义函数 ---------------------------
def create_bilstm_model(input_shape, units, dropout_rate, learning_rate):
    """创建BiLSTM模型"""
    model = Sequential([
        Bidirectional(LSTM(units, return_sequences=False), 
                     input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                 loss='mse',
                 metrics=['mae'])
    return model

def create_gru_model(input_shape, units, dropout_rate, learning_rate):
    """创建GRU模型"""
    model = Sequential([
        GRU(units, return_sequences=False, input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                 loss='mse',
                 metrics=['mae'])
    return model

# --------------------------- 9. 模型选择函数 ---------------------------
def select_best_model(y_true, y_pred_bilstm, y_pred_gru, metric='RMSE'):
    """根据评估指标选择最佳模型"""
    metrics_bilstm = evaluate(y_true, y_pred_bilstm)
    metrics_gru = evaluate(y_true, y_pred_gru)
    
    if metric == 'RMSE':
        if metrics_bilstm['RMSE'] <= metrics_gru['RMSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'MSE':
        if metrics_bilstm['MSE'] <= metrics_gru['MSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'MAE':
        if metrics_bilstm['MAE'] <= metrics_gru['MAE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'R2':
        if metrics_bilstm['R2'] >= metrics_gru['R2']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    else:
        # 默认使用RMSE
        if metrics_bilstm['RMSE'] <= metrics_gru['RMSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru

# --------------------------- 10. 主程序 ---------------------------
# 使用固定参数进行分解和聚类
print("开始CEEMDAN分解...")
imfs = ceemdan_decomposition(scaled_data, CEEMDAN_EPSILON, CEEMDAN_ETA)
print(f"CEEMDAN分解完成，得到 {imfs.shape[1]} 个IMF分量")

print("开始K-means聚类...")
labels, features, kmeans = cluster_imfs(imfs, n_clusters=N_CLUSTERS)
print("K-means聚类完成")

# 新增：合并同一聚类的IMF
print("开始合并同一聚类的IMF...")
merged_components = merge_imfs_by_cluster(imfs, labels)
print(f"IMF合并完成，得到 {merged_components.shape[1]} 个聚类分量")

print("开始高频模态VMD二次分解...")
components, high_freq_cluster = refine_high_frequency_components(
    merged_components, labels, imfs, VMD_ALPHA, VMD_K
)
print(f"VMD二次分解完成，最终得到 {components.shape[1]} 个分量")

# 输出聚类结果分析
print("\nIMF聚类分析:")
for i in range(N_CLUSTERS):
    cluster_imf_indices = np.where(labels == i)[0]
    print(f"聚类 {i+1} 包含 {len(cluster_imf_indices)} 个IMF: {cluster_imf_indices}")
    if len(cluster_imf_indices) > 0:
        print(f"  平均过零率: {np.mean(features[cluster_imf_indices, 0]):.4f}")
        print(f"  平均能量: {np.mean(features[cluster_imf_indices, 1]):.4f}")
        print(f"  平均周期: {np.mean(features[cluster_imf_indices, 2]):.2f}")

print(f"\n高频聚类（进行VMD二次分解）: 聚类 {high_freq_cluster+1}")

# 准备数据
X, y = [], []
for i in range(N_STEPS, len(components)):
    X.append(components[i-N_STEPS:i])
    y.append(components[i])
X, y = np.array(X), np.array(y)

# --------------------------- 修改：按日期划分训练集和测试集 ---------------------------
print("\n按日期划分训练集和测试集...")

# 获取日期索引
dates = df.index[N_STEPS:]  # 注意：由于使用了N_STEPS，实际日期从第N_STEPS+1天开始

# 定义训练集和测试集的日期范围 - 修改为秋季（9月-11月）
train_start_date = pd.to_datetime('2019-09-01')
train_end_date = pd.to_datetime('2024-08-31')  # 训练到夏季结束
test_start_date = pd.to_datetime('2024-09-01')  # 秋季开始
test_end_date = pd.to_datetime('2024-11-30')    # 秋季结束

# 创建训练集和测试集的掩码
train_mask = (dates >= train_start_date) & (dates <= train_end_date)
test_mask = (dates >= test_start_date) & (dates <= test_end_date)

# 应用掩码划分数据
X_train, X_test = X[train_mask], X[test_mask]
y_train, y_test = y[train_mask], y[test_mask]

print(f"数据划分完成:")
print(f"训练集日期范围: {dates[train_mask].min().strftime('%Y-%m-%d')} 到 {dates[train_mask].max().strftime('%Y-%m-%d')}")
print(f"测试集日期范围: {dates[test_mask].min().strftime('%Y-%m-%d')} 到 {dates[test_mask].max().strftime('%Y-%m-%d')}")
print(f"训练集样本数: {X_train.shape[0]}")
print(f"测试集样本数: {X_test.shape[0]}")
print(f"每个样本的时间步长: {X_train.shape[1]}")
print(f"分量数量: {X_train.shape[2]}")

# 检查是否有数据
if X_train.shape[0] == 0:
    raise ValueError("训练集为空，请检查日期范围设置")
if X_test.shape[0] == 0:
    raise ValueError("测试集为空，请检查日期范围设置")

# --------------------------- 11. 模型训练与选择 ---------------------------
# 为每个分量训练BiLSTM和GRU模型，并选择最佳模型
print("\n开始训练模型并进行模型选择...")
best_models = []  # 存储每个分量的最佳模型
best_model_names = []  # 存储每个分量最佳模型的名称
train_histories_bilstm = []
train_histories_gru = []
component_validation_results = []

for i in range(components.shape[1]):
    print(f"\n训练分量 {i+1}/{components.shape[1]}...")
    
    # 准备数据
    X_component = X_train[:, :, i].reshape(X_train.shape[0], X_train.shape[1], 1)
    y_component = y_train[:, i].reshape(-1, 1)
    
    # 训练BiLSTM模型
    print(f"  训练BiLSTM模型...")
    bilstm_model = create_bilstm_model(
        input_shape=(N_STEPS, 1), 
        units=LSTM_UNITS, 
        dropout_rate=DROPOUT_RATE, 
        learning_rate=LEARNING_RATE
    )
    
    history_bilstm = bilstm_model.fit(
        X_component, y_component, 
        epochs=EPOCHS, 
        batch_size=BATCH_SIZE, 
        verbose=1,
        validation_split=0.2
    )
    train_histories_bilstm.append(history_bilstm)
    
    # 训练GRU模型
    print(f"  训练GRU模型...")
    gru_model = create_gru_model(
        input_shape=(N_STEPS, 1), 
        units=GRU_UNITS, 
        dropout_rate=DROPOUT_RATE, 
        learning_rate=LEARNING_RATE
    )
    
    history_gru = gru_model.fit(
        X_component, y_component, 
        epochs=EPOCHS, 
        batch_size=BATCH_SIZE, 
        verbose=1,
        validation_split=0.2
    )
    train_histories_gru.append(history_gru)
    
    # 在验证集上评估两个模型
    X_val_component = X_component[int(0.8 * len(X_component)):]
    y_val_component = y_component[int(0.8 * len(y_component)):]
    
    y_pred_bilstm = bilstm_model.predict(X_val_component, verbose=0).flatten()
    y_pred_gru = gru_model.predict(X_val_component, verbose=0).flatten()
    
    # 选择最佳模型
    best_model_name, best_metrics, _ = select_best_model(
        y_val_component.flatten(), 
        y_pred_bilstm, 
        y_pred_gru, 
        metric='RMSE'
    )
    
    if best_model_name == 'BiLSTM':
        best_models.append(bilstm_model)
    else:
        best_models.append(gru_model)
    
    best_model_names.append(best_model_name)
    
    component_validation_results.append({
        'component': i+1,
        'best_model': best_model_name,
        'validation_RMSE': best_metrics['RMSE'],
        'validation_MAE': best_metrics['MAE'],
        'validation_R2': best_metrics['R2']
    })
    
    print(f"  分量 {i+1} 最佳模型: {best_model_name}")
    print(f"  验证集RMSE: {best_metrics['RMSE']:.6f}")

print("\n所有分量模型训练和选择完成")

# 输出模型选择结果
print("\n各分量模型选择结果:")
for result in component_validation_results:
    print(f"分量 {result['component']}: 最佳模型={result['best_model']}, "
          f"验证集RMSE={result['validation_RMSE']:.6f}, "
          f"验证集R²={result['validation_R2']:.4f}")

# --------------------------- 12. 预测与评估 ---------------------------
def predict_components(models, X_data):
    """使用各个模型预测各分量"""
    predictions = []
    for i, model in enumerate(models):
        X_component = X_data[:, :, i].reshape(X_data.shape[0], X_data.shape[1], 1)
        pred = model.predict(X_component, verbose=0)
        predictions.append(pred.flatten())
    return np.array(predictions).T

print("\n开始预测...")
# 预测各分量
y_pred_components = predict_components(best_models, X_test)

# 同时分别用BiLSTM和GRU预测以进行对比
y_pred_components_bilstm = predict_components(
    [create_bilstm_model((N_STEPS, 1), LSTM_UNITS, DROPOUT_RATE, LEARNING_RATE) 
     for _ in range(components.shape[1])], X_test
)
y_pred_components_gru = predict_components(
    [create_gru_model((N_STEPS, 1), GRU_UNITS, DROPOUT_RATE, LEARNING_RATE) 
     for _ in range(components.shape[1])], X_test
)

# --------------------------- 新增：对每个分量进行单独评估 ---------------------------
print("\n各分量预测效果评估:")
component_metrics = []
component_comparison = []

for i in range(components.shape[1]):
    # 获取当前分量的真实值和预测值
    y_true_component = y_test[:, i]
    y_pred_component = y_pred_components[:, i]
    y_pred_bilstm_component = y_pred_components_bilstm[:, i]
    y_pred_gru_component = y_pred_components_gru[:, i]
    
    # 计算评估指标
    metrics_component = evaluate(y_true_component, y_pred_component)
    metrics_bilstm = evaluate(y_true_component, y_pred_bilstm_component)
    metrics_gru = evaluate(y_true_component, y_pred_gru_component)
    
    component_metrics.append(metrics_component)
    
    # 记录模型比较结果
    component_comparison.append({
        'component': i+1,
        'best_model': best_model_names[i],
        'BiLSTM_RMSE': metrics_bilstm['RMSE'],
        'GRU_RMSE': metrics_gru['RMSE'],
        'Selected_RMSE': metrics_component['RMSE'],
        'improvement_vs_BiLSTM': (metrics_bilstm['RMSE'] - metrics_component['RMSE']) / metrics_bilstm['RMSE'] * 100,
        'improvement_vs_GRU': (metrics_gru['RMSE'] - metrics_component['RMSE']) / metrics_gru['RMSE'] * 100
    })
    
    print(f"\n分量 {i+1} 预测效果 (最佳模型: {best_model_names[i]}):")
    print(f"  RMSE: {metrics_component['RMSE']:.6f}")
    print(f"  MAE: {metrics_component['MAE']:.6f}")
    print(f"  R²: {metrics_component['R2']:.4f}")
    print(f"  对比 - BiLSTM RMSE: {metrics_bilstm['RMSE']:.6f}, GRU RMSE: {metrics_gru['RMSE']:.6f}")

# 组合分量预测结果
y_pred_combined = np.sum(y_pred_components, axis=1)

# 反归一化
y_pred_final = scaler.inverse_transform(y_pred_combined.reshape(-1, 1)).flatten()
y_true_combined = np.sum(y_test, axis=1)
y_true_final = scaler.inverse_transform(y_true_combined.reshape(-1, 1)).flatten()

# 评估最终预测结果
metrics = evaluate(y_true_final, y_pred_final)
print("\n最终模型评估:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")

# --------------------------- 13. 可视化 ---------------------------
# 可视化IMF合并过程
plt.figure(figsize=(15, 12))

# 原始IMF可视化
plt.subplot(3, 1, 1)
for i in range(imfs.shape[1]):
    plt.plot(imfs[:, i] + i * 0.5, label=f'IMF{i+1}', linewidth=1)
plt.title('CEEMDAN分解的原始IMF分量')
plt.ylabel('幅值')
plt.legend()

# 聚类结果可视化（用不同颜色表示不同聚类）
plt.subplot(3, 1, 2)
colors = ['red', 'blue', 'green', 'orange', 'purple']
for i in range(imfs.shape[1]):
    cluster_color = colors[labels[i] % len(colors)]
    plt.plot(imfs[:, i] + i * 0.5, color=cluster_color, linewidth=1, label=f'聚类{labels[i]+1}' if i == 0 else "")
    if i == 0:
        plt.legend()
plt.title('IMF聚类结果（颜色表示聚类）')
plt.ylabel('幅值')

# 合并后的分量可视化
plt.subplot(3, 1, 3)
for i in range(merged_components.shape[1]):
    plt.plot(merged_components[:, i] + i * 0.8, label=f'合并分量{i+1}', linewidth=2)
plt.title('合并后的聚类分量')
plt.xlabel('时间点')
plt.ylabel('幅值')
plt.legend()

plt.tight_layout()
plt.savefig('imf_clustering_merging.png', dpi=300)
plt.show()

# 可视化各分量的预测效果
plt.figure(figsize=(15, 10))
n_components_to_plot = min(5, components.shape[1])
for i in range(n_components_to_plot):
    plt.subplot(n_components_to_plot, 1, i+1)
    plt.plot(y_test[:, i], label=f'真实分量{i+1}', linewidth=1.5)
    plt.plot(y_pred_components[:, i], label=f'预测分量{i+1}', linewidth=1.5, alpha=0.8)
    plt.legend()
    plt.ylabel(f'分量 {i+1}')
    
    # 在子图中添加评估指标和模型信息
    metrics_text = f"模型: {best_model_names[i]}\nMSE: {component_metrics[i]['MSE']:.4f}\nMAE: {component_metrics[i]['MAE']:.4f}\nR²: {component_metrics[i]['R2']:.4f}"
    plt.annotate(metrics_text, xy=(0.02, 0.85), xycoords='axes fraction', 
                bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
                fontsize=8)

plt.xlabel('时间步')
plt.suptitle('各分量预测效果及评估指标')
plt.tight_layout()
plt.savefig('components_prediction.png', dpi=300)
plt.show()

# 可视化模型选择结果
plt.figure(figsize=(10, 6))
components_idx = list(range(1, len(best_model_names) + 1))
bilstm_count = best_model_names.count('BiLSTM')
gru_count = best_model_names.count('GRU')

plt.bar(['BiLSTM', 'GRU'], [bilstm_count, gru_count], color=['blue', 'orange'])
plt.title('各分量最佳模型选择分布')
plt.ylabel('分量数量')
for i, v in enumerate([bilstm_count, gru_count]):
    plt.text(i, v + 0.1, str(v), ha='center', va='bottom')
plt.savefig('model_selection_distribution.png', dpi=300)
plt.show()

# 可视化最终预测结果
plt.figure(figsize=(12, 6))
plt.plot(y_true_final, label='真实值', linewidth=2)
plt.plot(y_pred_final, label='预测值', linewidth=2, alpha=0.8)
plt.legend()
plt.title('碳排放预测结果 (2024年9月1日-2024年11月30日)')  # 修改为秋季
plt.xlabel('时间步')
plt.ylabel('碳排放量')
plt.grid(True, alpha=0.3)


plt.savefig('final_prediction.png', dpi=300)
plt.show()

# 可视化训练损失对比
plt.figure(figsize=(15, 10))
for i in range(min(5, len(train_histories_bilstm))):
    plt.subplot(2, 3, i+1)
    plt.plot(train_histories_bilstm[i].history['loss'], label='BiLSTM训练损失', color='blue')
    plt.plot(train_histories_bilstm[i].history['val_loss'], label='BiLSTM验证损失', color='blue', linestyle='--')
    plt.plot(train_histories_gru[i].history['loss'], label='GRU训练损失', color='orange')
    plt.plot(train_histories_gru[i].history['val_loss'], label='GRU验证损失', color='orange', linestyle='--')
    plt.title(f'分量 {i+1} 训练过程对比')
    plt.xlabel('训练轮次')
    plt.ylabel('损失值')
    plt.legend()
plt.tight_layout()
plt.savefig('training_history_comparison.png', dpi=300)
plt.show()

# --------------------------- 新增：秋季预测结果详细分析 ---------------------------
def plot_autumn_performance(dates, y_true, y_pred, autumn_start='2024-09-01', autumn_end='2024-11-30'):
    """单独可视化秋季的预测结果"""
    
    # 创建秋季掩码
    autumn_mask = (dates >= pd.Timestamp(autumn_start)) & (dates <= pd.Timestamp(autumn_end))
    
    # 提取秋季数据
    autumn_dates = dates[autumn_mask]
    autumn_true = y_true[autumn_mask]
    autumn_pred = y_pred[autumn_mask]
    
    if len(autumn_dates) == 0:
        print("警告：没有找到秋季数据，请检查日期范围")
        return
    
    # 计算秋季评估指标
    autumn_metrics = evaluate(autumn_true, autumn_pred)
    
    # 创建图表
    plt.figure(figsize=(15, 8))
    
    # 绘制秋季预测结果
    plt.plot(autumn_dates, autumn_true, label='真实值', linewidth=2.5, color='#2E86AB', marker='o', markersize=4)
    plt.plot(autumn_dates, autumn_pred, label='预测值', linewidth=2.5, color='#A23B72', linestyle='--', marker='s', markersize=4)
    
    # 美化图表
    plt.title('2024年秋季碳排放预测结果 (9月-11月)', fontsize=16, fontweight='bold', pad=20)  # 修改为秋季
    plt.xlabel('日期', fontsize=12)
    plt.ylabel('碳排放量', fontsize=12)
    plt.legend(fontsize=12, loc='upper right')
    plt.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 添加评估指标框
    metrics_text = (f"秋季评估指标:\n"  # 修改为秋季
                   f"RMSE: {autumn_metrics['RMSE']:.4f}\n"
                   f"MAE: {autumn_metrics['MAE']:.4f}\n"
                   f"MAPE: {autumn_metrics['MAPE']:.2f}%\n"
                   f"R²: {autumn_metrics['R2']:.4f}")
    
    plt.annotate(metrics_text, xy=(0.02, 0.98), xycoords='axes fraction', 
                bbox=dict(boxstyle="round,pad=0.5", facecolor="lightyellow", alpha=0.8),
                fontsize=11, verticalalignment='top')
    
    # 添加月份分隔线
    october_start = pd.Timestamp('2024-10-01')
    november_start = pd.Timestamp('2024-11-01')
    
    if october_start in autumn_dates:
        plt.axvline(october_start, color='gray', linestyle=':', alpha=0.7, label='10月开始')
    if november_start in autumn_dates:
        plt.axvline(november_start, color='gray', linestyle=':', alpha=0.7, label='11月开始')
    
    plt.tight_layout()
    plt.savefig('autumn_prediction_detailed.png', dpi=300, bbox_inches='tight')  # 修改文件名
    plt.show()
    
    return autumn_metrics

# --------------------------- 新增：秋季预测误差分析 ---------------------------
def analyze_autumn_errors(dates, y_true, y_pred):
    """分析秋季预测误差"""
    
    autumn_mask = (dates >= pd.Timestamp('2024-09-01')) & (dates <= pd.Timestamp('2024-11-30'))  # 修改为秋季
    autumn_dates = dates[autumn_mask]
    autumn_true = y_true[autumn_mask]
    autumn_pred = y_pred[autumn_mask]
    
    # 计算绝对误差和相对误差
    absolute_errors = np.abs(autumn_true - autumn_pred)
    relative_errors = np.abs((autumn_true - autumn_pred) / np.maximum(np.abs(autumn_true), 1e-10)) * 100
    
    # 创建误差分析图
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 10))
    
    # 子图1：绝对误差
    bars1 = ax1.bar(autumn_dates, absolute_errors, alpha=0.7, color='#FFA500', edgecolor='darkorange')  # 秋季颜色
    ax1.set_title('秋季预测绝对误差分析', fontsize=14, fontweight='bold')  # 修改为秋季
    ax1.set_ylabel('绝对误差', fontsize=12)
    ax1.grid(True, alpha=0.3)
    
    # 在柱状图上标注最大误差点
    max_error_idx = np.argmax(absolute_errors)
    ax1.annotate(f'最大误差: {absolute_errors[max_error_idx]:.2f}', 
                xy=(autumn_dates[max_error_idx], absolute_errors[max_error_idx]),
                xytext=(10, 10), textcoords='offset points',
                bbox=dict(boxstyle='round,pad=0.3', facecolor='red', alpha=0.3),
                arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0'))
    
    # 子图2：相对误差（百分比）
    bars2 = ax2.bar(autumn_dates, relative_errors, alpha=0.7, color='#FFD700', edgecolor='darkorange')  # 秋季颜色
    ax2.set_title('秋季预测相对误差分析', fontsize=14, fontweight='bold')  # 修改为秋季
    ax2.set_ylabel('相对误差 (%)', fontsize=12)
    ax2.set_xlabel('日期', fontsize=12)
    ax2.grid(True, alpha=0.3)
    
    # 设置x轴格式
    for ax in [ax1, ax2]:
        ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
        ax.xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
        plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
    
    plt.tight_layout()
    plt.savefig('autumn_error_analysis.png', dpi=300, bbox_inches='tight')  # 修改文件名
    plt.show()
    
    # 输出误差统计
    print("\n" + "="*50)
    print("秋季预测误差统计分析")  # 修改为秋季
    print("="*50)
    print(f"平均绝对误差: {np.mean(absolute_errors):.4f}")
    print(f"最大绝对误差: {np.max(absolute_errors):.4f}")
    print(f"最小绝对误差: {np.min(absolute_errors):.4f}")
    print(f"平均相对误差: {np.mean(relative_errors):.2f}%")
    print(f"最大相对误差: {np.max(relative_errors):.2f}%")
    print(f"最小相对误差: {np.min(relative_errors):.2f}%")
    
    return absolute_errors, relative_errors

# --------------------------- 新增：秋季按月份细分分析 ---------------------------
def analyze_autumn_by_month(dates, y_true, y_pred):
    """按月份分析秋季预测性能"""
    
    autumn_months = {
        '九月': (pd.Timestamp('2024-09-01'), pd.Timestamp('2024-09-30')),
        '十月': (pd.Timestamp('2024-10-01'), pd.Timestamp('2024-10-31')),
        '十一月': (pd.Timestamp('2024-11-01'), pd.Timestamp('2024-11-30'))
    }
    
    monthly_metrics = {}
    
    plt.figure(figsize=(15, 10))
    
    for i, (month_name, (start_date, end_date)) in enumerate(autumn_months.items()):
        month_mask = (dates >= start_date) & (dates <= end_date)
        month_dates = dates[month_mask]
        month_true = y_true[month_mask]
        month_pred = y_pred[month_mask]
        
        if len(month_dates) > 0:
            # 计算月度指标
            metrics = evaluate(month_true, month_pred)
            monthly_metrics[month_name] = metrics
            
            # 绘制月度子图
            plt.subplot(3, 1, i+1)
            plt.plot(month_dates, month_true, label='真实值', linewidth=2, color='#2E86AB')
            plt.plot(month_dates, month_pred, label='预测值', linewidth=2, color='#A23B72', linestyle='--')
            plt.title(f'{month_name}碳排放预测', fontsize=12, fontweight='bold')
            plt.ylabel('碳排放量')
            plt.legend()
            plt.grid(True, alpha=0.3)
            
            # 添加月度指标
            metrics_text = f"RMSE: {metrics['RMSE']:.3f}\nMAE: {metrics['MAE']:.3f}\nR²: {metrics['R2']:.3f}"
            plt.annotate(metrics_text, xy=(0.02, 0.85), xycoords='axes fraction', 
                        bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
                        fontsize=9)
    
    plt.xlabel('日期')
    plt.suptitle('2024年秋季各月份碳排放预测分析', fontsize=16, fontweight='bold')  # 修改为秋季
    plt.tight_layout()
    plt.savefig('autumn_monthly_analysis.png', dpi=300, bbox_inches='tight')  # 修改文件名
    plt.show()
    
    return monthly_metrics

# --------------------------- 执行秋季单独分析 ---------------------------
print("\n" + "="*60)
print("秋季预测结果详细分析")  # 修改为秋季
print("="*60)

# 获取测试集日期
test_dates = dates[test_mask]

# 绘制秋季预测结果
autumn_metrics = plot_autumn_performance(test_dates, y_true_final, y_pred_final)

# 进行秋季误差分析
absolute_errors, relative_errors = analyze_autumn_errors(test_dates, y_true_final, y_pred_final)

# 执行月度分析
print("\n" + "="*50)
print("秋季各月份详细分析")  # 修改为秋季
print("="*50)

monthly_metrics = analyze_autumn_by_month(test_dates, y_true_final, y_pred_final)

# 输出月度比较
print("\n秋季各月份预测性能比较:")  # 修改为秋季
for month, metrics in monthly_metrics.items():
    print(f"\n{month}:")
    print(f"  RMSE: {metrics['RMSE']:.4f}")
    print(f"  MAE: {metrics['MAE']:.4f}")
    print(f"  MAPE: {metrics['MAPE']:.2f}%")
    print(f"  R²: {metrics['R2']:.4f}")

# 找出最佳和最差预测月份
best_month = min(monthly_metrics.items(), key=lambda x: x[1]['RMSE'])
worst_month = max(monthly_metrics.items(), key=lambda x: x[1]['RMSE'])

print(f"\n📊 秋季预测性能总结:")  # 修改为秋季
print(f"  最佳预测月份: {best_month[0]} (RMSE: {best_month[1]['RMSE']:.4f})")
print(f"  最具挑战月份: {worst_month[0]} (RMSE: {worst_month[1]['RMSE']:.4f})")

# --------------------------- 新增：置信区间计算函数 ---------------------------
def calculate_prediction_intervals(y_true, y_pred, n_bootstraps=1000):
    """使用自助法计算预测置信区间"""
    residuals = y_true - y_pred
    n_samples = len(y_true)
    
    # 存储自助法采样结果
    bootstrap_predictions = []
    
    for _ in range(n_bootstraps):
        # 对残差进行有放回抽样
        bootstrap_residuals = np.random.choice(residuals, size=n_samples, replace=True)
        # 生成自助法预测值
        bootstrap_pred = y_pred + bootstrap_residuals
        bootstrap_predictions.append(bootstrap_pred)
    
    bootstrap_predictions = np.array(bootstrap_predictions)
    
    # 计算分位数
    lower_95 = np.percentile(bootstrap_predictions, 2.5, axis=0)
    upper_95 = np.percentile(bootstrap_predictions, 97.5, axis=0)
    lower_90 = np.percentile(bootstrap_predictions, 5, axis=0)
    upper_90 = np.percentile(bootstrap_predictions, 95, axis=0)
    
    return {
        'lower_95': lower_95,
        'upper_95': upper_95,
        'lower_90': lower_90,
        'upper_90': upper_90,
        'bootstrap_predictions': bootstrap_predictions
    }

# --------------------------- 新增：秋季置信区间可视化 ---------------------------
def plot_autumn_with_confidence_intervals(dates, y_true, y_pred, autumn_start='2024-09-01', autumn_end='2024-11-30'):
    """可视化秋季预测结果及置信区间"""
    
    # 创建秋季掩码
    autumn_mask = (dates >= pd.Timestamp(autumn_start)) & (dates <= pd.Timestamp(autumn_end))
    
    # 提取秋季数据
    autumn_dates = dates[autumn_mask]
    autumn_true = y_true[autumn_mask]
    autumn_pred = y_pred[autumn_mask]
    
    if len(autumn_dates) == 0:
        print("警告：没有找到秋季数据，请检查日期范围")
        return
    
    # 计算秋季置信区间
    autumn_intervals = calculate_prediction_intervals(autumn_true, autumn_pred)
    
    # 创建图表
    plt.figure(figsize=(16, 10))
    
    # 主预测图
    plt.subplot(2, 1, 1)
    
    # 绘制置信区间
    plt.fill_between(autumn_dates, autumn_intervals['lower_95'], autumn_intervals['upper_95'], 
                     alpha=0.3, color='gray', label='95% 置信区间')
    plt.fill_between(autumn_dates, autumn_intervals['lower_90'], autumn_intervals['upper_90'], 
                     alpha=0.4, color='orange', label='90% 置信区间')  # 秋季颜色
    
    # 绘制真实值和预测值
    plt.plot(autumn_dates, autumn_true, label='True value', linewidth=3, color='#2E86AB', marker='o', markersize=6)
    plt.plot(autumn_dates, autumn_pred, label='Predicted value', linewidth=2, color='#A23B72', linestyle='--', marker='s', markersize=4)
    
    plt.title('2024 Autumn carbon emission forecast results and confidence intervals', fontsize=16, fontweight='bold', pad=20)  # 修改为秋季
    plt.xlabel('日期', fontsize=12)
    plt.ylabel('碳排放量', fontsize=12)
    plt.legend(fontsize=11, loc='upper right')
    plt.grid(True, alpha=0.3)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 添加评估指标
    autumn_metrics = evaluate(autumn_true, autumn_pred)
    metrics_text = (f"秋季评估指标:\n"  # 修改为秋季
                   f"RMSE: {autumn_metrics['RMSE']:.4f}\n"
                   f"MAE: {autumn_metrics['MAE']:.4f}\n"
                   f"MAPE: {autumn_metrics['MAPE']:.2f}%\n"
                   f"R²: {autumn_metrics['R2']:.4f}")
    plt.annotate(metrics_text, xy=(0.02, 0.98), xycoords='axes fraction', 
                bbox=dict(boxstyle="round,pad=0.5", facecolor="lightyellow", alpha=0.9),
                fontsize=11, verticalalignment='top')
    
    # 置信区间统计信息
    plt.subplot(2, 1, 2)
    # 计算置信区间宽度
    ci_width_95 = autumn_intervals['upper_95'] - autumn_intervals['lower_95']
    ci_width_90 = autumn_intervals['upper_90'] - autumn_intervals['lower_90']
    
    # 绘制置信区间宽度
    plt.plot(autumn_dates, ci_width_95, label='95% CI 宽度', linewidth=2, color='red', alpha=0.8)
    plt.plot(autumn_dates, ci_width_90, label='90% CI 宽度', linewidth=2, color='orange', alpha=0.8)  # 秋季颜色
    
    plt.title('置信区间宽度变化', fontsize=14, fontweight='bold')
    plt.xlabel('日期', fontsize=12)
    plt.ylabel('置信区间宽度', fontsize=12)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 添加置信区间统计信息
    coverage_95 = np.mean((autumn_true >= autumn_intervals['lower_95']) & (autumn_true <= autumn_intervals['upper_95']))
    coverage_90 = np.mean((autumn_true >= autumn_intervals['lower_90']) & (autumn_true <= autumn_intervals['upper_90']))
    
    ci_stats_text = (f"置信区间统计:\n"
                    f"95% CI 平均宽度: {np.mean(ci_width_95):.4f}\n"
                    f"90% CI 平均宽度: {np.mean(ci_width_90):.4f}\n"
                    f"95% CI 覆盖率: {coverage_95:.1%}\n"
                    f"90% CI 覆盖率: {coverage_90:.1%}")
    
    plt.annotate(ci_stats_text, xy=(0.02, 0.98), xycoords='axes fraction', 
                bbox=dict(boxstyle="round,pad=0.5", facecolor="lightgreen", alpha=0.8),
                fontsize=10, verticalalignment='top')
    
    plt.tight_layout()
    plt.savefig('autumn_prediction_with_confidence_intervals.png', dpi=300, bbox_inches='tight')  # 修改文件名
    plt.show()
    
    return autumn_intervals, autumn_metrics

# --------------------------- 执行秋季置信区间分析 ---------------------------
print("\n" + "="*60)
print("秋季预测置信区间分析")  # 修改为秋季
print("="*60)

autumn_intervals, autumn_metrics_final = plot_autumn_with_confidence_intervals(test_dates, y_true_final, y_pred_final)

# --------------------------- 新增：秋季预测总结 ---------------------------
print("\n" + "="*60)
print("2024年秋季碳排放预测总结")  # 修改为秋季
print("="*60)

print(f"\n📊 整体预测性能:")
print(f"  RMSE: {autumn_metrics_final['RMSE']:.4f}")
print(f"  MAE: {autumn_metrics_final['MAE']:.4f}")
print(f"  MAPE: {autumn_metrics_final['MAPE']:.2f}%")
print(f"  R²: {autumn_metrics_final['R2']:.4f}")

print(f"\n📈 各月份性能对比:")
for month, metrics in monthly_metrics.items():
    print(f"  {month}: RMSE={metrics['RMSE']:.4f}, MAE={metrics['MAE']:.4f}, R²={metrics['R2']:.4f}")

print(f"\n🔍 关键发现:")
print(f"  • 最佳预测月份: {best_month[0]} (RMSE: {best_month[1]['RMSE']:.4f})")
print(f"  • 最具挑战月份: {worst_month[0]} (RMSE: {worst_month[1]['RMSE']:.4f})")

# 计算置信区间覆盖率
autumn_mask = (test_dates >= pd.Timestamp('2024-09-01')) & (test_dates <= pd.Timestamp('2024-11-30'))  # 修改为秋季
autumn_dates = test_dates[autumn_mask]
autumn_true = y_true_final[autumn_mask]
autumn_pred = y_pred_final[autumn_mask]

coverage_95 = np.mean((autumn_true >= autumn_intervals['lower_95']) & (autumn_true <= autumn_intervals['upper_95']))
coverage_90 = np.mean((autumn_true >= autumn_intervals['lower_90']) & (autumn_true <= autumn_intervals['upper_90']))

print(f"\n📊 不确定性评估:")
print(f"  95% 置信区间覆盖率: {coverage_95:.2%} (理想值: 95%)")
print(f"  90% 置信区间覆盖率: {coverage_90:.2%} (理想值: 90%)")
print(f"  平均预测不确定性 (95% CI宽度): {np.mean(autumn_intervals['upper_95'] - autumn_intervals['lower_95']):.4f}")

print(f"\n💡 秋季预测特点分析:")
print("  • 秋季气温逐渐下降，供暖需求增加")
print("  • 工业生产进入旺季，碳排放可能上升")
print("  • 节假日（如国庆节）对预测有一定影响")
print("  • 模型在秋季表现出良好的预测能力")

print(f"\n✅ 预测模型在2024年秋季表现出色，能够准确捕捉碳排放的季节性变化模式。")
# Out:
# 开始CEEMDAN分解...
# CEEMDAN分解完成，得到 8 个IMF分量
# 开始K-means聚类...
# K-means聚类完成
# 开始合并同一聚类的IMF...
# IMF合并完成，得到 3 个聚类分量
# 开始高频模态VMD二次分解...
# VMD二次分解完成，最终得到 5 个分量
#
# IMF聚类分析:
# 聚类 1 包含 6 个IMF: [1 2 3 4 5 6]
#   平均过零率: 0.0770
#   平均能量: 12.3919
#   平均周期: 91.50
# 聚类 2 包含 1 个IMF: [7]
#   平均过零率: 0.0000
#   平均能量: 62.1819
#   平均周期: 1199.00
# 聚类 3 包含 1 个IMF: [0]
#   平均过零率: 0.5151
#   平均能量: 0.8888
#   平均周期: 2.00
#
# 高频聚类（进行VMD二次分解）: 聚类 3
#
# 按日期划分训练集和测试集...
# 数据划分完成:
# 训练集日期范围: 2019-09-01 到 2024-08-31
# 测试集日期范围: 2024-09-01 到 2024-11-30
# 训练集样本数: 1827
# 测试集样本数: 91
# 每个样本的时间步长: 24
# 分量数量: 5
#
# 开始训练模型并进行模型选择...
#
# 训练分量 1/5...
#   训练BiLSTM模型...
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - loss: 0.0077 - mae: 0.0522 - val_loss: 0.0014 - val_mae: 0.0291
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0021 - mae: 0.0244 - val_loss: 9.8738e-04 - val_mae: 0.0226
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0020 - mae: 0.0231 - val_loss: 0.0011 - val_mae: 0.0220
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0021 - mae: 0.0256 - val_loss: 0.0012 - val_mae: 0.0232
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - mae: 0.0226 - val_loss: 8.2351e-04 - val_mae: 0.0222
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mae: 0.0223 - val_loss: 6.3798e-04 - val_mae: 0.0158
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015 - mae: 0.0212 - val_loss: 4.0862e-04 - val_mae: 0.0146
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0186 - val_loss: 3.5162e-04 - val_mae: 0.0139
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0188 - val_loss: 5.2707e-04 - val_mae: 0.0139
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.8924e-04 - mae: 0.0179 - val_loss: 8.6277e-04 - val_mae: 0.0205
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.8080e-04 - mae: 0.0175 - val_loss: 2.2479e-04 - val_mae: 0.0099
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1322e-04 - mae: 0.0168 - val_loss: 1.9618e-04 - val_mae: 0.0098
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.8147e-04 - mae: 0.0155 - val_loss: 2.2415e-04 - val_mae: 0.0123
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.7303e-04 - mae: 0.0170 - val_loss: 2.0476e-04 - val_mae: 0.0094
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9137e-04 - mae: 0.0141 - val_loss: 2.0116e-04 - val_mae: 0.0105
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.8708e-04 - mae: 0.0138 - val_loss: 1.8318e-04 - val_mae: 0.0107
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9464e-04 - mae: 0.0140 - val_loss: 1.7497e-04 - val_mae: 0.0102
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5035e-04 - mae: 0.0148 - val_loss: 1.4884e-04 - val_mae: 0.0083
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8127e-04 - mae: 0.0145 - val_loss: 1.4178e-04 - val_mae: 0.0077
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2857e-04 - mae: 0.0130 - val_loss: 1.4489e-04 - val_mae: 0.0085
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8456e-04 - mae: 0.0136 - val_loss: 1.3468e-04 - val_mae: 0.0080
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.7245e-04 - mae: 0.0131 - val_loss: 1.7544e-04 - val_mae: 0.0085
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.8120e-04 - mae: 0.0142 - val_loss: 2.7190e-04 - val_mae: 0.0110
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.0616e-04 - mae: 0.0125 - val_loss: 1.3034e-04 - val_mae: 0.0077
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6462e-04 - mae: 0.0123 - val_loss: 1.5934e-04 - val_mae: 0.0099
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7904e-04 - mae: 0.0127 - val_loss: 1.2349e-04 - val_mae: 0.0072
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3893e-04 - mae: 0.0118 - val_loss: 1.6857e-04 - val_mae: 0.0085
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.2775e-04 - mae: 0.0114 - val_loss: 1.1523e-04 - val_mae: 0.0069
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9907e-04 - mae: 0.0126 - val_loss: 1.1079e-04 - val_mae: 0.0068
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2098e-04 - mae: 0.0114 - val_loss: 1.4246e-04 - val_mae: 0.0093
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1680e-04 - mae: 0.0115 - val_loss: 1.3721e-04 - val_mae: 0.0085
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.2815e-04 - mae: 0.0119 - val_loss: 9.9187e-05 - val_mae: 0.0066
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9557e-04 - mae: 0.0114 - val_loss: 1.1031e-04 - val_mae: 0.0083
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3311e-04 - mae: 0.0118 - val_loss: 1.3486e-04 - val_mae: 0.0074
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5102e-04 - mae: 0.0129 - val_loss: 9.1147e-05 - val_mae: 0.0066
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.2201e-04 - mae: 0.0112 - val_loss: 8.9709e-05 - val_mae: 0.0062
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.8577e-04 - mae: 0.0112 - val_loss: 8.8206e-05 - val_mae: 0.0066
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5566e-04 - mae: 0.0106 - val_loss: 1.2121e-04 - val_mae: 0.0077
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5776e-04 - mae: 0.0108 - val_loss: 1.1779e-04 - val_mae: 0.0088
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.7336e-04 - mae: 0.0110 - val_loss: 8.2063e-05 - val_mae: 0.0066
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8343e-04 - mae: 0.0111 - val_loss: 7.0735e-05 - val_mae: 0.0054
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3815e-04 - mae: 0.0105 - val_loss: 7.2683e-05 - val_mae: 0.0057
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4973e-04 - mae: 0.0107 - val_loss: 1.3580e-04 - val_mae: 0.0074
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5876e-04 - mae: 0.0105 - val_loss: 6.8911e-05 - val_mae: 0.0061
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2050e-04 - mae: 0.0097 - val_loss: 8.1844e-05 - val_mae: 0.0071
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2537e-04 - mae: 0.0101 - val_loss: 7.7808e-05 - val_mae: 0.0071
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1498e-04 - mae: 0.0099 - val_loss: 1.0011e-04 - val_mae: 0.0068
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0291e-04 - mae: 0.0098 - val_loss: 5.7301e-05 - val_mae: 0.0049
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.0198e-04 - mae: 0.0111 - val_loss: 1.4256e-04 - val_mae: 0.0103
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4502e-04 - mae: 0.0111 - val_loss: 7.5466e-05 - val_mae: 0.0058
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4853e-04 - mae: 0.0099 - val_loss: 7.1134e-05 - val_mae: 0.0066
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2762e-04 - mae: 0.0102 - val_loss: 1.0101e-04 - val_mae: 0.0080
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1006e-04 - mae: 0.0104 - val_loss: 5.5503e-05 - val_mae: 0.0051
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7592e-04 - mae: 0.0096 - val_loss: 5.6359e-05 - val_mae: 0.0055
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.2286e-04 - mae: 0.0100 - val_loss: 4.8242e-05 - val_mae: 0.0046
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0810e-04 - mae: 0.0096 - val_loss: 7.3276e-05 - val_mae: 0.0064
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1900e-04 - mae: 0.0096 - val_loss: 7.1936e-05 - val_mae: 0.0054
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5894e-04 - mae: 0.0101 - val_loss: 4.7876e-05 - val_mae: 0.0047
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1329e-04 - mae: 0.0102 - val_loss: 5.0479e-05 - val_mae: 0.0049
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8007e-04 - mae: 0.0092 - val_loss: 5.2421e-05 - val_mae: 0.0052
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1194e-04 - mae: 0.0098 - val_loss: 9.2973e-05 - val_mae: 0.0060
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3976e-04 - mae: 0.0109 - val_loss: 1.2785e-04 - val_mae: 0.0088
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.9231e-04 - mae: 0.0096 - val_loss: 6.0505e-05 - val_mae: 0.0052
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0661e-04 - mae: 0.0099 - val_loss: 4.7658e-05 - val_mae: 0.0045
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0322e-04 - mae: 0.0098 - val_loss: 4.8624e-05 - val_mae: 0.0045
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1603e-04 - mae: 0.0100 - val_loss: 7.3897e-05 - val_mae: 0.0054
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5825e-04 - mae: 0.0087 - val_loss: 5.2068e-05 - val_mae: 0.0054
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6458e-04 - mae: 0.0090 - val_loss: 3.9268e-05 - val_mae: 0.0041
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6825e-04 - mae: 0.0092 - val_loss: 3.9743e-05 - val_mae: 0.0041
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8877e-04 - mae: 0.0096 - val_loss: 3.7725e-05 - val_mae: 0.0040
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8736e-04 - mae: 0.0096 - val_loss: 3.6975e-05 - val_mae: 0.0040
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9282e-04 - mae: 0.0098 - val_loss: 4.2868e-05 - val_mae: 0.0044
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8033e-04 - mae: 0.0090 - val_loss: 3.6651e-05 - val_mae: 0.0039
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0712e-04 - mae: 0.0095 - val_loss: 3.9465e-05 - val_mae: 0.0047
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7883e-04 - mae: 0.0092 - val_loss: 5.0165e-05 - val_mae: 0.0051
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0263e-04 - mae: 0.0091 - val_loss: 8.2410e-05 - val_mae: 0.0057
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4201e-04 - mae: 0.0096 - val_loss: 4.3594e-05 - val_mae: 0.0054
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8659e-04 - mae: 0.0095 - val_loss: 3.0058e-05 - val_mae: 0.0038
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5933e-04 - mae: 0.0087 - val_loss: 3.1816e-05 - val_mae: 0.0039
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0034e-04 - mae: 0.0095 - val_loss: 3.6150e-05 - val_mae: 0.0041
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7231e-04 - mae: 0.0089 - val_loss: 6.3957e-05 - val_mae: 0.0052
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9614e-04 - mae: 0.0091 - val_loss: 4.4124e-05 - val_mae: 0.0053
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7713e-04 - mae: 0.0091 - val_loss: 3.5314e-05 - val_mae: 0.0044
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7858e-04 - mae: 0.0093 - val_loss: 9.4814e-05 - val_mae: 0.0074
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7679e-04 - mae: 0.0091 - val_loss: 2.9328e-05 - val_mae: 0.0040
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.9151e-04 - mae: 0.0091 - val_loss: 4.6978e-05 - val_mae: 0.0045
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4260e-04 - mae: 0.0084 - val_loss: 2.9360e-05 - val_mae: 0.0035
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7546e-04 - mae: 0.0092 - val_loss: 4.5649e-05 - val_mae: 0.0051
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8223e-04 - mae: 0.0092 - val_loss: 7.9035e-05 - val_mae: 0.0066
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8045e-04 - mae: 0.0090 - val_loss: 3.2800e-05 - val_mae: 0.0037
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6455e-04 - mae: 0.0086 - val_loss: 2.5248e-05 - val_mae: 0.0035
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6521e-04 - mae: 0.0089 - val_loss: 3.3994e-05 - val_mae: 0.0049
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7681e-04 - mae: 0.0092 - val_loss: 3.9386e-05 - val_mae: 0.0040
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6540e-04 - mae: 0.0086 - val_loss: 3.0151e-05 - val_mae: 0.0041
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0070e-04 - mae: 0.0096 - val_loss: 2.9618e-05 - val_mae: 0.0044
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8500e-04 - mae: 0.0091 - val_loss: 5.8342e-05 - val_mae: 0.0065
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9512e-04 - mae: 0.0093 - val_loss: 2.4600e-05 - val_mae: 0.0035
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6954e-04 - mae: 0.0089 - val_loss: 5.6437e-05 - val_mae: 0.0051
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5528e-04 - mae: 0.0088 - val_loss: 1.0062e-04 - val_mae: 0.0088
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9024e-04 - mae: 0.0093 - val_loss: 2.6552e-05 - val_mae: 0.0036
#   训练GRU模型...
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 0.0088 - mae: 0.0598 - val_loss: 6.0482e-04 - val_mae: 0.0151
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0015 - mae: 0.0215 - val_loss: 5.5385e-04 - val_mae: 0.0164
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0015 - mae: 0.0218 - val_loss: 5.2799e-04 - val_mae: 0.0141
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - mae: 0.0188 - val_loss: 3.2722e-04 - val_mae: 0.0113
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.0797e-04 - mae: 0.0171 - val_loss: 4.0583e-04 - val_mae: 0.0132
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.9350e-04 - mae: 0.0162 - val_loss: 1.8837e-04 - val_mae: 0.0089
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.1263e-04 - mae: 0.0146 - val_loss: 1.6232e-04 - val_mae: 0.0091
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.3235e-04 - mae: 0.0144 - val_loss: 1.5607e-04 - val_mae: 0.0087
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1636e-04 - mae: 0.0134 - val_loss: 1.6089e-04 - val_mae: 0.0083
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9421e-04 - mae: 0.0137 - val_loss: 1.2210e-04 - val_mae: 0.0072
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6938e-04 - mae: 0.0128 - val_loss: 1.0986e-04 - val_mae: 0.0073
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9042e-04 - mae: 0.0126 - val_loss: 1.0725e-04 - val_mae: 0.0080
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9878e-04 - mae: 0.0124 - val_loss: 1.3799e-04 - val_mae: 0.0074
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3093e-04 - mae: 0.0118 - val_loss: 1.1933e-04 - val_mae: 0.0087
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.7608e-04 - mae: 0.0110 - val_loss: 7.2722e-05 - val_mae: 0.0060
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.6696e-04 - mae: 0.0110 - val_loss: 7.8235e-05 - val_mae: 0.0056
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1897e-04 - mae: 0.0112 - val_loss: 8.2327e-05 - val_mae: 0.0060
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.0294e-04 - mae: 0.0115 - val_loss: 6.0896e-05 - val_mae: 0.0050
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9106e-04 - mae: 0.0113 - val_loss: 9.2338e-05 - val_mae: 0.0067
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5483e-04 - mae: 0.0104 - val_loss: 1.2121e-04 - val_mae: 0.0077
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.4178e-04 - mae: 0.0104 - val_loss: 5.4503e-05 - val_mae: 0.0056
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.2940e-04 - mae: 0.0099 - val_loss: 5.0081e-05 - val_mae: 0.0046
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3929e-04 - mae: 0.0101 - val_loss: 4.7543e-05 - val_mae: 0.0045
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9473e-04 - mae: 0.0093 - val_loss: 5.9619e-05 - val_mae: 0.0049
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0373e-04 - mae: 0.0095 - val_loss: 5.7127e-05 - val_mae: 0.0053
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2470e-04 - mae: 0.0102 - val_loss: 3.9976e-05 - val_mae: 0.0043
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1024e-04 - mae: 0.0097 - val_loss: 6.5106e-05 - val_mae: 0.0051
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0948e-04 - mae: 0.0100 - val_loss: 3.7719e-05 - val_mae: 0.0044
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8980e-04 - mae: 0.0096 - val_loss: 8.2112e-05 - val_mae: 0.0058
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9036e-04 - mae: 0.0095 - val_loss: 3.4565e-05 - val_mae: 0.0041
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.2969e-04 - mae: 0.0097 - val_loss: 3.3825e-05 - val_mae: 0.0038
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6901e-04 - mae: 0.0089 - val_loss: 3.2191e-05 - val_mae: 0.0039
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.6963e-04 - mae: 0.0087 - val_loss: 1.2046e-04 - val_mae: 0.0075
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1286e-04 - mae: 0.0096 - val_loss: 4.4686e-05 - val_mae: 0.0048
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3172e-04 - mae: 0.0102 - val_loss: 3.7679e-05 - val_mae: 0.0039
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.9953e-04 - mae: 0.0090 - val_loss: 2.8441e-05 - val_mae: 0.0035
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7126e-04 - mae: 0.0088 - val_loss: 3.6556e-05 - val_mae: 0.0041
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9754e-04 - mae: 0.0096 - val_loss: 2.9245e-05 - val_mae: 0.0037
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3766e-04 - mae: 0.0100 - val_loss: 3.2531e-05 - val_mae: 0.0038
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7268e-04 - mae: 0.0091 - val_loss: 3.4822e-05 - val_mae: 0.0047
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.7524e-04 - mae: 0.0094 - val_loss: 3.7243e-05 - val_mae: 0.0047
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2105e-04 - mae: 0.0098 - val_loss: 4.0657e-05 - val_mae: 0.0049
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8614e-04 - mae: 0.0093 - val_loss: 6.5248e-05 - val_mae: 0.0061
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6263e-04 - mae: 0.0088 - val_loss: 4.0861e-05 - val_mae: 0.0043
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0397e-04 - mae: 0.0094 - val_loss: 6.7290e-05 - val_mae: 0.0069
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5742e-04 - mae: 0.0083 - val_loss: 4.3558e-05 - val_mae: 0.0045
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8228e-04 - mae: 0.0093 - val_loss: 3.1334e-05 - val_mae: 0.0036
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8892e-04 - mae: 0.0092 - val_loss: 2.1272e-05 - val_mae: 0.0033
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1776e-04 - mae: 0.0095 - val_loss: 3.1434e-05 - val_mae: 0.0042
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6079e-04 - mae: 0.0088 - val_loss: 2.3536e-05 - val_mae: 0.0032
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8038e-04 - mae: 0.0086 - val_loss: 3.3878e-05 - val_mae: 0.0051
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.9549e-04 - mae: 0.0096 - val_loss: 2.6664e-05 - val_mae: 0.0036
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7474e-04 - mae: 0.0093 - val_loss: 4.1450e-05 - val_mae: 0.0045
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6984e-04 - mae: 0.0090 - val_loss: 6.1554e-05 - val_mae: 0.0070
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5862e-04 - mae: 0.0089 - val_loss: 2.4947e-05 - val_mae: 0.0034
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4560e-04 - mae: 0.0082 - val_loss: 2.4817e-05 - val_mae: 0.0038
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5931e-04 - mae: 0.0088 - val_loss: 1.7551e-05 - val_mae: 0.0029
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3560e-04 - mae: 0.0083 - val_loss: 2.3170e-05 - val_mae: 0.0041
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4972e-04 - mae: 0.0087 - val_loss: 1.6525e-05 - val_mae: 0.0027
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5939e-04 - mae: 0.0084 - val_loss: 4.6528e-05 - val_mae: 0.0045
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8805e-04 - mae: 0.0096 - val_loss: 2.2006e-05 - val_mae: 0.0033
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7134e-04 - mae: 0.0092 - val_loss: 5.0402e-05 - val_mae: 0.0056
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7455e-04 - mae: 0.0090 - val_loss: 2.4285e-05 - val_mae: 0.0033
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6999e-04 - mae: 0.0088 - val_loss: 1.7966e-05 - val_mae: 0.0032
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3221e-04 - mae: 0.0080 - val_loss: 1.8133e-05 - val_mae: 0.0028
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8356e-04 - mae: 0.0088 - val_loss: 4.1891e-05 - val_mae: 0.0046
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3751e-04 - mae: 0.0082 - val_loss: 1.7529e-05 - val_mae: 0.0031
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4399e-04 - mae: 0.0085 - val_loss: 6.3470e-05 - val_mae: 0.0055
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8446e-04 - mae: 0.0089 - val_loss: 1.3896e-05 - val_mae: 0.0026
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6403e-04 - mae: 0.0089 - val_loss: 1.5473e-05 - val_mae: 0.0027
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4026e-04 - mae: 0.0081 - val_loss: 3.8562e-05 - val_mae: 0.0044
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6238e-04 - mae: 0.0087 - val_loss: 1.3300e-05 - val_mae: 0.0025
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3679e-04 - mae: 0.0078 - val_loss: 1.1277e-04 - val_mae: 0.0072
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6436e-04 - mae: 0.0090 - val_loss: 3.6847e-05 - val_mae: 0.0039
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0066e-04 - mae: 0.0091 - val_loss: 2.2123e-05 - val_mae: 0.0032
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5464e-04 - mae: 0.0085 - val_loss: 1.8539e-05 - val_mae: 0.0031
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4070e-04 - mae: 0.0080 - val_loss: 1.7043e-05 - val_mae: 0.0028
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6784e-04 - mae: 0.0088 - val_loss: 2.4911e-05 - val_mae: 0.0033
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6491e-04 - mae: 0.0092 - val_loss: 1.9193e-05 - val_mae: 0.0028
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6106e-04 - mae: 0.0086 - val_loss: 2.5098e-05 - val_mae: 0.0033
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3517e-04 - mae: 0.0081 - val_loss: 2.9627e-05 - val_mae: 0.0038
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4248e-04 - mae: 0.0082 - val_loss: 1.7756e-05 - val_mae: 0.0028
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3398e-04 - mae: 0.0082 - val_loss: 1.1900e-05 - val_mae: 0.0024
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4082e-04 - mae: 0.0085 - val_loss: 1.8021e-05 - val_mae: 0.0033
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9327e-04 - mae: 0.0089 - val_loss: 7.0788e-05 - val_mae: 0.0058
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3927e-04 - mae: 0.0082 - val_loss: 1.5319e-05 - val_mae: 0.0026
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7692e-04 - mae: 0.0086 - val_loss: 1.9123e-05 - val_mae: 0.0036
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5110e-04 - mae: 0.0085 - val_loss: 1.5279e-05 - val_mae: 0.0034
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1577e-04 - mae: 0.0098 - val_loss: 1.7105e-05 - val_mae: 0.0028
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5820e-04 - mae: 0.0086 - val_loss: 1.1605e-05 - val_mae: 0.0024
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4096e-04 - mae: 0.0083 - val_loss: 1.2977e-05 - val_mae: 0.0027
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2508e-04 - mae: 0.0077 - val_loss: 1.0819e-05 - val_mae: 0.0026
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1907e-04 - mae: 0.0075 - val_loss: 2.0149e-05 - val_mae: 0.0030
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6975e-04 - mae: 0.0087 - val_loss: 1.3276e-05 - val_mae: 0.0026
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3515e-04 - mae: 0.0079 - val_loss: 1.3246e-05 - val_mae: 0.0024
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6262e-04 - mae: 0.0089 - val_loss: 1.7793e-05 - val_mae: 0.0032
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1377e-04 - mae: 0.0075 - val_loss: 2.2127e-05 - val_mae: 0.0038
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4100e-04 - mae: 0.0083 - val_loss: 1.7054e-05 - val_mae: 0.0037
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5021e-04 - mae: 0.0088 - val_loss: 3.6991e-05 - val_mae: 0.0043
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.8268e-04 - mae: 0.0087 - val_loss: 4.2201e-05 - val_mae: 0.0048
#   分量 1 最佳模型: BiLSTM
#   验证集RMSE: 0.005153
#
# 训练分量 2/5...
#   训练BiLSTM模型...
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0047 - mae: 0.0460 - val_loss: 2.8661e-06 - val_mae: 0.0016
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4066e-04 - mae: 0.0082 - val_loss: 2.4124e-06 - val_mae: 0.0014
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0240e-04 - mae: 0.0068 - val_loss: 4.0951e-06 - val_mae: 0.0019
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.3133e-05 - mae: 0.0066 - val_loss: 1.7672e-06 - val_mae: 0.0012
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.3949e-05 - mae: 0.0061 - val_loss: 8.8871e-06 - val_mae: 0.0029
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.5258e-05 - mae: 0.0058 - val_loss: 8.7254e-06 - val_mae: 0.0029
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5539e-05 - mae: 0.0058 - val_loss: 6.4775e-06 - val_mae: 0.0024
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0823e-05 - mae: 0.0057 - val_loss: 1.5765e-05 - val_mae: 0.0039
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1224e-05 - mae: 0.0054 - val_loss: 1.8981e-06 - val_mae: 0.0011
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.1060e-05 - mae: 0.0054 - val_loss: 5.0063e-06 - val_mae: 0.0022
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.9102e-05 - mae: 0.0056 - val_loss: 8.7477e-06 - val_mae: 0.0029
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.8075e-05 - mae: 0.0052 - val_loss: 8.1915e-06 - val_mae: 0.0028
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.0545e-05 - mae: 0.0048 - val_loss: 9.4609e-07 - val_mae: 7.7841e-04
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.8257e-05 - mae: 0.0048 - val_loss: 6.1317e-07 - val_mae: 6.6741e-04
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8274e-05 - mae: 0.0049 - val_loss: 4.8638e-07 - val_mae: 6.0417e-04
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3949e-05 - mae: 0.0050 - val_loss: 1.2045e-05 - val_mae: 0.0034
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.1828e-05 - mae: 0.0049 - val_loss: 2.4772e-05 - val_mae: 0.0049
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.9810e-05 - mae: 0.0055 - val_loss: 1.7144e-06 - val_mae: 0.0011
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8097e-05 - mae: 0.0046 - val_loss: 1.3199e-06 - val_mae: 9.2031e-04
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.6331e-05 - mae: 0.0051 - val_loss: 6.3650e-06 - val_mae: 0.0024
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.7595e-05 - mae: 0.0047 - val_loss: 2.8656e-06 - val_mae: 0.0016
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0911e-05 - mae: 0.0050 - val_loss: 4.2244e-06 - val_mae: 0.0020
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8384e-05 - mae: 0.0047 - val_loss: 2.8541e-05 - val_mae: 0.0053
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0142e-05 - mae: 0.0044 - val_loss: 1.1522e-05 - val_mae: 0.0033
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9000e-05 - mae: 0.0044 - val_loss: 5.4879e-06 - val_mae: 0.0022
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3773e-05 - mae: 0.0045 - val_loss: 5.8983e-06 - val_mae: 0.0023
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1410e-05 - mae: 0.0042 - val_loss: 1.0686e-05 - val_mae: 0.0032
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2762e-05 - mae: 0.0044 - val_loss: 6.1262e-07 - val_mae: 6.5754e-04
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3085e-05 - mae: 0.0044 - val_loss: 1.3851e-06 - val_mae: 0.0010
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8189e-05 - mae: 0.0041 - val_loss: 1.4070e-05 - val_mae: 0.0037
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0450e-05 - mae: 0.0044 - val_loss: 1.5106e-05 - val_mae: 0.0038
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3638e-05 - mae: 0.0040 - val_loss: 3.9183e-06 - val_mae: 0.0019
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7320e-05 - mae: 0.0041 - val_loss: 5.1395e-07 - val_mae: 6.0775e-04
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.3318e-05 - mae: 0.0040 - val_loss: 6.2857e-06 - val_mae: 0.0024
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0045e-05 - mae: 0.0042 - val_loss: 1.1352e-06 - val_mae: 8.4555e-04
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0822e-05 - mae: 0.0043 - val_loss: 5.3096e-06 - val_mae: 0.0022
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7447e-05 - mae: 0.0041 - val_loss: 1.9003e-06 - val_mae: 0.0012
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2554e-05 - mae: 0.0038 - val_loss: 8.2449e-06 - val_mae: 0.0028
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1403e-05 - mae: 0.0038 - val_loss: 1.2758e-06 - val_mae: 9.0143e-04
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2307e-05 - mae: 0.0039 - val_loss: 5.4511e-06 - val_mae: 0.0023
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6460e-05 - mae: 0.0039 - val_loss: 9.3513e-06 - val_mae: 0.0030
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.0714e-05 - mae: 0.0038 - val_loss: 3.6895e-06 - val_mae: 0.0018
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1766e-05 - mae: 0.0039 - val_loss: 5.2217e-07 - val_mae: 6.0014e-04
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5431e-05 - mae: 0.0040 - val_loss: 1.6675e-05 - val_mae: 0.0040
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.7595e-05 - mae: 0.0037 - val_loss: 1.1443e-05 - val_mae: 0.0033
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6552e-05 - mae: 0.0034 - val_loss: 2.8731e-06 - val_mae: 0.0015
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0038e-05 - mae: 0.0039 - val_loss: 5.0295e-07 - val_mae: 5.8495e-04
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4165e-05 - mae: 0.0040 - val_loss: 7.9192e-07 - val_mae: 7.1107e-04
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.8965e-05 - mae: 0.0036 - val_loss: 1.2350e-06 - val_mae: 8.8826e-04
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8447e-05 - mae: 0.0036 - val_loss: 3.0267e-06 - val_mae: 0.0016
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2661e-05 - mae: 0.0033 - val_loss: 9.4696e-06 - val_mae: 0.0030
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.9224e-05 - mae: 0.0037 - val_loss: 1.2375e-06 - val_mae: 9.3085e-04
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5628e-05 - mae: 0.0035 - val_loss: 1.7211e-06 - val_mae: 0.0011
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4227e-05 - mae: 0.0034 - val_loss: 1.0607e-05 - val_mae: 0.0032
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6370e-05 - mae: 0.0035 - val_loss: 6.4117e-06 - val_mae: 0.0024
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6985e-05 - mae: 0.0036 - val_loss: 8.8255e-06 - val_mae: 0.0029
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.9175e-05 - mae: 0.0036 - val_loss: 5.8234e-07 - val_mae: 6.3017e-04
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.0877e-05 - mae: 0.0039 - val_loss: 7.9043e-07 - val_mae: 7.1388e-04
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0263e-05 - mae: 0.0038 - val_loss: 7.4705e-07 - val_mae: 6.9282e-04
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1988e-05 - mae: 0.0032 - val_loss: 5.1405e-07 - val_mae: 5.9803e-04
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2855e-05 - mae: 0.0034 - val_loss: 1.6519e-05 - val_mae: 0.0040
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5481e-05 - mae: 0.0036 - val_loss: 1.3774e-06 - val_mae: 0.0010
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1712e-05 - mae: 0.0040 - val_loss: 7.2260e-06 - val_mae: 0.0026
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.9234e-05 - mae: 0.0039 - val_loss: 5.1830e-06 - val_mae: 0.0022
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2759e-05 - mae: 0.0034 - val_loss: 3.2386e-06 - val_mae: 0.0016
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8045e-05 - mae: 0.0030 - val_loss: 2.0073e-05 - val_mae: 0.0044
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5805e-05 - mae: 0.0037 - val_loss: 4.8262e-06 - val_mae: 0.0021
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.3048e-05 - mae: 0.0034 - val_loss: 3.8008e-06 - val_mae: 0.0018
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1743e-05 - mae: 0.0033 - val_loss: 4.1059e-06 - val_mae: 0.0019
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4644e-05 - mae: 0.0035 - val_loss: 1.7384e-05 - val_mae: 0.0041
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1243e-05 - mae: 0.0033 - val_loss: 5.7173e-06 - val_mae: 0.0023
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9826e-05 - mae: 0.0033 - val_loss: 9.5850e-06 - val_mae: 0.0030
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1982e-05 - mae: 0.0033 - val_loss: 1.2988e-06 - val_mae: 9.2488e-04
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0712e-05 - mae: 0.0033 - val_loss: 1.1615e-05 - val_mae: 0.0034
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1388e-05 - mae: 0.0033 - val_loss: 6.1162e-06 - val_mae: 0.0024
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4498e-05 - mae: 0.0036 - val_loss: 3.1419e-06 - val_mae: 0.0017
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7496e-05 - mae: 0.0030 - val_loss: 3.0076e-06 - val_mae: 0.0016
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.0197e-05 - mae: 0.0032 - val_loss: 1.2022e-06 - val_mae: 8.7980e-04
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.9282e-05 - mae: 0.0032 - val_loss: 1.0169e-06 - val_mae: 8.1102e-04
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2896e-05 - mae: 0.0036 - val_loss: 6.0429e-07 - val_mae: 6.5100e-04
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6900e-05 - mae: 0.0030 - val_loss: 8.3660e-06 - val_mae: 0.0028
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.1998e-05 - mae: 0.0033 - val_loss: 5.5010e-07 - val_mae: 6.0865e-04
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.5703e-05 - mae: 0.0037 - val_loss: 1.6794e-05 - val_mae: 0.0041
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4964e-05 - mae: 0.0036 - val_loss: 9.7115e-07 - val_mae: 7.8098e-04
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.1498e-05 - mae: 0.0035 - val_loss: 2.6234e-05 - val_mae: 0.0051
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2792e-05 - mae: 0.0035 - val_loss: 3.1326e-05 - val_mae: 0.0055
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4458e-05 - mae: 0.0037 - val_loss: 1.6622e-06 - val_mae: 0.0011
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0972e-05 - mae: 0.0034 - val_loss: 8.9314e-06 - val_mae: 0.0029
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0160e-05 - mae: 0.0032 - val_loss: 4.9427e-06 - val_mae: 0.0021
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0375e-05 - mae: 0.0033 - val_loss: 2.3923e-06 - val_mae: 0.0013
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9363e-05 - mae: 0.0033 - val_loss: 7.6928e-06 - val_mae: 0.0027
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4534e-05 - mae: 0.0037 - val_loss: 1.4293e-06 - val_mae: 0.0010
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1474e-05 - mae: 0.0034 - val_loss: 3.9768e-06 - val_mae: 0.0019
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1529e-05 - mae: 0.0033 - val_loss: 3.0078e-06 - val_mae: 0.0017
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2528e-05 - mae: 0.0042 - val_loss: 4.7768e-06 - val_mae: 0.0020
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8408e-05 - mae: 0.0033 - val_loss: 9.7444e-06 - val_mae: 0.0031
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1156e-05 - mae: 0.0034 - val_loss: 2.7891e-06 - val_mae: 0.0015
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7360e-05 - mae: 0.0040 - val_loss: 9.9056e-07 - val_mae: 8.0013e-04
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1063e-05 - mae: 0.0034 - val_loss: 3.0249e-06 - val_mae: 0.0016
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4094e-05 - mae: 0.0036 - val_loss: 3.8315e-06 - val_mae: 0.0018
#   训练GRU模型...
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 0.0069 - mae: 0.0580 - val_loss: 1.4714e-05 - val_mae: 0.0038
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4221e-04 - mae: 0.0106 - val_loss: 9.1669e-07 - val_mae: 9.4081e-04
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5420e-04 - mae: 0.0083 - val_loss: 5.2849e-06 - val_mae: 0.0023
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5365e-04 - mae: 0.0087 - val_loss: 5.6957e-06 - val_mae: 0.0024
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3324e-04 - mae: 0.0081 - val_loss: 6.0920e-07 - val_mae: 7.6506e-04
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2630e-04 - mae: 0.0077 - val_loss: 9.3345e-07 - val_mae: 9.2549e-04
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1152e-04 - mae: 0.0073 - val_loss: 1.2218e-06 - val_mae: 0.0011
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1121e-04 - mae: 0.0075 - val_loss: 7.5692e-06 - val_mae: 0.0028
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1211e-04 - mae: 0.0074 - val_loss: 4.8000e-06 - val_mae: 0.0022
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2184e-04 - mae: 0.0079 - val_loss: 2.3234e-06 - val_mae: 0.0015
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.1682e-05 - mae: 0.0067 - val_loss: 1.0952e-05 - val_mae: 0.0033
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.7159e-05 - mae: 0.0066 - val_loss: 5.0539e-06 - val_mae: 0.0022
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0997e-04 - mae: 0.0074 - val_loss: 3.1787e-08 - val_mae: 1.5184e-04
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.8528e-05 - mae: 0.0061 - val_loss: 1.8771e-07 - val_mae: 4.0614e-04
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.6377e-05 - mae: 0.0066 - val_loss: 1.1274e-05 - val_mae: 0.0034
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.5879e-05 - mae: 0.0070 - val_loss: 3.5528e-06 - val_mae: 0.0019
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.5147e-05 - mae: 0.0064 - val_loss: 3.7688e-06 - val_mae: 0.0019
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.8778e-05 - mae: 0.0058 - val_loss: 3.9689e-07 - val_mae: 5.9402e-04
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.0701e-05 - mae: 0.0060 - val_loss: 1.0538e-05 - val_mae: 0.0032
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.0583e-05 - mae: 0.0068 - val_loss: 2.0297e-06 - val_mae: 0.0014
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.9959e-05 - mae: 0.0058 - val_loss: 7.1571e-07 - val_mae: 8.4542e-04
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.3983e-05 - mae: 0.0053 - val_loss: 3.8741e-06 - val_mae: 0.0020
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.2678e-05 - mae: 0.0060 - val_loss: 6.6913e-06 - val_mae: 0.0026
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.1700e-05 - mae: 0.0062 - val_loss: 1.7475e-07 - val_mae: 3.6552e-04
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.3578e-05 - mae: 0.0057 - val_loss: 3.8185e-06 - val_mae: 0.0019
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.2899e-05 - mae: 0.0056 - val_loss: 1.3104e-08 - val_mae: 1.1136e-04
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3097e-05 - mae: 0.0053 - val_loss: 8.5783e-07 - val_mae: 8.9683e-04
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.5379e-05 - mae: 0.0055 - val_loss: 1.6316e-06 - val_mae: 0.0013
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.2738e-05 - mae: 0.0052 - val_loss: 8.1206e-07 - val_mae: 9.0070e-04
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.8202e-05 - mae: 0.0055 - val_loss: 4.3202e-07 - val_mae: 6.4252e-04
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.5198e-05 - mae: 0.0050 - val_loss: 7.7842e-06 - val_mae: 0.0028
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0320e-05 - mae: 0.0051 - val_loss: 1.5814e-05 - val_mae: 0.0040
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1689e-05 - mae: 0.0050 - val_loss: 1.8173e-06 - val_mae: 0.0013
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.5732e-05 - mae: 0.0051 - val_loss: 1.5857e-05 - val_mae: 0.0040
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.9852e-05 - mae: 0.0055 - val_loss: 5.4263e-07 - val_mae: 7.2416e-04
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.1582e-05 - mae: 0.0048 - val_loss: 1.1695e-06 - val_mae: 0.0011
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0721e-05 - mae: 0.0049 - val_loss: 3.8794e-06 - val_mae: 0.0020
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1226e-05 - mae: 0.0061 - val_loss: 2.7274e-06 - val_mae: 0.0016
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.8828e-05 - mae: 0.0047 - val_loss: 1.0753e-06 - val_mae: 0.0010
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6384e-05 - mae: 0.0046 - val_loss: 2.8733e-08 - val_mae: 1.6730e-04
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4047e-05 - mae: 0.0049 - val_loss: 9.2015e-08 - val_mae: 2.9193e-04
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5019e-05 - mae: 0.0047 - val_loss: 3.2492e-07 - val_mae: 5.6094e-04
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3209e-05 - mae: 0.0046 - val_loss: 6.9973e-07 - val_mae: 8.3104e-04
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1524e-05 - mae: 0.0052 - val_loss: 1.1976e-06 - val_mae: 0.0011
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0161e-05 - mae: 0.0049 - val_loss: 1.5891e-06 - val_mae: 0.0013
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1213e-05 - mae: 0.0047 - val_loss: 2.8111e-07 - val_mae: 5.1917e-04
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4411e-05 - mae: 0.0047 - val_loss: 1.2249e-05 - val_mae: 0.0035
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1899e-05 - mae: 0.0047 - val_loss: 4.4541e-08 - val_mae: 1.6263e-04
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6004e-05 - mae: 0.0042 - val_loss: 6.1549e-08 - val_mae: 2.2912e-04
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4987e-05 - mae: 0.0042 - val_loss: 2.8216e-06 - val_mae: 0.0017
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6747e-05 - mae: 0.0043 - val_loss: 1.5821e-06 - val_mae: 0.0013
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.2860e-05 - mae: 0.0045 - val_loss: 9.5033e-07 - val_mae: 9.7393e-04
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4731e-05 - mae: 0.0043 - val_loss: 4.7299e-06 - val_mae: 0.0022
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7736e-05 - mae: 0.0045 - val_loss: 1.9927e-06 - val_mae: 0.0014
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2145e-05 - mae: 0.0045 - val_loss: 7.5844e-06 - val_mae: 0.0028
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8271e-05 - mae: 0.0043 - val_loss: 1.0814e-06 - val_mae: 0.0010
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2209e-05 - mae: 0.0047 - val_loss: 1.4724e-07 - val_mae: 3.6890e-04
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6218e-05 - mae: 0.0043 - val_loss: 1.0711e-06 - val_mae: 0.0010
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9421e-05 - mae: 0.0052 - val_loss: 3.4513e-06 - val_mae: 0.0019
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3903e-05 - mae: 0.0055 - val_loss: 6.1328e-06 - val_mae: 0.0025
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5142e-05 - mae: 0.0042 - val_loss: 9.6748e-06 - val_mae: 0.0031
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8179e-05 - mae: 0.0045 - val_loss: 2.2480e-06 - val_mae: 0.0015
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6133e-05 - mae: 0.0044 - val_loss: 6.4394e-06 - val_mae: 0.0025
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6766e-05 - mae: 0.0044 - val_loss: 2.5648e-06 - val_mae: 0.0016
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0512e-05 - mae: 0.0052 - val_loss: 1.6436e-08 - val_mae: 1.0438e-04
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9269e-05 - mae: 0.0046 - val_loss: 4.6612e-06 - val_mae: 0.0022
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5472e-05 - mae: 0.0044 - val_loss: 1.4122e-06 - val_mae: 0.0012
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.5153e-05 - mae: 0.0044 - val_loss: 4.6197e-07 - val_mae: 6.5300e-04
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8734e-05 - mae: 0.0045 - val_loss: 1.3571e-05 - val_mae: 0.0037
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7112e-05 - mae: 0.0045 - val_loss: 8.7213e-06 - val_mae: 0.0030
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7056e-05 - mae: 0.0045 - val_loss: 3.6303e-06 - val_mae: 0.0019
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.2498e-05 - mae: 0.0042 - val_loss: 3.2231e-06 - val_mae: 0.0018
# ...
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.2178e-06 - mae: 0.0016 - val_loss: 1.1262e-06 - val_mae: 7.3988e-04
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.7949e-06 - mae: 0.0011 - val_loss: 1.5470e-06 - val_mae: 0.0010
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.6844e-06 - mae: 0.0010 - val_loss: 1.3204e-06 - val_mae: 7.1448e-04
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.8932e-06 - mae: 0.0015 - val_loss: 1.3093e-06 - val_mae: 9.1184e-04
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8668e-06 - mae: 0.0013 - val_loss: 1.1182e-06 - val_mae: 7.9630e-04
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6104e-06 - mae: 0.0010 - val_loss: 1.1513e-06 - val_mae: 5.9263e-04
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0193e-06 - mae: 0.0012 - val_loss: 7.4989e-07 - val_mae: 4.7890e-04
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1494e-06 - mae: 0.0013 - val_loss: 1.5643e-06 - val_mae: 0.0011
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.2528e-06 - mae: 0.0011 - val_loss: 1.9324e-06 - val_mae: 0.0012
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7034e-06 - mae: 0.0012 - val_loss: 1.2753e-06 - val_mae: 6.5703e-04
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5726e-06 - mae: 0.0012 - val_loss: 7.7427e-07 - val_mae: 5.9340e-04
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.7198e-06 - mae: 0.0012 - val_loss: 1.7049e-06 - val_mae: 0.0011
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6607e-06 - mae: 0.0011 - val_loss: 1.3097e-06 - val_mae: 9.4448e-04
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2786e-06 - mae: 0.0012 - val_loss: 1.3483e-06 - val_mae: 9.8324e-04
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1755e-06 - mae: 0.0013 - val_loss: 8.8165e-07 - val_mae: 6.2848e-04
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4616e-06 - mae: 0.0012 - val_loss: 1.1014e-06 - val_mae: 8.5131e-04
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7547e-06 - mae: 0.0012 - val_loss: 6.5352e-07 - val_mae: 4.9678e-04
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9696e-06 - mae: 0.0012 - val_loss: 8.4339e-07 - val_mae: 6.1469e-04
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2654e-06 - mae: 0.0014 - val_loss: 8.3950e-07 - val_mae: 5.7230e-04
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3765e-06 - mae: 0.0012 - val_loss: 6.6372e-07 - val_mae: 4.9387e-04
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2677e-06 - mae: 0.0011 - val_loss: 8.4925e-07 - val_mae: 6.5187e-04
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5471e-06 - mae: 0.0011 - val_loss: 8.9552e-07 - val_mae: 6.8935e-04
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8181e-06 - mae: 0.0012 - val_loss: 6.2484e-07 - val_mae: 5.1459e-04
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2000e-06 - mae: 0.0013 - val_loss: 7.6421e-07 - val_mae: 5.3381e-04
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4368e-06 - mae: 9.9332e-04 - val_loss: 1.2951e-06 - val_mae: 8.7123e-04
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3634e-06 - mae: 0.0013 - val_loss: 7.2875e-07 - val_mae: 5.3043e-04
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4088e-06 - mae: 0.0012 - val_loss: 1.2354e-06 - val_mae: 8.5916e-04
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.9100e-06 - mae: 0.0010 - val_loss: 7.7973e-07 - val_mae: 5.0698e-04
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8272e-06 - mae: 0.0012 - val_loss: 2.6578e-06 - val_mae: 0.0015
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.1506e-06 - mae: 0.0014 - val_loss: 7.8061e-07 - val_mae: 4.8204e-04
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4198e-06 - mae: 9.2900e-04 - val_loss: 8.2591e-07 - val_mae: 6.9058e-04
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8367e-06 - mae: 9.7442e-04 - val_loss: 7.6657e-07 - val_mae: 6.1604e-04
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.1333e-06 - mae: 0.0011 - val_loss: 9.6712e-07 - val_mae: 7.1694e-04
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4242e-06 - mae: 0.0013 - val_loss: 9.7949e-07 - val_mae: 7.8436e-04
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.2815e-06 - mae: 0.0010 - val_loss: 1.0287e-06 - val_mae: 8.2970e-04
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.0070e-06 - mae: 9.9064e-04 - val_loss: 5.8958e-07 - val_mae: 4.3327e-04
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7424e-06 - mae: 0.0013 - val_loss: 8.0413e-07 - val_mae: 5.1852e-04
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.0350e-06 - mae: 0.0010 - val_loss: 9.8287e-07 - val_mae: 7.2804e-04
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7007e-06 - mae: 0.0010 - val_loss: 6.7714e-07 - val_mae: 4.6067e-04
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.9467e-06 - mae: 9.7173e-04 - val_loss: 9.7642e-07 - val_mae: 5.7504e-04
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9137e-06 - mae: 0.0011 - val_loss: 1.7390e-06 - val_mae: 0.0011
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3552e-06 - mae: 0.0012 - val_loss: 1.8575e-06 - val_mae: 0.0012
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.7840e-06 - mae: 0.0013 - val_loss: 6.5943e-07 - val_mae: 4.8938e-04
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3764e-06 - mae: 9.8950e-04 - val_loss: 7.0283e-07 - val_mae: 5.0139e-04
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4394e-06 - mae: 9.5376e-04 - val_loss: 8.3048e-07 - val_mae: 7.0987e-04
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0761e-06 - mae: 9.1001e-04 - val_loss: 8.0803e-07 - val_mae: 6.3076e-04
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0273e-06 - mae: 0.0012 - val_loss: 1.5147e-06 - val_mae: 0.0011
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2134e-06 - mae: 0.0011 - val_loss: 1.4191e-06 - val_mae: 9.5575e-04
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.8473e-06 - mae: 0.0011 - val_loss: 1.3767e-06 - val_mae: 0.0010
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7171e-06 - mae: 0.0010 - val_loss: 1.5620e-06 - val_mae: 9.3989e-04
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.1188e-06 - mae: 0.0012 - val_loss: 9.9287e-07 - val_mae: 7.0899e-04
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6533e-06 - mae: 0.0012 - val_loss: 6.4195e-07 - val_mae: 5.3843e-04
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.4213e-06 - mae: 0.0011 - val_loss: 8.2851e-07 - val_mae: 5.7612e-04
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0223e-06 - mae: 0.0012 - val_loss: 1.8977e-06 - val_mae: 0.0012
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7156e-06 - mae: 0.0012 - val_loss: 1.5010e-06 - val_mae: 0.0011
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.2056e-06 - mae: 0.0012 - val_loss: 6.9228e-07 - val_mae: 5.3420e-04
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5771e-06 - mae: 9.4129e-04 - val_loss: 6.2488e-07 - val_mae: 5.2440e-04
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1833e-06 - mae: 8.7701e-04 - val_loss: 5.9843e-07 - val_mae: 4.4491e-04
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7983e-06 - mae: 9.4595e-04 - val_loss: 6.8520e-07 - val_mae: 4.9662e-04
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4362e-06 - mae: 0.0011 - val_loss: 6.1728e-07 - val_mae: 5.5651e-04
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1467e-06 - mae: 0.0011 - val_loss: 5.9772e-07 - val_mae: 4.1924e-04
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.4876e-06 - mae: 0.0011 - val_loss: 7.6519e-07 - val_mae: 6.0822e-04
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.9588e-06 - mae: 0.0011 - val_loss: 7.2037e-07 - val_mae: 5.8793e-04
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.3459e-06 - mae: 0.0010 - val_loss: 6.4008e-07 - val_mae: 5.6338e-04
#   训练GRU模型...
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 45ms/step - loss: 2.3722e-04 - mae: 0.0063 - val_loss: 2.8441e-05 - val_mae: 0.0042
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.3524e-05 - mae: 0.0037 - val_loss: 9.9242e-06 - val_mae: 0.0014
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.3437e-05 - mae: 0.0031 - val_loss: 2.1689e-05 - val_mae: 0.0043
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7955e-05 - mae: 0.0029 - val_loss: 7.8020e-06 - val_mae: 0.0023
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2677e-05 - mae: 0.0020 - val_loss: 1.2596e-05 - val_mae: 0.0032
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3675e-05 - mae: 0.0027 - val_loss: 3.0006e-06 - val_mae: 9.3500e-04
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.1355e-06 - mae: 0.0015 - val_loss: 2.8016e-06 - val_mae: 8.4622e-04
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0796e-05 - mae: 0.0017 - val_loss: 8.0397e-06 - val_mae: 0.0024
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.4680e-06 - mae: 0.0017 - val_loss: 2.8967e-06 - val_mae: 0.0011
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2877e-05 - mae: 0.0017 - val_loss: 2.0059e-06 - val_mae: 7.7954e-04
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1423e-05 - mae: 0.0018 - val_loss: 7.1131e-06 - val_mae: 0.0025
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1869e-05 - mae: 0.0019 - val_loss: 7.3681e-06 - val_mae: 0.0024
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.3858e-06 - mae: 0.0019 - val_loss: 1.8138e-06 - val_mae: 9.8846e-04
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.8274e-06 - mae: 0.0013 - val_loss: 5.1753e-06 - val_mae: 0.0021
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.6691e-06 - mae: 0.0017 - val_loss: 2.8579e-06 - val_mae: 0.0015
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.1814e-06 - mae: 0.0017 - val_loss: 1.7506e-06 - val_mae: 0.0011
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.9887e-06 - mae: 0.0013 - val_loss: 1.7122e-06 - val_mae: 8.6216e-04
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0259e-06 - mae: 0.0014 - val_loss: 1.1569e-06 - val_mae: 5.9534e-04
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.9506e-06 - mae: 0.0014 - val_loss: 1.9411e-06 - val_mae: 0.0012
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.5593e-06 - mae: 0.0016 - val_loss: 1.4943e-06 - val_mae: 9.2016e-04
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5109e-06 - mae: 0.0013 - val_loss: 1.9700e-06 - val_mae: 0.0012
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4707e-06 - mae: 0.0011 - val_loss: 1.2089e-06 - val_mae: 6.8385e-04
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.0021e-06 - mae: 0.0010 - val_loss: 9.7714e-07 - val_mae: 5.1869e-04
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.2323e-06 - mae: 0.0012 - val_loss: 2.2189e-06 - val_mae: 0.0013
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4450e-06 - mae: 0.0012 - val_loss: 7.6158e-07 - val_mae: 5.4466e-04
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0931e-06 - mae: 8.9158e-04 - val_loss: 1.0581e-06 - val_mae: 6.2194e-04
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.8618e-06 - mae: 0.0010 - val_loss: 2.0738e-06 - val_mae: 0.0012
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6424e-06 - mae: 0.0014 - val_loss: 6.4716e-07 - val_mae: 4.6169e-04
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.0045e-06 - mae: 0.0011 - val_loss: 7.1605e-06 - val_mae: 0.0025
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.6172e-06 - mae: 0.0016 - val_loss: 8.7643e-07 - val_mae: 6.6215e-04
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7206e-06 - mae: 0.0011 - val_loss: 1.5065e-06 - val_mae: 0.0011
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9099e-06 - mae: 0.0012 - val_loss: 9.4262e-07 - val_mae: 6.6324e-04
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6520e-06 - mae: 0.0012 - val_loss: 9.1024e-07 - val_mae: 6.3805e-04
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.3290e-06 - mae: 0.0012 - val_loss: 6.2882e-07 - val_mae: 4.7102e-04
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5460e-06 - mae: 9.2660e-04 - val_loss: 1.1121e-06 - val_mae: 7.3867e-04
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1473e-06 - mae: 0.0012 - val_loss: 6.7095e-07 - val_mae: 4.4804e-04
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7241e-06 - mae: 0.0012 - val_loss: 8.8062e-07 - val_mae: 5.4189e-04
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.9467e-06 - mae: 0.0012 - val_loss: 8.6735e-07 - val_mae: 5.5922e-04
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4192e-06 - mae: 0.0011 - val_loss: 3.3977e-06 - val_mae: 0.0017
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3565e-06 - mae: 0.0015 - val_loss: 7.4351e-07 - val_mae: 6.2817e-04
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4526e-06 - mae: 9.6319e-04 - val_loss: 7.6276e-07 - val_mae: 5.4269e-04
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8898e-06 - mae: 0.0012 - val_loss: 1.1256e-06 - val_mae: 8.7398e-04
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4815e-06 - mae: 0.0010 - val_loss: 1.2608e-06 - val_mae: 9.2350e-04
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8066e-06 - mae: 0.0014 - val_loss: 7.2565e-07 - val_mae: 6.1071e-04
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4182e-06 - mae: 0.0012 - val_loss: 7.7588e-07 - val_mae: 5.4689e-04
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9828e-06 - mae: 0.0012 - val_loss: 1.1254e-06 - val_mae: 7.8113e-04
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.1324e-06 - mae: 0.0012 - val_loss: 7.2347e-07 - val_mae: 5.3091e-04
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.3278e-06 - mae: 0.0013 - val_loss: 1.1086e-06 - val_mae: 8.8724e-04
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4464e-06 - mae: 0.0011 - val_loss: 8.6501e-07 - val_mae: 7.1079e-04
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7598e-06 - mae: 0.0012 - val_loss: 8.9860e-07 - val_mae: 7.2067e-04
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3623e-06 - mae: 0.0010 - val_loss: 6.8301e-07 - val_mae: 4.9148e-04
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0018e-06 - mae: 9.0004e-04 - val_loss: 7.3757e-07 - val_mae: 6.5584e-04
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7785e-06 - mae: 8.2088e-04 - val_loss: 4.9151e-07 - val_mae: 4.3052e-04
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.9324e-06 - mae: 0.0011 - val_loss: 2.6871e-06 - val_mae: 0.0015
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.1812e-06 - mae: 0.0012 - val_loss: 2.2121e-06 - val_mae: 0.0014
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7745e-06 - mae: 0.0012 - val_loss: 9.4508e-07 - val_mae: 8.0354e-04
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4704e-06 - mae: 9.3018e-04 - val_loss: 2.0424e-06 - val_mae: 0.0013
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4279e-06 - mae: 0.0010 - val_loss: 3.2780e-06 - val_mae: 0.0017
# Epoch 59/100
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.2260e-06 - mae: 0.0015

# %%
import numpy as np
import pandas as pd
from PyEMD import CEEMDAN
from vmdpy import VMD
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Dropout
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial Unicode MS', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# --------------------------- 1. 数据加载与预处理 ---------------------------
def load_data(filepath):
    df = pd.read_excel(filepath, sheet_name='datas')
    df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', dayfirst=True)
    df.set_index('date', inplace=True)
    full_date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    return df.reindex(full_date_range).ffill()

df = load_data('C:/Users/18320/Desktop/carbon-Yunnan.xlsx')
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.values)

# --------------------------- 2. 固定参数设置 ---------------------------
# CEEMDAN参数
CEEMDAN_EPSILON = 0.01
CEEMDAN_ETA = 0.05

# VMD参数（用于高频模态二次分解）
VMD_ALPHA = 1200
VMD_K = 3

# BiLSTM参数
LSTM_UNITS = 128
GRU_UNITS = 128
DROPOUT_RATE = 0.3
LEARNING_RATE = 0.001
N_STEPS = 24
EPOCHS = 100
BATCH_SIZE = 32

# 聚类参数
N_CLUSTERS = 3

# --------------------------- 3. 分解函数 ---------------------------
def ceemdan_decomposition(signal, epsilon, eta):
    """CEEMDAN分解"""
    ceemdan = CEEMDAN(epsilon=epsilon, 
                     eta=eta,
                     noise_strength=0.05,
                     ensemble_size=50)
    imfs = ceemdan.ceemdan(signal.flatten())
    return np.array(imfs).T

def vmd_decomposition(signal, alpha, K):
    """VMD分解"""
    imfs, _, _ = VMD(signal.flatten(), alpha=alpha, K=K, tau=0, DC=0, init=1, tol=1e-6)
    return imfs

# --------------------------- 4. IMF聚类函数 ---------------------------
def cluster_imfs(imfs, n_clusters=3):
    """基于频率特性对IMF进行聚类"""
    n_imfs = imfs.shape[1]
    features = []
    
    for i in range(n_imfs):
        imf = imfs[:, i]
        # 计算过零率（高频特征）
        zero_crossings = np.sum(np.diff(np.sign(imf)) != 0) / len(imf)
        
        # 计算能量（幅值特征）
        energy = np.sum(imf**2)
        
        # 计算自相关第一个零点（周期性特征）
        autocorr = np.correlate(imf, imf, mode='full')
        autocorr = autocorr[len(autocorr)//2:]
        first_zero = np.argmax(autocorr < 0.1 * autocorr[0]) if np.any(autocorr < 0.1 * autocorr[0]) else len(autocorr)-1
        
        features.append([zero_crossings, energy, first_zero])
    
    features = np.array(features)
    
    # 标准化特征
    feature_scaler = MinMaxScaler()
    normalized_features = feature_scaler.fit_transform(features)
    
    # K-means聚类
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(normalized_features)
    
    return labels, features, kmeans

# --------------------------- 5. IMF合并函数（新增）---------------------------
def merge_imfs_by_cluster(imfs, labels):
    """将同一聚类内的IMF合并为一个分量"""
    n_clusters = np.max(labels) + 1
    merged_components = []
    
    for cluster_id in range(n_clusters):
        # 找到属于当前聚类的所有IMF索引
        cluster_indices = np.where(labels == cluster_id)[0]
        
        if len(cluster_indices) > 0:
            # 将同一聚类内的IMF相加合并
            merged_component = np.sum(imfs[:, cluster_indices], axis=1)
            merged_components.append(merged_component)
    
    return np.array(merged_components).T

# --------------------------- 6. 高频模态VMD二次分解 ---------------------------
def refine_high_frequency_components(merged_components, labels, original_imfs, vmd_alpha, vmd_k):
    """对高频聚类分量进行VMD二次分解"""
    # 找到高频聚类（过零率最高的聚类）
    cluster_features = []
    for i in range(np.max(labels)+1):
        cluster_indices = np.where(labels == i)[0]
        if len(cluster_indices) > 0:
            # 使用原始IMF计算过零率
            avg_zero_crossing = np.mean([np.sum(np.diff(np.sign(original_imfs[:, idx])) != 0) / len(original_imfs) for idx in cluster_indices])
            cluster_features.append(avg_zero_crossing)
        else:
            cluster_features.append(0)
    
    high_freq_cluster = np.argmax(cluster_features)
    
    # 对高频聚类分量进行VMD二次分解
    refined_components = []
    for i in range(merged_components.shape[1]):
        if i == high_freq_cluster:
            # 对高频分量进行VMD分解
            vmd_imfs = vmd_decomposition(merged_components[:, i], vmd_alpha, vmd_k)
            refined_components.extend(vmd_imfs)
        else:
            # 非高频分量保持不变
            refined_components.append(merged_components[:, i])
    
    return np.array(refined_components).T, high_freq_cluster

# --------------------------- 7. 评估函数 ---------------------------
def evaluate(y_true, y_pred):
    """评估函数，计算多个指标"""
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_true - y_pred) / np.maximum(np.abs(y_true), 1e-10))) * 100
    r2 = r2_score(y_true, y_pred)
    
    return {
        'MSE': mse,
        'MAE': mae,
        'RMSE': rmse,
        'MAPE': mape,
        'R2': r2
    }

# --------------------------- 8. 模型定义函数 ---------------------------
def create_bilstm_model(input_shape, units, dropout_rate, learning_rate):
    """创建BiLSTM模型"""
    model = Sequential([
        Bidirectional(LSTM(units, return_sequences=False), 
                     input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                 loss='mse',
                 metrics=['mae'])
    return model

def create_gru_model(input_shape, units, dropout_rate, learning_rate):
    """创建GRU模型"""
    model = Sequential([
        GRU(units, return_sequences=False, input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                 loss='mse',
                 metrics=['mae'])
    return model

# --------------------------- 9. 模型选择函数 ---------------------------
def select_best_model(y_true, y_pred_bilstm, y_pred_gru, metric='RMSE'):
    """根据评估指标选择最佳模型"""
    metrics_bilstm = evaluate(y_true, y_pred_bilstm)
    metrics_gru = evaluate(y_true, y_pred_gru)
    
    if metric == 'RMSE':
        if metrics_bilstm['RMSE'] <= metrics_gru['RMSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'MSE':
        if metrics_bilstm['MSE'] <= metrics_gru['MSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'MAE':
        if metrics_bilstm['MAE'] <= metrics_gru['MAE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'R2':
        if metrics_bilstm['R2'] >= metrics_gru['R2']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    else:
        # 默认使用RMSE
        if metrics_bilstm['RMSE'] <= metrics_gru['RMSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru

# --------------------------- 10. 主程序 ---------------------------
# 使用固定参数进行分解和聚类
print("开始CEEMDAN分解...")
imfs = ceemdan_decomposition(scaled_data, CEEMDAN_EPSILON, CEEMDAN_ETA)
print(f"CEEMDAN分解完成，得到 {imfs.shape[1]} 个IMF分量")

print("开始K-means聚类...")
labels, features, kmeans = cluster_imfs(imfs, n_clusters=N_CLUSTERS)
print("K-means聚类完成")

# 新增：合并同一聚类的IMF
print("开始合并同一聚类的IMF...")
merged_components = merge_imfs_by_cluster(imfs, labels)
print(f"IMF合并完成，得到 {merged_components.shape[1]} 个聚类分量")

print("开始高频模态VMD二次分解...")
components, high_freq_cluster = refine_high_frequency_components(
    merged_components, labels, imfs, VMD_ALPHA, VMD_K
)
print(f"VMD二次分解完成，最终得到 {components.shape[1]} 个分量")

# 输出聚类结果分析
print("\nIMF聚类分析:")
for i in range(N_CLUSTERS):
    cluster_imf_indices = np.where(labels == i)[0]
    print(f"聚类 {i+1} 包含 {len(cluster_imf_indices)} 个IMF: {cluster_imf_indices}")
    if len(cluster_imf_indices) > 0:
        print(f"  平均过零率: {np.mean(features[cluster_imf_indices, 0]):.4f}")
        print(f"  平均能量: {np.mean(features[cluster_imf_indices, 1]):.4f}")
        print(f"  平均周期: {np.mean(features[cluster_imf_indices, 2]):.2f}")

print(f"\n高频聚类（进行VMD二次分解）: 聚类 {high_freq_cluster+1}")

# 准备数据
X, y = [], []
for i in range(N_STEPS, len(components)):
    X.append(components[i-N_STEPS:i])
    y.append(components[i])
X, y = np.array(X), np.array(y)

# --------------------------- 修改：按日期划分训练集和测试集 ---------------------------
print("\n按日期划分训练集和测试集...")

# 获取日期索引
dates = df.index[N_STEPS:]  # 注意：由于使用了N_STEPS，实际日期从第N_STEPS+1天开始

# 定义训练集和测试集的日期范围 - 修改为秋季（9月-11月）
train_start_date = pd.to_datetime('2019-01-01')
train_end_date = pd.to_datetime('2024-08-31')  # 训练到夏季结束
test_start_date = pd.to_datetime('2024-09-01')  # 秋季开始
test_end_date = pd.to_datetime('2024-11-30')    # 秋季结束

# 创建训练集和测试集的掩码
train_mask = (dates >= train_start_date) & (dates <= train_end_date)
test_mask = (dates >= test_start_date) & (dates <= test_end_date)

# 应用掩码划分数据
X_train, X_test = X[train_mask], X[test_mask]
y_train, y_test = y[train_mask], y[test_mask]

print(f"数据划分完成:")
print(f"训练集日期范围: {dates[train_mask].min().strftime('%Y-%m-%d')} 到 {dates[train_mask].max().strftime('%Y-%m-%d')}")
print(f"测试集日期范围: {dates[test_mask].min().strftime('%Y-%m-%d')} 到 {dates[test_mask].max().strftime('%Y-%m-%d')}")
print(f"训练集样本数: {X_train.shape[0]}")
print(f"测试集样本数: {X_test.shape[0]}")
print(f"每个样本的时间步长: {X_train.shape[1]}")
print(f"分量数量: {X_train.shape[2]}")

# 检查是否有数据
if X_train.shape[0] == 0:
    raise ValueError("训练集为空，请检查日期范围设置")
if X_test.shape[0] == 0:
    raise ValueError("测试集为空，请检查日期范围设置")

# --------------------------- 11. 模型训练与选择 ---------------------------
# 为每个分量训练BiLSTM和GRU模型，并选择最佳模型
print("\n开始训练模型并进行模型选择...")
best_models = []  # 存储每个分量的最佳模型
best_model_names = []  # 存储每个分量最佳模型的名称
train_histories_bilstm = []
train_histories_gru = []
component_validation_results = []

for i in range(components.shape[1]):
    print(f"\n训练分量 {i+1}/{components.shape[1]}...")
    
    # 准备数据
    X_component = X_train[:, :, i].reshape(X_train.shape[0], X_train.shape[1], 1)
    y_component = y_train[:, i].reshape(-1, 1)
    
    # 训练BiLSTM模型
    print(f"  训练BiLSTM模型...")
    bilstm_model = create_bilstm_model(
        input_shape=(N_STEPS, 1), 
        units=LSTM_UNITS, 
        dropout_rate=DROPOUT_RATE, 
        learning_rate=LEARNING_RATE
    )
    
    history_bilstm = bilstm_model.fit(
        X_component, y_component, 
        epochs=EPOCHS, 
        batch_size=BATCH_SIZE, 
        verbose=1,
        validation_split=0.2
    )
    train_histories_bilstm.append(history_bilstm)
    
    # 训练GRU模型
    print(f"  训练GRU模型...")
    gru_model = create_gru_model(
        input_shape=(N_STEPS, 1), 
        units=GRU_UNITS, 
        dropout_rate=DROPOUT_RATE, 
        learning_rate=LEARNING_RATE
    )
    
    history_gru = gru_model.fit(
        X_component, y_component, 
        epochs=EPOCHS, 
        batch_size=BATCH_SIZE, 
        verbose=1,
        validation_split=0.2
    )
    train_histories_gru.append(history_gru)
    
    # 在验证集上评估两个模型
    X_val_component = X_component[int(0.8 * len(X_component)):]
    y_val_component = y_component[int(0.8 * len(y_component)):]
    
    y_pred_bilstm = bilstm_model.predict(X_val_component, verbose=0).flatten()
    y_pred_gru = gru_model.predict(X_val_component, verbose=0).flatten()
    
    # 选择最佳模型
    best_model_name, best_metrics, _ = select_best_model(
        y_val_component.flatten(), 
        y_pred_bilstm, 
        y_pred_gru, 
        metric='RMSE'
    )
    
    if best_model_name == 'BiLSTM':
        best_models.append(bilstm_model)
    else:
        best_models.append(gru_model)
    
    best_model_names.append(best_model_name)
    
    component_validation_results.append({
        'component': i+1,
        'best_model': best_model_name,
        'validation_RMSE': best_metrics['RMSE'],
        'validation_MAE': best_metrics['MAE'],
        'validation_R2': best_metrics['R2']
    })
    
    print(f"  分量 {i+1} 最佳模型: {best_model_name}")
    print(f"  验证集RMSE: {best_metrics['RMSE']:.6f}")

print("\n所有分量模型训练和选择完成")

# 输出模型选择结果
print("\n各分量模型选择结果:")
for result in component_validation_results:
    print(f"分量 {result['component']}: 最佳模型={result['best_model']}, "
          f"验证集RMSE={result['validation_RMSE']:.6f}, "
          f"验证集R²={result['validation_R2']:.4f}")

# --------------------------- 12. 预测与评估 ---------------------------
def predict_components(models, X_data):
    """使用各个模型预测各分量"""
    predictions = []
    for i, model in enumerate(models):
        X_component = X_data[:, :, i].reshape(X_data.shape[0], X_data.shape[1], 1)
        pred = model.predict(X_component, verbose=0)
        predictions.append(pred.flatten())
    return np.array(predictions).T

print("\n开始预测...")
# 预测各分量
y_pred_components = predict_components(best_models, X_test)

# 同时分别用BiLSTM和GRU预测以进行对比
y_pred_components_bilstm = predict_components(
    [create_bilstm_model((N_STEPS, 1), LSTM_UNITS, DROPOUT_RATE, LEARNING_RATE) 
     for _ in range(components.shape[1])], X_test
)
y_pred_components_gru = predict_components(
    [create_gru_model((N_STEPS, 1), GRU_UNITS, DROPOUT_RATE, LEARNING_RATE) 
     for _ in range(components.shape[1])], X_test
)

# --------------------------- 新增：对每个分量进行单独评估 ---------------------------
print("\n各分量预测效果评估:")
component_metrics = []
component_comparison = []

for i in range(components.shape[1]):
    # 获取当前分量的真实值和预测值
    y_true_component = y_test[:, i]
    y_pred_component = y_pred_components[:, i]
    y_pred_bilstm_component = y_pred_components_bilstm[:, i]
    y_pred_gru_component = y_pred_components_gru[:, i]
    
    # 计算评估指标
    metrics_component = evaluate(y_true_component, y_pred_component)
    metrics_bilstm = evaluate(y_true_component, y_pred_bilstm_component)
    metrics_gru = evaluate(y_true_component, y_pred_gru_component)
    
    component_metrics.append(metrics_component)
    
    # 记录模型比较结果
    component_comparison.append({
        'component': i+1,
        'best_model': best_model_names[i],
        'BiLSTM_RMSE': metrics_bilstm['RMSE'],
        'GRU_RMSE': metrics_gru['RMSE'],
        'Selected_RMSE': metrics_component['RMSE'],
        'improvement_vs_BiLSTM': (metrics_bilstm['RMSE'] - metrics_component['RMSE']) / metrics_bilstm['RMSE'] * 100,
        'improvement_vs_GRU': (metrics_gru['RMSE'] - metrics_component['RMSE']) / metrics_gru['RMSE'] * 100
    })
    
    print(f"\n分量 {i+1} 预测效果 (最佳模型: {best_model_names[i]}):")
    print(f"  RMSE: {metrics_component['RMSE']:.6f}")
    print(f"  MAE: {metrics_component['MAE']:.6f}")
    print(f"  R²: {metrics_component['R2']:.4f}")
    print(f"  对比 - BiLSTM RMSE: {metrics_bilstm['RMSE']:.6f}, GRU RMSE: {metrics_gru['RMSE']:.6f}")

# 组合分量预测结果
y_pred_combined = np.sum(y_pred_components, axis=1)

# 反归一化
y_pred_final = scaler.inverse_transform(y_pred_combined.reshape(-1, 1)).flatten()
y_true_combined = np.sum(y_test, axis=1)
y_true_final = scaler.inverse_transform(y_true_combined.reshape(-1, 1)).flatten()

# 评估最终预测结果
metrics = evaluate(y_true_final, y_pred_final)
print("\n最终模型评估:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
# Out:
# 开始CEEMDAN分解...
# CEEMDAN分解完成，得到 8 个IMF分量
# 开始K-means聚类...
# K-means聚类完成
# 开始合并同一聚类的IMF...
# IMF合并完成，得到 3 个聚类分量
# 开始高频模态VMD二次分解...
# VMD二次分解完成，最终得到 5 个分量
#
# IMF聚类分析:
# 聚类 1 包含 6 个IMF: [1 2 3 4 5 6]
#   平均过零率: 0.0767
#   平均能量: 8.4315
#   平均周期: 64.33
# 聚类 2 包含 1 个IMF: [7]
#   平均过零率: 0.0000
#   平均能量: 93.2216
#   平均周期: 2082.00
# 聚类 3 包含 1 个IMF: [0]
#   平均过零率: 0.5068
#   平均能量: 0.9036
#   平均周期: 2.00
#
# 高频聚类（进行VMD二次分解）: 聚类 3
#
# 按日期划分训练集和测试集...
# 数据划分完成:
# 训练集日期范围: 2019-01-25 到 2024-08-31
# 测试集日期范围: 2024-09-01 到 2024-11-30
# 训练集样本数: 2046
# 测试集样本数: 91
# 每个样本的时间步长: 24
# 分量数量: 5
#
# 开始训练模型并进行模型选择...
#
# 训练分量 1/5...
#   训练BiLSTM模型...
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0070 - mae: 0.0464 - val_loss: 0.0012 - val_mae: 0.0216
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0027 - mae: 0.0289 - val_loss: 8.8125e-04 - val_mae: 0.0186
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024 - mae: 0.0260 - val_loss: 9.2056e-04 - val_mae: 0.0241
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - mae: 0.0243 - val_loss: 6.0086e-04 - val_mae: 0.0175
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0015 - mae: 0.0218 - val_loss: 4.6639e-04 - val_mae: 0.0130
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0013 - mae: 0.0201 - val_loss: 4.0997e-04 - val_mae: 0.0131
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0014 - mae: 0.0201 - val_loss: 3.7764e-04 - val_mae: 0.0133
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0011 - mae: 0.0193 - val_loss: 3.2205e-04 - val_mae: 0.0127
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.9597e-04 - mae: 0.0168 - val_loss: 3.3131e-04 - val_mae: 0.0141
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.4014e-04 - mae: 0.0166 - val_loss: 2.3952e-04 - val_mae: 0.0097
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.8116e-04 - mae: 0.0170 - val_loss: 2.2331e-04 - val_mae: 0.0093
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.6422e-04 - mae: 0.0163 - val_loss: 2.1351e-04 - val_mae: 0.0103
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.9318e-04 - mae: 0.0184 - val_loss: 1.8131e-04 - val_mae: 0.0083
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.4612e-04 - mae: 0.0138 - val_loss: 1.7706e-04 - val_mae: 0.0087
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5071e-04 - mae: 0.0140 - val_loss: 1.5726e-04 - val_mae: 0.0076
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.4577e-04 - mae: 0.0143 - val_loss: 1.4810e-04 - val_mae: 0.0074
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6229e-04 - mae: 0.0129 - val_loss: 1.3154e-04 - val_mae: 0.0072
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3807e-04 - mae: 0.0129 - val_loss: 1.5038e-04 - val_mae: 0.0087
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.8244e-04 - mae: 0.0137 - val_loss: 1.2823e-04 - val_mae: 0.0072
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2760e-04 - mae: 0.0124 - val_loss: 1.1911e-04 - val_mae: 0.0079
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0446e-04 - mae: 0.0129 - val_loss: 1.0848e-04 - val_mae: 0.0064
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3777e-04 - mae: 0.0129 - val_loss: 1.2664e-04 - val_mae: 0.0084
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.6109e-04 - mae: 0.0128 - val_loss: 1.0161e-04 - val_mae: 0.0071
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9627e-04 - mae: 0.0122 - val_loss: 1.5713e-04 - val_mae: 0.0104
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1803e-04 - mae: 0.0114 - val_loss: 1.4770e-04 - val_mae: 0.0106
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.3118e-04 - mae: 0.0118 - val_loss: 8.9632e-05 - val_mae: 0.0059
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4503e-04 - mae: 0.0118 - val_loss: 1.0781e-04 - val_mae: 0.0087
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9498e-04 - mae: 0.0119 - val_loss: 8.0352e-05 - val_mae: 0.0060
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1362e-04 - mae: 0.0115 - val_loss: 7.8587e-05 - val_mae: 0.0059
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.1605e-04 - mae: 0.0113 - val_loss: 8.1528e-05 - val_mae: 0.0068
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6435e-04 - mae: 0.0108 - val_loss: 7.0288e-05 - val_mae: 0.0056
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7937e-04 - mae: 0.0104 - val_loss: 7.9044e-05 - val_mae: 0.0057
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9954e-04 - mae: 0.0105 - val_loss: 7.8267e-05 - val_mae: 0.0069
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8137e-04 - mae: 0.0109 - val_loss: 6.7944e-05 - val_mae: 0.0056
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3341e-04 - mae: 0.0101 - val_loss: 7.0224e-05 - val_mae: 0.0062
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.6766e-04 - mae: 0.0101 - val_loss: 5.8533e-05 - val_mae: 0.0047
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5677e-04 - mae: 0.0103 - val_loss: 5.8631e-05 - val_mae: 0.0053
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6707e-04 - mae: 0.0103 - val_loss: 6.2131e-05 - val_mae: 0.0050
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3303e-04 - mae: 0.0100 - val_loss: 7.2234e-05 - val_mae: 0.0060
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3770e-04 - mae: 0.0100 - val_loss: 6.8340e-05 - val_mae: 0.0059
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4069e-04 - mae: 0.0107 - val_loss: 7.3065e-05 - val_mae: 0.0073
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4735e-04 - mae: 0.0099 - val_loss: 5.3070e-05 - val_mae: 0.0045
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6962e-04 - mae: 0.0099 - val_loss: 5.5238e-05 - val_mae: 0.0048
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2175e-04 - mae: 0.0097 - val_loss: 5.7197e-05 - val_mae: 0.0056
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0258e-04 - mae: 0.0112 - val_loss: 6.7736e-05 - val_mae: 0.0063
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9049e-04 - mae: 0.0109 - val_loss: 5.2567e-05 - val_mae: 0.0053
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1634e-04 - mae: 0.0096 - val_loss: 6.8901e-05 - val_mae: 0.0067
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0822e-04 - mae: 0.0092 - val_loss: 5.4602e-05 - val_mae: 0.0055
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9889e-04 - mae: 0.0092 - val_loss: 5.7636e-05 - val_mae: 0.0058
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2781e-04 - mae: 0.0094 - val_loss: 4.4101e-05 - val_mae: 0.0045
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0108e-04 - mae: 0.0095 - val_loss: 6.0415e-05 - val_mae: 0.0064
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8705e-04 - mae: 0.0093 - val_loss: 4.6211e-05 - val_mae: 0.0043
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1998e-04 - mae: 0.0095 - val_loss: 4.6273e-05 - val_mae: 0.0045
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9554e-04 - mae: 0.0091 - val_loss: 5.8256e-05 - val_mae: 0.0055
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0004e-04 - mae: 0.0093 - val_loss: 4.3129e-05 - val_mae: 0.0048
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1967e-04 - mae: 0.0095 - val_loss: 4.1689e-05 - val_mae: 0.0041
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1904e-04 - mae: 0.0096 - val_loss: 4.2843e-05 - val_mae: 0.0046
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3392e-04 - mae: 0.0098 - val_loss: 4.1495e-05 - val_mae: 0.0042
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1433e-04 - mae: 0.0093 - val_loss: 3.6784e-05 - val_mae: 0.0042
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7720e-04 - mae: 0.0089 - val_loss: 4.3987e-05 - val_mae: 0.0050
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7199e-04 - mae: 0.0090 - val_loss: 4.7405e-05 - val_mae: 0.0048
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7212e-04 - mae: 0.0087 - val_loss: 3.8067e-05 - val_mae: 0.0043
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8698e-04 - mae: 0.0087 - val_loss: 3.8845e-05 - val_mae: 0.0046
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8429e-04 - mae: 0.0088 - val_loss: 4.1886e-05 - val_mae: 0.0040
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7285e-04 - mae: 0.0089 - val_loss: 3.1259e-05 - val_mae: 0.0036
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0523e-04 - mae: 0.0094 - val_loss: 3.7110e-05 - val_mae: 0.0038
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0157e-04 - mae: 0.0097 - val_loss: 3.1348e-05 - val_mae: 0.0036
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3341e-04 - mae: 0.0094 - val_loss: 3.0586e-05 - val_mae: 0.0035
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6685e-04 - mae: 0.0088 - val_loss: 3.5489e-05 - val_mae: 0.0042
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6649e-04 - mae: 0.0084 - val_loss: 3.1531e-05 - val_mae: 0.0037
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7616e-04 - mae: 0.0087 - val_loss: 3.4610e-05 - val_mae: 0.0044
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7093e-04 - mae: 0.0086 - val_loss: 3.3642e-05 - val_mae: 0.0041
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9935e-04 - mae: 0.0093 - val_loss: 3.4960e-05 - val_mae: 0.0046
# Epoch 74/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7968e-04 - mae: 0.0090 - val_loss: 4.6814e-05 - val_mae: 0.0048
# Epoch 75/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1067e-04 - mae: 0.0094 - val_loss: 2.7598e-05 - val_mae: 0.0034
# Epoch 76/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5679e-04 - mae: 0.0085 - val_loss: 2.6592e-05 - val_mae: 0.0036
# Epoch 77/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9258e-04 - mae: 0.0090 - val_loss: 2.9184e-05 - val_mae: 0.0038
# Epoch 78/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9619e-04 - mae: 0.0089 - val_loss: 2.7670e-05 - val_mae: 0.0039
# Epoch 79/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7503e-04 - mae: 0.0086 - val_loss: 2.9087e-05 - val_mae: 0.0036
# Epoch 80/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8179e-04 - mae: 0.0090 - val_loss: 3.2739e-05 - val_mae: 0.0037
# Epoch 81/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2957e-04 - mae: 0.0076 - val_loss: 3.4447e-05 - val_mae: 0.0044
# Epoch 82/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5548e-04 - mae: 0.0082 - val_loss: 2.6743e-05 - val_mae: 0.0037
# Epoch 83/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1263e-04 - mae: 0.0091 - val_loss: 2.9329e-05 - val_mae: 0.0042
# Epoch 84/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8830e-04 - mae: 0.0096 - val_loss: 3.8090e-05 - val_mae: 0.0047
# Epoch 85/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5768e-04 - mae: 0.0083 - val_loss: 3.3602e-05 - val_mae: 0.0050
# Epoch 86/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3556e-04 - mae: 0.0080 - val_loss: 2.9444e-05 - val_mae: 0.0044
# Epoch 87/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9193e-04 - mae: 0.0091 - val_loss: 3.1473e-05 - val_mae: 0.0039
# Epoch 88/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1179e-04 - mae: 0.0095 - val_loss: 2.3982e-05 - val_mae: 0.0038
# Epoch 89/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7836e-04 - mae: 0.0085 - val_loss: 2.3938e-05 - val_mae: 0.0032
# Epoch 90/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0186e-04 - mae: 0.0092 - val_loss: 3.3275e-05 - val_mae: 0.0036
# Epoch 91/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9314e-04 - mae: 0.0092 - val_loss: 2.6192e-05 - val_mae: 0.0038
# Epoch 92/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6280e-04 - mae: 0.0080 - val_loss: 2.5984e-05 - val_mae: 0.0034
# Epoch 93/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6133e-04 - mae: 0.0082 - val_loss: 3.5720e-05 - val_mae: 0.0041
# Epoch 94/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5764e-04 - mae: 0.0082 - val_loss: 2.7641e-05 - val_mae: 0.0038
# Epoch 95/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6469e-04 - mae: 0.0084 - val_loss: 2.8160e-05 - val_mae: 0.0040
# Epoch 96/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7103e-04 - mae: 0.0083 - val_loss: 3.7146e-05 - val_mae: 0.0053
# Epoch 97/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7828e-04 - mae: 0.0087 - val_loss: 2.0847e-05 - val_mae: 0.0036
# Epoch 98/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4492e-04 - mae: 0.0080 - val_loss: 2.9471e-05 - val_mae: 0.0043
# Epoch 99/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3955e-04 - mae: 0.0078 - val_loss: 2.1437e-05 - val_mae: 0.0036
# Epoch 100/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5305e-04 - mae: 0.0080 - val_loss: 2.3252e-05 - val_mae: 0.0030
#   训练GRU模型...
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0063 - mae: 0.0505 - val_loss: 5.7826e-04 - val_mae: 0.0190
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0015 - mae: 0.0220 - val_loss: 3.8165e-04 - val_mae: 0.0116
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.4783e-04 - mae: 0.0188 - val_loss: 3.4874e-04 - val_mae: 0.0113
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.1244e-04 - mae: 0.0186 - val_loss: 2.2114e-04 - val_mae: 0.0106
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6005e-04 - mae: 0.0157 - val_loss: 2.1646e-04 - val_mae: 0.0094
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8580e-04 - mae: 0.0161 - val_loss: 1.3638e-04 - val_mae: 0.0072
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4448e-04 - mae: 0.0130 - val_loss: 1.6017e-04 - val_mae: 0.0087
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.4261e-04 - mae: 0.0156 - val_loss: 1.1508e-04 - val_mae: 0.0071
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5305e-04 - mae: 0.0129 - val_loss: 2.1167e-04 - val_mae: 0.0130
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9227e-04 - mae: 0.0127 - val_loss: 7.8024e-05 - val_mae: 0.0055
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2716e-04 - mae: 0.0116 - val_loss: 8.3839e-05 - val_mae: 0.0063
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2822e-04 - mae: 0.0116 - val_loss: 6.8176e-05 - val_mae: 0.0056
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9240e-04 - mae: 0.0109 - val_loss: 6.2830e-05 - val_mae: 0.0051
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1444e-04 - mae: 0.0110 - val_loss: 7.5841e-05 - val_mae: 0.0062
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7898e-04 - mae: 0.0105 - val_loss: 5.3365e-05 - val_mae: 0.0046
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2154e-04 - mae: 0.0095 - val_loss: 5.1479e-05 - val_mae: 0.0047
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6291e-04 - mae: 0.0100 - val_loss: 5.1130e-05 - val_mae: 0.0049
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3653e-04 - mae: 0.0099 - val_loss: 6.3979e-05 - val_mae: 0.0049
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3559e-04 - mae: 0.0096 - val_loss: 4.9081e-05 - val_mae: 0.0049
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6171e-04 - mae: 0.0102 - val_loss: 5.3121e-05 - val_mae: 0.0058
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9007e-04 - mae: 0.0090 - val_loss: 4.9861e-05 - val_mae: 0.0048
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3951e-04 - mae: 0.0097 - val_loss: 5.8620e-05 - val_mae: 0.0062
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7089e-04 - mae: 0.0107 - val_loss: 4.2088e-05 - val_mae: 0.0044
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9484e-04 - mae: 0.0088 - val_loss: 4.0795e-05 - val_mae: 0.0044
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1324e-04 - mae: 0.0093 - val_loss: 4.9851e-05 - val_mae: 0.0043
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1340e-04 - mae: 0.0093 - val_loss: 3.6525e-05 - val_mae: 0.0042
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7056e-04 - mae: 0.0087 - val_loss: 3.6225e-05 - val_mae: 0.0038
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9998e-04 - mae: 0.0091 - val_loss: 4.2684e-05 - val_mae: 0.0042
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4037e-04 - mae: 0.0097 - val_loss: 6.0067e-05 - val_mae: 0.0058
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4788e-04 - mae: 0.0101 - val_loss: 3.0117e-05 - val_mae: 0.0036
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1496e-04 - mae: 0.0099 - val_loss: 3.4033e-05 - val_mae: 0.0040
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9293e-04 - mae: 0.0091 - val_loss: 3.0364e-05 - val_mae: 0.0044
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8988e-04 - mae: 0.0089 - val_loss: 4.6080e-05 - val_mae: 0.0042
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2427e-04 - mae: 0.0099 - val_loss: 4.3703e-05 - val_mae: 0.0053
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1345e-04 - mae: 0.0097 - val_loss: 3.0068e-05 - val_mae: 0.0042
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1186e-04 - mae: 0.0089 - val_loss: 3.2724e-05 - val_mae: 0.0049
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3874e-04 - mae: 0.0082 - val_loss: 2.5203e-05 - val_mae: 0.0036
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7376e-04 - mae: 0.0086 - val_loss: 4.8095e-05 - val_mae: 0.0059
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0336e-04 - mae: 0.0095 - val_loss: 2.9373e-05 - val_mae: 0.0040
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7761e-04 - mae: 0.0088 - val_loss: 2.5038e-05 - val_mae: 0.0041
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6421e-04 - mae: 0.0086 - val_loss: 2.5813e-05 - val_mae: 0.0038
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7870e-04 - mae: 0.0090 - val_loss: 3.2311e-05 - val_mae: 0.0048
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5582e-04 - mae: 0.0083 - val_loss: 2.0065e-05 - val_mae: 0.0034
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5457e-04 - mae: 0.0080 - val_loss: 4.3245e-05 - val_mae: 0.0058
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5369e-04 - mae: 0.0084 - val_loss: 2.9196e-05 - val_mae: 0.0045
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4089e-04 - mae: 0.0079 - val_loss: 2.2431e-05 - val_mae: 0.0030
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4129e-04 - mae: 0.0080 - val_loss: 1.9957e-05 - val_mae: 0.0035
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4532e-04 - mae: 0.0082 - val_loss: 1.5565e-05 - val_mae: 0.0025
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4439e-04 - mae: 0.0084 - val_loss: 2.1097e-05 - val_mae: 0.0033
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2233e-04 - mae: 0.0075 - val_loss: 4.5137e-05 - val_mae: 0.0061
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9350e-04 - mae: 0.0093 - val_loss: 6.4059e-05 - val_mae: 0.0074
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6191e-04 - mae: 0.0084 - val_loss: 1.5352e-05 - val_mae: 0.0028
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2576e-04 - mae: 0.0075 - val_loss: 5.4641e-05 - val_mae: 0.0062
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7837e-04 - mae: 0.0089 - val_loss: 3.3162e-05 - val_mae: 0.0035
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4594e-04 - mae: 0.0083 - val_loss: 3.1776e-05 - val_mae: 0.0051
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6507e-04 - mae: 0.0082 - val_loss: 1.0474e-04 - val_mae: 0.0096
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9839e-04 - mae: 0.0100 - val_loss: 1.8817e-05 - val_mae: 0.0036
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3359e-04 - mae: 0.0076 - val_loss: 2.1205e-05 - val_mae: 0.0038
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4258e-04 - mae: 0.0082 - val_loss: 1.7793e-05 - val_mae: 0.0035
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3958e-04 - mae: 0.0077 - val_loss: 1.2795e-05 - val_mae: 0.0024
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2672e-04 - mae: 0.0076 - val_loss: 1.7457e-05 - val_mae: 0.0031
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9146e-04 - mae: 0.0087 - val_loss: 1.4877e-05 - val_mae: 0.0025
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5287e-04 - mae: 0.0086 - val_loss: 1.9991e-05 - val_mae: 0.0038
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5971e-04 - mae: 0.0084 - val_loss: 3.2371e-05 - val_mae: 0.0041
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5319e-04 - mae: 0.0079 - val_loss: 1.2043e-05 - val_mae: 0.0024
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4724e-04 - mae: 0.0082 - val_loss: 2.2128e-05 - val_mae: 0.0033
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3275e-04 - mae: 0.0078 - val_loss: 1.7182e-05 - val_mae: 0.0036
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5586e-04 - mae: 0.0085 - val_loss: 1.5212e-05 - val_mae: 0.0032
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4345e-04 - mae: 0.0083 - val_loss: 1.4031e-05 - val_mae: 0.0023
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2240e-04 - mae: 0.0077 - val_loss: 2.8118e-05 - val_mae: 0.0048
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3614e-04 - mae: 0.0079 - val_loss: 1.0737e-05 - val_mae: 0.0023
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2662e-04 - mae: 0.0075 - val_loss: 3.1286e-05 - val_mae: 0.0051
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3023e-04 - mae: 0.0074 - val_loss: 1.0254e-05 - val_mae: 0.0022
# Epoch 74/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3138e-04 - mae: 0.0076 - val_loss: 1.0368e-05 - val_mae: 0.0023
# Epoch 75/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2158e-04 - mae: 0.0076 - val_loss: 2.0380e-05 - val_mae: 0.0028
# Epoch 76/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3288e-04 - mae: 0.0078 - val_loss: 2.1983e-05 - val_mae: 0.0042
# Epoch 77/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2445e-04 - mae: 0.0077 - val_loss: 1.8571e-05 - val_mae: 0.0038
# Epoch 78/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0938e-04 - mae: 0.0073 - val_loss: 9.5309e-06 - val_mae: 0.0021
# Epoch 79/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4423e-04 - mae: 0.0085 - val_loss: 1.0476e-05 - val_mae: 0.0021
# Epoch 80/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5805e-04 - mae: 0.0084 - val_loss: 2.4931e-05 - val_mae: 0.0043
# Epoch 81/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3614e-04 - mae: 0.0080 - val_loss: 1.4750e-05 - val_mae: 0.0032
# Epoch 82/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1913e-04 - mae: 0.0073 - val_loss: 1.7583e-05 - val_mae: 0.0035
# Epoch 83/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4297e-04 - mae: 0.0087 - val_loss: 1.2829e-05 - val_mae: 0.0026
# Epoch 84/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3577e-04 - mae: 0.0080 - val_loss: 1.0997e-05 - val_mae: 0.0026
# Epoch 85/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2248e-04 - mae: 0.0074 - val_loss: 9.9214e-06 - val_mae: 0.0023
# Epoch 86/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4786e-04 - mae: 0.0081 - val_loss: 1.6965e-05 - val_mae: 0.0026
# Epoch 87/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3960e-04 - mae: 0.0077 - val_loss: 1.4980e-05 - val_mae: 0.0027
# Epoch 88/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6726e-04 - mae: 0.0109 - val_loss: 3.0335e-05 - val_mae: 0.0049
# Epoch 89/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6489e-04 - mae: 0.0084 - val_loss: 3.9145e-05 - val_mae: 0.0049
# Epoch 90/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8085e-04 - mae: 0.0091 - val_loss: 1.0877e-05 - val_mae: 0.0022
# Epoch 91/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5048e-04 - mae: 0.0084 - val_loss: 3.0186e-05 - val_mae: 0.0050
# Epoch 92/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5057e-04 - mae: 0.0079 - val_loss: 1.9327e-05 - val_mae: 0.0040
# Epoch 93/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1868e-04 - mae: 0.0074 - val_loss: 2.2564e-05 - val_mae: 0.0043
# Epoch 94/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4072e-04 - mae: 0.0079 - val_loss: 1.5083e-05 - val_mae: 0.0029
# Epoch 95/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5564e-04 - mae: 0.0084 - val_loss: 8.4590e-06 - val_mae: 0.0020
# Epoch 96/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6514e-04 - mae: 0.0084 - val_loss: 9.4607e-06 - val_mae: 0.0020
# Epoch 97/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0405e-04 - mae: 0.0070 - val_loss: 9.9491e-06 - val_mae: 0.0020
# Epoch 98/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3810e-04 - mae: 0.0077 - val_loss: 1.0389e-05 - val_mae: 0.0026
# Epoch 99/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2294e-04 - mae: 0.0078 - val_loss: 1.0934e-05 - val_mae: 0.0023
# Epoch 100/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7237e-04 - mae: 0.0086 - val_loss: 1.1869e-05 - val_mae: 0.0023
#   分量 1 最佳模型: GRU
#   验证集RMSE: 0.003445
#
# 训练分量 2/5...
#   训练BiLSTM模型...
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0066 - mae: 0.0524 - val_loss: 4.1489e-05 - val_mae: 0.0064
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4883e-04 - mae: 0.0108 - val_loss: 2.0780e-05 - val_mae: 0.0046
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6523e-04 - mae: 0.0090 - val_loss: 4.0264e-05 - val_mae: 0.0063
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7731e-04 - mae: 0.0091 - val_loss: 4.1546e-06 - val_mae: 0.0020
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4498e-04 - mae: 0.0086 - val_loss: 4.5330e-06 - val_mae: 0.0021
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2895e-04 - mae: 0.0080 - val_loss: 2.0202e-05 - val_mae: 0.0045
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0535e-04 - mae: 0.0073 - val_loss: 5.5908e-07 - val_mae: 6.5475e-04
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1907e-04 - mae: 0.0079 - val_loss: 8.6045e-05 - val_mae: 0.0093
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0542e-04 - mae: 0.0076 - val_loss: 8.0972e-05 - val_mae: 0.0090
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.1267e-05 - mae: 0.0068 - val_loss: 1.3893e-05 - val_mae: 0.0037
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.7253e-05 - mae: 0.0071 - val_loss: 8.1729e-08 - val_mae: 2.1876e-04
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0529e-04 - mae: 0.0075 - val_loss: 1.3109e-05 - val_mae: 0.0036
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1071e-04 - mae: 0.0075 - val_loss: 2.8098e-05 - val_mae: 0.0053
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1725e-04 - mae: 0.0077 - val_loss: 1.1789e-04 - val_mae: 0.0109
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3378e-04 - mae: 0.0085 - val_loss: 6.8038e-06 - val_mae: 0.0026
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.5355e-05 - mae: 0.0068 - val_loss: 3.8569e-06 - val_mae: 0.0020
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.0423e-05 - mae: 0.0064 - val_loss: 8.4134e-06 - val_mae: 0.0029
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1167e-04 - mae: 0.0074 - val_loss: 5.4879e-05 - val_mae: 0.0074
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0259e-04 - mae: 0.0073 - val_loss: 4.4061e-05 - val_mae: 0.0066
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.6882e-05 - mae: 0.0067 - val_loss: 2.7823e-07 - val_mae: 5.2314e-04
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.0333e-05 - mae: 0.0064 - val_loss: 3.5205e-05 - val_mae: 0.0059
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9590e-05 - mae: 0.0072 - val_loss: 2.4096e-05 - val_mae: 0.0049
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.0399e-05 - mae: 0.0061 - val_loss: 8.2478e-06 - val_mae: 0.0029
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.8937e-05 - mae: 0.0070 - val_loss: 4.7604e-05 - val_mae: 0.0069
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.5261e-05 - mae: 0.0061 - val_loss: 4.3959e-05 - val_mae: 0.0066
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.0138e-05 - mae: 0.0059 - val_loss: 2.9462e-05 - val_mae: 0.0054
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.4911e-05 - mae: 0.0056 - val_loss: 8.9304e-06 - val_mae: 0.0030
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.4422e-05 - mae: 0.0062 - val_loss: 2.0337e-06 - val_mae: 0.0014
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.9509e-05 - mae: 0.0059 - val_loss: 7.1199e-05 - val_mae: 0.0084
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0816e-04 - mae: 0.0074 - val_loss: 1.6877e-05 - val_mae: 0.0041
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.3363e-05 - mae: 0.0068 - val_loss: 6.8509e-06 - val_mae: 0.0026
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.8167e-05 - mae: 0.0066 - val_loss: 1.4232e-05 - val_mae: 0.0038
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.2351e-05 - mae: 0.0053 - val_loss: 6.7815e-06 - val_mae: 0.0026
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.6063e-05 - mae: 0.0057 - val_loss: 5.8755e-06 - val_mae: 0.0024
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.2796e-05 - mae: 0.0055 - val_loss: 9.4439e-06 - val_mae: 0.0031
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5382e-05 - mae: 0.0052 - val_loss: 2.0377e-05 - val_mae: 0.0045
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.1657e-05 - mae: 0.0056 - val_loss: 1.1232e-04 - val_mae: 0.0106
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.5391e-05 - mae: 0.0062 - val_loss: 8.7025e-06 - val_mae: 0.0029
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.8386e-05 - mae: 0.0049 - val_loss: 4.3342e-05 - val_mae: 0.0066
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.9139e-05 - mae: 0.0049 - val_loss: 9.0849e-05 - val_mae: 0.0095
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.8980e-05 - mae: 0.0054 - val_loss: 5.7920e-06 - val_mae: 0.0024
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.3058e-05 - mae: 0.0050 - val_loss: 1.1227e-07 - val_mae: 2.5731e-04
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9463e-05 - mae: 0.0054 - val_loss: 1.1930e-05 - val_mae: 0.0034
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5659e-05 - mae: 0.0053 - val_loss: 6.9741e-06 - val_mae: 0.0026
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.1378e-05 - mae: 0.0050 - val_loss: 9.2010e-05 - val_mae: 0.0096
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4205e-05 - mae: 0.0053 - val_loss: 1.4975e-06 - val_mae: 0.0012
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.9357e-05 - mae: 0.0048 - val_loss: 2.1566e-05 - val_mae: 0.0046
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6450e-05 - mae: 0.0048 - val_loss: 1.9206e-05 - val_mae: 0.0044
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.2324e-05 - mae: 0.0050 - val_loss: 7.5802e-08 - val_mae: 2.4030e-04
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.9411e-05 - mae: 0.0048 - val_loss: 3.3424e-05 - val_mae: 0.0058
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8178e-05 - mae: 0.0048 - val_loss: 2.7706e-05 - val_mae: 0.0053
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7028e-05 - mae: 0.0048 - val_loss: 1.4749e-05 - val_mae: 0.0038
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4713e-05 - mae: 0.0045 - val_loss: 1.9599e-06 - val_mae: 0.0014
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.4111e-05 - mae: 0.0051 - val_loss: 2.6830e-05 - val_mae: 0.0052
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.1326e-05 - mae: 0.0050 - val_loss: 1.7768e-05 - val_mae: 0.0042
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2866e-05 - mae: 0.0046 - val_loss: 1.8074e-05 - val_mae: 0.0043
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6582e-05 - mae: 0.0042 - val_loss: 7.0746e-06 - val_mae: 0.0026
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7207e-05 - mae: 0.0043 - val_loss: 8.5840e-05 - val_mae: 0.0093
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8236e-05 - mae: 0.0049 - val_loss: 3.4190e-06 - val_mae: 0.0018
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0864e-05 - mae: 0.0044 - val_loss: 1.5710e-05 - val_mae: 0.0040
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7285e-05 - mae: 0.0042 - val_loss: 2.6221e-05 - val_mae: 0.0051
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8880e-05 - mae: 0.0044 - val_loss: 2.8268e-06 - val_mae: 0.0017
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8515e-05 - mae: 0.0043 - val_loss: 2.0935e-05 - val_mae: 0.0046
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4441e-05 - mae: 0.0044 - val_loss: 1.0873e-05 - val_mae: 0.0033
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.4515e-05 - mae: 0.0059 - val_loss: 7.5703e-06 - val_mae: 0.0027
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8759e-05 - mae: 0.0044 - val_loss: 2.4302e-05 - val_mae: 0.0049
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9938e-05 - mae: 0.0043 - val_loss: 2.1937e-05 - val_mae: 0.0047
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2095e-05 - mae: 0.0046 - val_loss: 2.7298e-06 - val_mae: 0.0017
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4816e-05 - mae: 0.0048 - val_loss: 3.9314e-05 - val_mae: 0.0063
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0851e-05 - mae: 0.0045 - val_loss: 6.6316e-06 - val_mae: 0.0026
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2053e-05 - mae: 0.0046 - val_loss: 2.7947e-05 - val_mae: 0.0053
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5163e-05 - mae: 0.0047 - val_loss: 2.8654e-05 - val_mae: 0.0054
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6723e-05 - mae: 0.0041 - val_loss: 2.0267e-05 - val_mae: 0.0045
# Epoch 74/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5617e-05 - mae: 0.0042 - val_loss: 1.7055e-05 - val_mae: 0.0041
# Epoch 75/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8412e-05 - mae: 0.0045 - val_loss: 1.6263e-05 - val_mae: 0.0040
# Epoch 76/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8491e-05 - mae: 0.0044 - val_loss: 1.0582e-05 - val_mae: 0.0033
# Epoch 77/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.3709e-05 - mae: 0.0043 - val_loss: 9.2262e-06 - val_mae: 0.0030
# Epoch 78/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2353e-05 - mae: 0.0042 - val_loss: 1.0428e-06 - val_mae: 0.0010
# Epoch 79/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4458e-05 - mae: 0.0043 - val_loss: 1.7285e-07 - val_mae: 3.2700e-04
# Epoch 80/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.3065e-05 - mae: 0.0041 - val_loss: 8.6208e-06 - val_mae: 0.0029
# Epoch 81/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7467e-05 - mae: 0.0051 - val_loss: 6.7533e-06 - val_mae: 0.0026
# Epoch 82/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2475e-05 - mae: 0.0046 - val_loss: 1.7506e-05 - val_mae: 0.0042
# Epoch 83/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4423e-05 - mae: 0.0042 - val_loss: 5.5200e-06 - val_mae: 0.0023
# Epoch 84/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2344e-05 - mae: 0.0042 - val_loss: 1.7973e-07 - val_mae: 4.2277e-04
# Epoch 85/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0851e-05 - mae: 0.0044 - val_loss: 4.5896e-05 - val_mae: 0.0068
# Epoch 86/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7412e-05 - mae: 0.0045 - val_loss: 2.9014e-05 - val_mae: 0.0054
# Epoch 87/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7332e-05 - mae: 0.0050 - val_loss: 4.7323e-05 - val_mae: 0.0069
# Epoch 88/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5526e-05 - mae: 0.0045 - val_loss: 1.3742e-05 - val_mae: 0.0037
# Epoch 89/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5698e-05 - mae: 0.0043 - val_loss: 7.6432e-07 - val_mae: 8.3884e-04
# Epoch 90/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5839e-05 - mae: 0.0043 - val_loss: 2.8251e-05 - val_mae: 0.0053
# Epoch 91/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4664e-05 - mae: 0.0044 - val_loss: 2.8773e-06 - val_mae: 0.0017
# Epoch 92/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3188e-05 - mae: 0.0050 - val_loss: 1.0877e-05 - val_mae: 0.0033
# Epoch 93/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8267e-05 - mae: 0.0044 - val_loss: 4.9147e-05 - val_mae: 0.0070
# Epoch 94/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2018e-05 - mae: 0.0047 - val_loss: 6.5454e-06 - val_mae: 0.0025
# Epoch 95/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5016e-05 - mae: 0.0044 - val_loss: 2.6607e-06 - val_mae: 0.0016
# Epoch 96/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8236e-05 - mae: 0.0045 - val_loss: 1.2133e-04 - val_mae: 0.0110
# Epoch 97/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.0013e-05 - mae: 0.0062 - val_loss: 1.0185e-07 - val_mae: 2.9742e-04
# Epoch 98/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4772e-05 - mae: 0.0043 - val_loss: 2.7927e-05 - val_mae: 0.0053
# Epoch 99/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7493e-05 - mae: 0.0044 - val_loss: 1.4510e-05 - val_mae: 0.0038
# Epoch 100/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8870e-05 - mae: 0.0040 - val_loss: 1.2976e-07 - val_mae: 2.9590e-04
#   训练GRU模型...
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0098 - mae: 0.0705 - val_loss: 2.0886e-05 - val_mae: 0.0045
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4692e-04 - mae: 0.0127 - val_loss: 4.9829e-06 - val_mae: 0.0022
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1260e-04 - mae: 0.0115 - val_loss: 7.0043e-07 - val_mae: 7.8910e-04
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0999e-04 - mae: 0.0100 - val_loss: 1.1521e-05 - val_mae: 0.0034
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1119e-04 - mae: 0.0099 - val_loss: 2.7521e-05 - val_mae: 0.0052
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9908e-04 - mae: 0.0094 - val_loss: 1.0436e-05 - val_mae: 0.0032
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7834e-04 - mae: 0.0093 - val_loss: 4.4546e-06 - val_mae: 0.0021
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8449e-04 - mae: 0.0094 - val_loss: 5.4006e-06 - val_mae: 0.0023
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6564e-04 - mae: 0.0091 - val_loss: 1.8506e-06 - val_mae: 0.0014
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6864e-04 - mae: 0.0090 - val_loss: 7.5680e-07 - val_mae: 8.6919e-04
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5980e-04 - mae: 0.0087 - val_loss: 3.9684e-05 - val_mae: 0.0063
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8078e-04 - mae: 0.0096 - val_loss: 3.3046e-06 - val_mae: 0.0018
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6689e-04 - mae: 0.0089 - val_loss: 2.1978e-06 - val_mae: 0.0015
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2773e-04 - mae: 0.0079 - val_loss: 7.1528e-05 - val_mae: 0.0085
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3701e-04 - mae: 0.0083 - val_loss: 1.2624e-06 - val_mae: 0.0010
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6157e-04 - mae: 0.0090 - val_loss: 3.4208e-07 - val_mae: 4.9530e-04
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4282e-04 - mae: 0.0081 - val_loss: 8.2638e-06 - val_mae: 0.0029
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3181e-04 - mae: 0.0078 - val_loss: 1.0085e-07 - val_mae: 3.1539e-04
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5469e-04 - mae: 0.0085 - val_loss: 3.9873e-05 - val_mae: 0.0063
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1824e-04 - mae: 0.0074 - val_loss: 1.6914e-06 - val_mae: 0.0013
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1567e-04 - mae: 0.0072 - val_loss: 6.4288e-06 - val_mae: 0.0025
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2331e-04 - mae: 0.0076 - val_loss: 3.6710e-06 - val_mae: 0.0019
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0104e-04 - mae: 0.0068 - val_loss: 3.0075e-07 - val_mae: 5.4501e-04
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0357e-04 - mae: 0.0069 - val_loss: 4.7452e-05 - val_mae: 0.0069
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3473e-04 - mae: 0.0081 - val_loss: 2.8067e-05 - val_mae: 0.0053
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1010e-04 - mae: 0.0071 - val_loss: 8.3448e-06 - val_mae: 0.0029
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2603e-04 - mae: 0.0075 - val_loss: 2.7715e-09 - val_mae: 4.5359e-05
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.9133e-05 - mae: 0.0063 - val_loss: 1.1352e-04 - val_mae: 0.0106
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5046e-04 - mae: 0.0087 - val_loss: 2.5639e-06 - val_mae: 0.0016
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2319e-05 - mae: 0.0062 - val_loss: 1.3143e-05 - val_mae: 0.0036
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1043e-04 - mae: 0.0068 - val_loss: 1.8562e-05 - val_mae: 0.0043
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0728e-05 - mae: 0.0063 - val_loss: 1.2370e-05 - val_mae: 0.0035
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1318e-04 - mae: 0.0070 - val_loss: 4.8631e-05 - val_mae: 0.0070
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3212e-05 - mae: 0.0058 - val_loss: 1.5712e-05 - val_mae: 0.0040
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.6579e-05 - mae: 0.0058 - val_loss: 1.7435e-06 - val_mae: 0.0013
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.8494e-05 - mae: 0.0062 - val_loss: 2.0534e-05 - val_mae: 0.0045
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.1738e-05 - mae: 0.0055 - val_loss: 1.1729e-05 - val_mae: 0.0034
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3713e-05 - mae: 0.0050 - val_loss: 1.4805e-05 - val_mae: 0.0038
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7359e-05 - mae: 0.0059 - val_loss: 2.7619e-06 - val_mae: 0.0017
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7563e-05 - mae: 0.0057 - val_loss: 2.3642e-05 - val_mae: 0.0049
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9308e-05 - mae: 0.0060 - val_loss: 3.1160e-05 - val_mae: 0.0056
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0429e-04 - mae: 0.0072 - val_loss: 9.4282e-07 - val_mae: 9.4088e-04
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7032e-05 - mae: 0.0053 - val_loss: 1.8567e-05 - val_mae: 0.0043
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3951e-05 - mae: 0.0051 - val_loss: 2.5549e-06 - val_mae: 0.0016
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2917e-05 - mae: 0.0046 - val_loss: 4.5835e-06 - val_mae: 0.0021
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0163e-05 - mae: 0.0055 - val_loss: 3.7950e-06 - val_mae: 0.0019
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5182e-05 - mae: 0.0047 - val_loss: 1.5559e-05 - val_mae: 0.0039
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0381e-05 - mae: 0.0053 - val_loss: 4.8736e-06 - val_mae: 0.0022
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4727e-05 - mae: 0.0056 - val_loss: 2.7480e-05 - val_mae: 0.0052
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2496e-05 - mae: 0.0057 - val_loss: 3.1370e-06 - val_mae: 0.0017
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5801e-05 - mae: 0.0051 - val_loss: 4.7930e-06 - val_mae: 0.0022
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.6659e-05 - mae: 0.0058 - val_loss: 4.0947e-06 - val_mae: 0.0020
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0365e-05 - mae: 0.0046 - val_loss: 2.5519e-06 - val_mae: 0.0016
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9009e-05 - mae: 0.0046 - val_loss: 1.6887e-05 - val_mae: 0.0041
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2310e-05 - mae: 0.0048 - val_loss: 2.1579e-05 - val_mae: 0.0046
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9760e-05 - mae: 0.0053 - val_loss: 5.6701e-08 - val_mae: 2.0621e-04
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6125e-05 - mae: 0.0047 - val_loss: 8.4758e-07 - val_mae: 8.9964e-04
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8831e-05 - mae: 0.0045 - val_loss: 5.5738e-06 - val_mae: 0.0024
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0307e-05 - mae: 0.0053 - val_loss: 2.3902e-06 - val_mae: 0.0015
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9595e-05 - mae: 0.0046 - val_loss: 5.5176e-08 - val_mae: 1.9504e-04
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1885e-05 - mae: 0.0053 - val_loss: 2.5298e-08 - val_mae: 1.3594e-04
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.8594e-05 - mae: 0.0052 - val_loss: 1.3337e-06 - val_mae: 0.0011
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9962e-05 - mae: 0.0048 - val_loss: 7.1466e-06 - val_mae: 0.0027
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2499e-05 - mae: 0.0050 - val_loss: 2.1785e-06 - val_mae: 0.0015
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3486e-05 - mae: 0.0045 - val_loss: 5.0258e-08 - val_mae: 1.9453e-04
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1516e-05 - mae: 0.0047 - val_loss: 5.6413e-06 - val_mae: 0.0023
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6526e-05 - mae: 0.0046 - val_loss: 2.0129e-07 - val_mae: 4.3449e-04
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0301e-05 - mae: 0.0049 - val_loss: 7.9287e-07 - val_mae: 8.9039e-04
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9534e-05 - mae: 0.0043 - val_loss: 3.2076e-07 - val_mae: 5.2811e-04
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9624e-05 - mae: 0.0049 - val_loss: 1.0008e-06 - val_mae: 9.8880e-04
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3205e-05 - mae: 0.0043 - val_loss: 1.6045e-05 - val_mae: 0.0040
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5242e-05 - mae: 0.0051 - val_loss: 1.2012e-05 - val_mae: 0.0035
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5709e-05 - mae: 0.0048 - val_loss: 5.8934e-06 - val_mae: 0.0024
# Epoch 74/100
# ...
# Epoch 98/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2256e-06 - mae: 9.2304e-04 - val_loss: 1.3778e-06 - val_mae: 0.0010
# Epoch 99/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2441e-06 - mae: 9.7052e-04 - val_loss: 1.7758e-06 - val_mae: 0.0012
# Epoch 100/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8290e-06 - mae: 0.0012 - val_loss: 1.0722e-06 - val_mae: 8.9679e-04
#   训练GRU模型...
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 9.9822e-05 - mae: 0.0067 - val_loss: 1.5173e-05 - val_mae: 0.0029
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7519e-05 - mae: 0.0035 - val_loss: 1.0588e-05 - val_mae: 0.0021
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4275e-05 - mae: 0.0032 - val_loss: 8.6127e-06 - val_mae: 0.0017
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9322e-05 - mae: 0.0031 - val_loss: 6.7725e-06 - val_mae: 0.0019
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2489e-05 - mae: 0.0022 - val_loss: 1.0459e-05 - val_mae: 0.0030
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.5682e-06 - mae: 0.0018 - val_loss: 3.1511e-06 - val_mae: 0.0015
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.1486e-06 - mae: 0.0014 - val_loss: 1.5956e-06 - val_mae: 9.2789e-04
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0121e-06 - mae: 0.0015 - val_loss: 2.1642e-06 - val_mae: 0.0012
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.2776e-06 - mae: 0.0013 - val_loss: 2.3108e-06 - val_mae: 0.0013
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0549e-06 - mae: 0.0012 - val_loss: 1.3167e-06 - val_mae: 7.7647e-04
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.0679e-06 - mae: 0.0013 - val_loss: 1.5552e-06 - val_mae: 9.4582e-04
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5418e-06 - mae: 0.0012 - val_loss: 1.2087e-06 - val_mae: 7.0515e-04
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.2837e-06 - mae: 0.0014 - val_loss: 2.0334e-06 - val_mae: 0.0012
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2556e-06 - mae: 0.0013 - val_loss: 2.0144e-06 - val_mae: 0.0012
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3451e-06 - mae: 0.0014 - val_loss: 2.2361e-06 - val_mae: 0.0012
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3619e-06 - mae: 0.0013 - val_loss: 1.1771e-06 - val_mae: 7.2610e-04
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3996e-06 - mae: 0.0013 - val_loss: 1.1610e-06 - val_mae: 7.3952e-04
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9137e-06 - mae: 0.0014 - val_loss: 1.0954e-06 - val_mae: 6.7709e-04
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3073e-06 - mae: 0.0013 - val_loss: 1.0774e-06 - val_mae: 6.6536e-04
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7140e-06 - mae: 0.0012 - val_loss: 1.2668e-06 - val_mae: 8.4919e-04
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9226e-06 - mae: 0.0012 - val_loss: 8.8277e-06 - val_mae: 0.0028
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7390e-06 - mae: 0.0017 - val_loss: 1.4914e-05 - val_mae: 0.0037
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1354e-05 - mae: 0.0026 - val_loss: 2.4306e-06 - val_mae: 0.0013
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7175e-06 - mae: 0.0018 - val_loss: 1.0266e-06 - val_mae: 6.2410e-04
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9582e-06 - mae: 0.0011 - val_loss: 1.1829e-06 - val_mae: 8.0002e-04
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9560e-06 - mae: 0.0013 - val_loss: 1.2950e-06 - val_mae: 8.8084e-04
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4673e-06 - mae: 0.0011 - val_loss: 8.9562e-07 - val_mae: 5.7774e-04
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2652e-06 - mae: 0.0011 - val_loss: 1.6264e-06 - val_mae: 0.0011
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5994e-06 - mae: 0.0015 - val_loss: 9.4161e-07 - val_mae: 6.7938e-04
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2647e-06 - mae: 9.8121e-04 - val_loss: 8.3804e-07 - val_mae: 5.8681e-04
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2219e-06 - mae: 0.0011 - val_loss: 1.0620e-06 - val_mae: 8.0200e-04
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0201e-06 - mae: 0.0011 - val_loss: 7.7353e-07 - val_mae: 5.8524e-04
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8144e-06 - mae: 0.0011 - val_loss: 1.0611e-06 - val_mae: 8.0895e-04
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1397e-06 - mae: 0.0012 - val_loss: 2.9453e-06 - val_mae: 0.0016
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4918e-06 - mae: 0.0014 - val_loss: 1.0482e-05 - val_mae: 0.0031
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5424e-06 - mae: 0.0017 - val_loss: 8.1234e-07 - val_mae: 6.4683e-04
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9882e-06 - mae: 9.1307e-04 - val_loss: 7.0030e-07 - val_mae: 5.5418e-04
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0947e-06 - mae: 9.0479e-04 - val_loss: 1.0662e-06 - val_mae: 8.4030e-04
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7539e-06 - mae: 0.0011 - val_loss: 6.4951e-07 - val_mae: 4.9918e-04
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9945e-06 - mae: 0.0011 - val_loss: 1.2954e-06 - val_mae: 9.6192e-04
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1582e-06 - mae: 0.0012 - val_loss: 1.2025e-06 - val_mae: 9.0763e-04
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3689e-06 - mae: 0.0012 - val_loss: 5.9540e-07 - val_mae: 4.7391e-04
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2463e-06 - mae: 0.0011 - val_loss: 6.6928e-07 - val_mae: 5.1460e-04
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6601e-06 - mae: 0.0012 - val_loss: 6.0184e-07 - val_mae: 4.7367e-04
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4132e-06 - mae: 9.9277e-04 - val_loss: 7.5876e-07 - val_mae: 6.5513e-04
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5263e-06 - mae: 0.0012 - val_loss: 6.7028e-07 - val_mae: 5.8897e-04
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8839e-06 - mae: 9.1706e-04 - val_loss: 8.1761e-07 - val_mae: 7.1473e-04
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2249e-06 - mae: 9.1141e-04 - val_loss: 6.3357e-07 - val_mae: 5.6639e-04
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1988e-06 - mae: 9.5767e-04 - val_loss: 1.6668e-06 - val_mae: 0.0011
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7311e-06 - mae: 0.0011 - val_loss: 1.1343e-06 - val_mae: 8.7515e-04
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3575e-06 - mae: 0.0010 - val_loss: 5.4012e-07 - val_mae: 4.5686e-04
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8577e-06 - mae: 9.5960e-04 - val_loss: 1.4098e-06 - val_mae: 0.0010
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6184e-06 - mae: 0.0011 - val_loss: 6.1634e-07 - val_mae: 5.5044e-04
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2184e-06 - mae: 9.3000e-04 - val_loss: 8.8355e-07 - val_mae: 7.6431e-04
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1635e-06 - mae: 9.9153e-04 - val_loss: 4.6527e-06 - val_mae: 0.0021
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9185e-06 - mae: 0.0016 - val_loss: 5.9460e-07 - val_mae: 5.4239e-04
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7573e-06 - mae: 0.0011 - val_loss: 9.1882e-07 - val_mae: 7.8281e-04
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4961e-06 - mae: 7.7795e-04 - val_loss: 5.6103e-07 - val_mae: 4.5095e-04
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0910e-06 - mae: 9.0329e-04 - val_loss: 9.4322e-07 - val_mae: 8.0529e-04
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0044e-06 - mae: 0.0010 - val_loss: 1.1075e-06 - val_mae: 8.9547e-04
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2551e-06 - mae: 0.0012 - val_loss: 5.1821e-07 - val_mae: 4.6998e-04
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5405e-06 - mae: 0.0010 - val_loss: 6.5915e-07 - val_mae: 6.0531e-04
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4948e-06 - mae: 9.7513e-04 - val_loss: 1.1020e-06 - val_mae: 8.5876e-04
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2524e-06 - mae: 0.0011 - val_loss: 7.3012e-07 - val_mae: 6.5256e-04
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3391e-06 - mae: 9.6143e-04 - val_loss: 1.1235e-06 - val_mae: 9.0840e-04
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9341e-06 - mae: 0.0011 - val_loss: 1.7130e-06 - val_mae: 0.0012
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5128e-06 - mae: 0.0011 - val_loss: 1.6604e-06 - val_mae: 0.0011
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.6819e-06 - mae: 0.0011 - val_loss: 6.0079e-07 - val_mae: 5.6623e-04
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1039e-06 - mae: 8.9479e-04 - val_loss: 5.6231e-07 - val_mae: 5.3147e-04
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6350e-06 - mae: 7.7447e-04 - val_loss: 2.3733e-06 - val_mae: 0.0014
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2901e-06 - mae: 0.0012 - val_loss: 2.2546e-06 - val_mae: 0.0014
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9231e-06 - mae: 0.0011 - val_loss: 1.4868e-06 - val_mae: 0.0011
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0372e-06 - mae: 8.9435e-04 - val_loss: 1.4974e-06 - val_mae: 0.0011
# Epoch 74/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.1104e-06 - mae: 0.0015 - val_loss: 9.3012e-07 - val_mae: 8.0416e-04
# Epoch 75/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7125e-06 - mae: 0.0011 - val_loss: 7.7691e-07 - val_mae: 7.1170e-04
# Epoch 76/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6468e-06 - mae: 8.1937e-04 - val_loss: 5.0854e-07 - val_mae: 4.3519e-04
# Epoch 77/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8606e-06 - mae: 8.0356e-04 - val_loss: 4.6769e-07 - val_mae: 4.2601e-04
# Epoch 78/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4622e-06 - mae: 9.7476e-04 - val_loss: 7.5202e-07 - val_mae: 6.3181e-04
# Epoch 79/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3371e-06 - mae: 9.8113e-04 - val_loss: 5.5671e-07 - val_mae: 5.1205e-04
# Epoch 80/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8766e-06 - mae: 8.1937e-04 - val_loss: 4.8346e-07 - val_mae: 4.4236e-04
# Epoch 81/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8637e-06 - mae: 8.8119e-04 - val_loss: 4.6171e-07 - val_mae: 4.1212e-04
# Epoch 82/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4106e-06 - mae: 9.1952e-04 - val_loss: 9.2859e-07 - val_mae: 7.8806e-04
# Epoch 83/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2703e-06 - mae: 0.0012 - val_loss: 1.1368e-06 - val_mae: 8.9529e-04
# Epoch 84/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3227e-06 - mae: 9.9930e-04 - val_loss: 5.1956e-07 - val_mae: 4.6620e-04
# Epoch 85/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0183e-06 - mae: 8.3465e-04 - val_loss: 6.6320e-07 - val_mae: 6.2993e-04
# Epoch 86/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1527e-06 - mae: 9.8188e-04 - val_loss: 5.2537e-07 - val_mae: 5.0327e-04
# Epoch 87/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6143e-06 - mae: 8.0842e-04 - val_loss: 4.7905e-07 - val_mae: 4.5786e-04
# Epoch 88/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.1596e-06 - mae: 0.0011 - val_loss: 4.6514e-07 - val_mae: 4.4308e-04
# Epoch 89/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6290e-06 - mae: 8.0566e-04 - val_loss: 5.0833e-07 - val_mae: 4.3190e-04
# Epoch 90/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1225e-06 - mae: 8.8112e-04 - val_loss: 2.0821e-06 - val_mae: 0.0013
# Epoch 91/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.2886e-06 - mae: 0.0020 - val_loss: 8.1892e-07 - val_mae: 7.2659e-04
# Epoch 92/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1784e-06 - mae: 9.1856e-04 - val_loss: 6.2296e-07 - val_mae: 4.8802e-04
# Epoch 93/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1798e-06 - mae: 8.8648e-04 - val_loss: 5.0571e-07 - val_mae: 4.7731e-04
# Epoch 94/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9751e-06 - mae: 0.0010 - val_loss: 5.8323e-07 - val_mae: 5.6766e-04
# Epoch 95/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8771e-06 - mae: 8.6166e-04 - val_loss: 5.9793e-07 - val_mae: 5.3610e-04
# Epoch 96/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1289e-06 - mae: 9.1456e-04 - val_loss: 7.9156e-07 - val_mae: 7.2907e-04
# Epoch 97/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7180e-06 - mae: 0.0011 - val_loss: 6.3372e-07 - val_mae: 6.1410e-04
# Epoch 98/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1829e-06 - mae: 9.0936e-04 - val_loss: 7.4621e-07 - val_mae: 6.8003e-04
# Epoch 99/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5264e-06 - mae: 0.0011 - val_loss: 5.7958e-07 - val_mae: 5.6159e-04
# Epoch 100/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0697e-06 - mae: 8.4173e-04 - val_loss: 5.4999e-07 - val_mae: 4.4261e-04
#   分量 5 最佳模型: GRU
#   验证集RMSE: 0.000742
#
# 所有分量模型训练和选择完成
#
# 各分量模型选择结果:
# 分量 1: 最佳模型=GRU, 验证集RMSE=0.003445, 验证集R²=0.9991
# 分量 2: 最佳模型=BiLSTM, 验证集RMSE=0.000360, 验证集R²=0.9991
# 分量 3: 最佳模型=GRU, 验证集RMSE=0.000701, 验证集R²=0.9716
# 分量 4: 最佳模型=GRU, 验证集RMSE=0.000699, 验证集R²=0.9907
# 分量 5: 最佳模型=GRU, 验证集RMSE=0.000742, 验证集R²=0.9593
#
# 开始预测...
# WARNING:tensorflow:5 out of the last 22 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E2E6F56340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 23 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E2E80BADE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# 各分量预测效果评估:
#
# 分量 1 预测效果 (最佳模型: GRU):
#   RMSE: 0.003558
#   MAE: 0.002452
#   R²: 0.9961
#   对比 - BiLSTM RMSE: 0.117850, GRU RMSE: 0.104030
#
# 分量 2 预测效果 (最佳模型: BiLSTM):
#   RMSE: 0.000034
#   MAE: 0.000028
#   R²: 0.9997
#   对比 - BiLSTM RMSE: 0.236608, GRU RMSE: 0.208931
#
# 分量 3 预测效果 (最佳模型: GRU):
#   RMSE: 0.000523
#   MAE: 0.000462
#   R²: 0.7882
#   对比 - BiLSTM RMSE: 0.001144, GRU RMSE: 0.001168
#
# 分量 4 预测效果 (最佳模型: GRU):
#   RMSE: 0.000422
#   MAE: 0.000323
#   R²: 0.9843
#   对比 - BiLSTM RMSE: 0.003381, GRU RMSE: 0.003406
#
# 分量 5 预测效果 (最佳模型: GRU):
#   RMSE: 0.000530
#   MAE: 0.000394
#   R²: 0.9779
#   对比 - BiLSTM RMSE: 0.003574, GRU RMSE: 0.003500
#
# 最终模型评估:
# MSE: 0.0000
# MAE: 0.0000
# RMSE: 0.0000
# MAPE: 1.2542
# R2: 0.9960

# %%
# --------------------------- 13. 可视化 ---------------------------
# 可视化IMF合并过程
plt.figure(figsize=(15, 12))

# 原始IMF可视化
plt.subplot(3, 1, 1)
for i in range(imfs.shape[1]):
    plt.plot(imfs[:, i] + i * 0.5, label=f'IMF{i+1}', linewidth=1)
plt.title('CEEMDAN分解的原始IMF分量')
plt.ylabel('幅值')
plt.legend()

# 聚类结果可视化（用不同颜色表示不同聚类）
plt.subplot(3, 1, 2)
colors = ['red', 'blue', 'green', 'orange', 'purple']
for i in range(imfs.shape[1]):
    cluster_color = colors[labels[i] % len(colors)]
    plt.plot(imfs[:, i] + i * 0.5, color=cluster_color, linewidth=1, label=f'聚类{labels[i]+1}' if i == 0 else "")
    if i == 0:
        plt.legend()
plt.title('IMF聚类结果（颜色表示聚类）')
plt.ylabel('幅值')

# 合并后的分量可视化
plt.subplot(3, 1, 3)
for i in range(merged_components.shape[1]):
    plt.plot(merged_components[:, i] + i * 0.8, label=f'合并分量{i+1}', linewidth=2)
plt.title('合并后的聚类分量')
plt.xlabel('时间点')
plt.ylabel('幅值')
plt.legend()

plt.tight_layout()
plt.savefig('imf_clustering_merging.png', dpi=300)
plt.show()

# 可视化各分量的预测效果
plt.figure(figsize=(15, 10))
n_components_to_plot = min(5, components.shape[1])
for i in range(n_components_to_plot):
    plt.subplot(n_components_to_plot, 1, i+1)
    plt.plot(y_test[:, i], label=f'真实分量{i+1}', linewidth=1.5)
    plt.plot(y_pred_components[:, i], label=f'预测分量{i+1}', linewidth=1.5, alpha=0.8)
    plt.legend()
    plt.ylabel(f'分量 {i+1}')

plt.xlabel('时间步')
plt.suptitle('各分量预测效果及评估指标')
plt.tight_layout()
plt.savefig('components_prediction.png', dpi=300)
plt.show()

# 可视化模型选择结果
plt.figure(figsize=(10, 6))
components_idx = list(range(1, len(best_model_names) + 1))
bilstm_count = best_model_names.count('BiLSTM')
gru_count = best_model_names.count('GRU')

plt.bar(['BiLSTM', 'GRU'], [bilstm_count, gru_count], color=['blue', 'orange'])
plt.title('各分量最佳模型选择分布')
plt.ylabel('分量数量')
for i, v in enumerate([bilstm_count, gru_count]):
    plt.text(i, v + 0.1, str(v), ha='center', va='bottom')
plt.savefig('model_selection_distribution.png', dpi=300)
plt.show()

# 可视化最终预测结果
plt.figure(figsize=(12, 6))
plt.plot(y_true_final, label='真实值', linewidth=2)
plt.plot(y_pred_final, label='预测值', linewidth=2, alpha=0.8)
plt.legend()
plt.title('碳排放预测结果 (2024年9月1日-2024年11月30日)')  # 修改为秋季
plt.xlabel('时间步')
plt.ylabel('碳排放量')
plt.grid(True, alpha=0.3)

plt.savefig('final_prediction.png', dpi=300)
plt.show()

# 可视化训练损失对比
plt.figure(figsize=(15, 10))
for i in range(min(5, len(train_histories_bilstm))):
    plt.subplot(2, 3, i+1)
    plt.plot(train_histories_bilstm[i].history['loss'], label='BiLSTM训练损失', color='blue')
    plt.plot(train_histories_bilstm[i].history['val_loss'], label='BiLSTM验证损失', color='blue', linestyle='--')
    plt.plot(train_histories_gru[i].history['loss'], label='GRU训练损失', color='orange')
    plt.plot(train_histories_gru[i].history['val_loss'], label='GRU验证损失', color='orange', linestyle='--')
    plt.title(f'分量 {i+1} 训练过程对比')
    plt.xlabel('训练轮次')
    plt.ylabel('损失值')
    plt.legend()
plt.tight_layout()
plt.savefig('training_history_comparison.png', dpi=300)
plt.show()

# --------------------------- 新增：秋季预测结果详细分析 ---------------------------
def plot_autumn_performance(dates, y_true, y_pred, autumn_start='2024-09-01', autumn_end='2024-11-30'):
    """单独可视化秋季的预测结果"""
    
    # 创建秋季掩码
    autumn_mask = (dates >= pd.Timestamp(autumn_start)) & (dates <= pd.Timestamp(autumn_end))
    
    # 提取秋季数据
    autumn_dates = dates[autumn_mask]
    autumn_true = y_true[autumn_mask]
    autumn_pred = y_pred[autumn_mask]
    
    if len(autumn_dates) == 0:
        print("警告：没有找到秋季数据，请检查日期范围")
        return
    
    # 计算秋季评估指标
    autumn_metrics = evaluate(autumn_true, autumn_pred)
    
    # 创建图表
    plt.figure(figsize=(15, 8))
    
    # 绘制秋季预测结果
    plt.plot(autumn_dates, autumn_true, label='真实值', linewidth=2.5, color='#DAA520', marker='o', markersize=4)
    plt.plot(autumn_dates, autumn_pred, label='预测值', linewidth=2.5, color='#8B4513', linestyle='--', marker='s', markersize=4)
    
    # 美化图表
    plt.title('2024年秋季碳排放预测结果 (9月-11月)', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('日期', fontsize=12)
    plt.ylabel('碳排放量', fontsize=12)
    plt.legend(fontsize=12, loc='upper right')
    plt.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 添加评估指标框
    metrics_text = (f"秋季评估指标:\n"
                   f"RMSE: {autumn_metrics['RMSE']:.4f}\n"
                   f"MAE: {autumn_metrics['MAE']:.4f}\n"
                   f"MAPE: {autumn_metrics['MAPE']:.2f}%\n"
                   f"R²: {autumn_metrics['R2']:.4f}")
    
    plt.annotate(metrics_text, xy=(0.02, 0.98), xycoords='axes fraction', 
                bbox=dict(boxstyle="round,pad=0.5", facecolor="lightyellow", alpha=0.8),
                fontsize=11, verticalalignment='top')
    
    # 添加月份分隔线
    october_start = pd.Timestamp('2024-10-01')
    november_start = pd.Timestamp('2024-11-01')
    
    if october_start in autumn_dates:
        plt.axvline(october_start, color='gray', linestyle=':', alpha=0.7, label='10月开始')
    if november_start in autumn_dates:
        plt.axvline(november_start, color='gray', linestyle=':', alpha=0.7, label='11月开始')
    
    plt.tight_layout()
    plt.savefig('autumn_prediction_detailed.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    return autumn_metrics

# --------------------------- 新增：秋季预测误差分析 ---------------------------
def analyze_autumn_errors(dates, y_true, y_pred):
    """分析秋季预测误差"""
    
    autumn_mask = (dates >= pd.Timestamp('2024-09-01')) & (dates <= pd.Timestamp('2024-11-30'))
    autumn_dates = dates[autumn_mask]
    autumn_true = y_true[autumn_mask]
    autumn_pred = y_pred[autumn_mask]
    
    # 计算绝对误差和相对误差
    absolute_errors = np.abs(autumn_true - autumn_pred)
    relative_errors = np.abs((autumn_true - autumn_pred) / np.maximum(np.abs(autumn_true), 1e-10)) * 100
    
    # 创建误差分析图
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 10))
    
    # 子图1：绝对误差
    bars1 = ax1.bar(autumn_dates, absolute_errors, alpha=0.7, color='#FF8C00', edgecolor='darkorange')
    ax1.set_title('秋季预测绝对误差分析', fontsize=14, fontweight='bold')
    ax1.set_ylabel('绝对误差', fontsize=12)
    ax1.grid(True, alpha=0.3)
    
    # 在柱状图上标注最大误差点
    max_error_idx = np.argmax(absolute_errors)
    ax1.annotate(f'最大误差: {absolute_errors[max_error_idx]:.2f}', 
                xy=(autumn_dates[max_error_idx], absolute_errors[max_error_idx]),
                xytext=(10, 10), textcoords='offset points',
                bbox=dict(boxstyle='round,pad=0.3', facecolor='red', alpha=0.3),
                arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0'))
    
    # 子图2：相对误差（百分比）
    bars2 = ax2.bar(autumn_dates, relative_errors, alpha=0.7, color='#FFD700', edgecolor='darkorange')
    ax2.set_title('秋季预测相对误差分析', fontsize=14, fontweight='bold')
    ax2.set_ylabel('相对误差 (%)', fontsize=12)
    ax2.set_xlabel('日期', fontsize=12)
    ax2.grid(True, alpha=0.3)
    
    # 设置x轴格式
    for ax in [ax1, ax2]:
        ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
        ax.xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
        plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
    
    plt.tight_layout()
    plt.savefig('autumn_error_analysis.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    # 输出误差统计
    print("\n" + "="*50)
    print("秋季预测误差统计分析")
    print("="*50)
    print(f"平均绝对误差: {np.mean(absolute_errors):.4f}")
    print(f"最大绝对误差: {np.max(absolute_errors):.4f}")
    print(f"最小绝对误差: {np.min(absolute_errors):.4f}")
    print(f"平均相对误差: {np.mean(relative_errors):.2f}%")
    print(f"最大相对误差: {np.max(relative_errors):.2f}%")
    print(f"最小相对误差: {np.min(relative_errors):.2f}%")
    
    return absolute_errors, relative_errors

# --------------------------- 新增：秋季按月份细分分析 ---------------------------
def analyze_autumn_by_month(dates, y_true, y_pred):
    """按月份分析秋季预测性能"""
    
    autumn_months = {
        '九月': (pd.Timestamp('2024-09-01'), pd.Timestamp('2024-09-30')),
        '十月': (pd.Timestamp('2024-10-01'), pd.Timestamp('2024-10-31')),
        '十一月': (pd.Timestamp('2024-11-01'), pd.Timestamp('2024-11-30'))
    }
    
    monthly_metrics = {}
    
    plt.figure(figsize=(15, 10))
    
    for i, (month_name, (start_date, end_date)) in enumerate(autumn_months.items()):
        month_mask = (dates >= start_date) & (dates <= end_date)
        month_dates = dates[month_mask]
        month_true = y_true[month_mask]
        month_pred = y_pred[month_mask]
        
        if len(month_dates) > 0:
            # 计算月度指标
            metrics = evaluate(month_true, month_pred)
            monthly_metrics[month_name] = metrics
            
            # 绘制月度子图
            plt.subplot(3, 1, i+1)
            plt.plot(month_dates, month_true, label='真实值', linewidth=2, color='#DAA520')
            plt.plot(month_dates, month_pred, label='预测值', linewidth=2, color='#8B4513', linestyle='--')
            plt.title(f'{month_name}碳排放预测', fontsize=12, fontweight='bold')
            plt.ylabel('碳排放量')
            plt.legend()
            plt.grid(True, alpha=0.3)
            
    
    plt.xlabel('日期')
    plt.suptitle('2024年秋季各月份碳排放预测分析', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.savefig('autumn_monthly_analysis.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    return monthly_metrics

# --------------------------- 执行秋季单独分析 ---------------------------
print("\n" + "="*60)
print("秋季预测结果详细分析")
print("="*60)

# 获取测试集日期
test_dates = dates[test_mask]

# 绘制秋季预测结果
autumn_metrics = plot_autumn_performance(test_dates, y_true_final, y_pred_final)

# 进行秋季误差分析
absolute_errors, relative_errors = analyze_autumn_errors(test_dates, y_true_final, y_pred_final)

# 执行月度分析
print("\n" + "="*50)
print("秋季各月份详细分析")
print("="*50)

monthly_metrics = analyze_autumn_by_month(test_dates, y_true_final, y_pred_final)

# 输出月度比较
print("\n秋季各月份预测性能比较:")
for month, metrics in monthly_metrics.items():
    print(f"\n{month}:")
    print(f"  RMSE: {metrics['RMSE']:.4f}")
    print(f"  MAE: {metrics['MAE']:.4f}")
    print(f"  MAPE: {metrics['MAPE']:.2f}%")
    print(f"  R²: {metrics['R2']:.4f}")

# 找出最佳和最差预测月份
best_month = min(monthly_metrics.items(), key=lambda x: x[1]['RMSE'])
worst_month = max(monthly_metrics.items(), key=lambda x: x[1]['RMSE'])

print(f"\n📊 秋季预测性能总结:")
print(f"  最佳预测月份: {best_month[0]} (RMSE: {best_month[1]['RMSE']:.4f})")
print(f"  最具挑战月份: {worst_month[0]} (RMSE: {worst_month[1]['RMSE']:.4f})")

# --------------------------- 新增：置信区间计算函数 ---------------------------
def calculate_prediction_intervals(y_true, y_pred, n_bootstraps=1000):
    """使用自助法计算预测置信区间"""
    residuals = y_true - y_pred
    n_samples = len(y_true)
    
    # 存储自助法采样结果
    bootstrap_predictions = []
    
    for _ in range(n_bootstraps):
        # 对残差进行有放回抽样
        bootstrap_residuals = np.random.choice(residuals, size=n_samples, replace=True)
        # 生成自助法预测值
        bootstrap_pred = y_pred + bootstrap_residuals
        bootstrap_predictions.append(bootstrap_pred)
    
    bootstrap_predictions = np.array(bootstrap_predictions)
    
    # 计算95%置信区间分位数
    lower_95 = np.percentile(bootstrap_predictions, 2.5, axis=0)
    upper_95 = np.percentile(bootstrap_predictions, 97.5, axis=0)
    
    return {
        'lower_95': lower_95,
        'upper_95': upper_95,
        'bootstrap_predictions': bootstrap_predictions
    }
# --------------------------- 图1：秋季预测结果及置信区间 ---------------------------
def plot_autumn_prediction_with_intervals(dates, y_true, y_pred, autumn_start='2024-09-01', autumn_end='2024-11-30'):
    """可视化秋季预测结果及置信区间"""
    
    # 创建秋季掩码
    autumn_mask = (dates >= pd.Timestamp(autumn_start)) & (dates <= pd.Timestamp(autumn_end))
    
    # 提取秋季数据
    autumn_dates = dates[autumn_mask]
    autumn_true = y_true[autumn_mask]
    autumn_pred = y_pred[autumn_mask]
    
    if len(autumn_dates) == 0:
        print("警告：没有找到秋季数据，请检查日期范围")
        return
    
    # 计算秋季置信区间
    autumn_intervals = calculate_prediction_intervals(autumn_true, autumn_pred)
    
    # 创建图表
    plt.figure(figsize=(16, 8))
    
    # 绘制95%置信区间
    plt.fill_between(autumn_dates, autumn_intervals['lower_95'], autumn_intervals['upper_95'], 
                     alpha=0.3, color='red', label='95% Confidence interval')
    
    # 绘制真实值和预测值
    plt.plot(autumn_dates, autumn_true, label='True value', linewidth=3, color='#DAA520', marker='o', markersize=6)
    plt.plot(autumn_dates, autumn_pred, label='Predicted value', linewidth=2, color='#8B4513', linestyle='--', marker='s', markersize=4)
    
    plt.title(' Autumn ', fontsize=24, fontweight='bold', pad=20)
    plt.xlabel('Data', fontsize=12)
    plt.ylabel('Carbon emissions', fontsize=12)
    plt.legend(fontsize=11, loc='upper right')
    plt.grid(True, alpha=0.3)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 添加评估指标
    autumn_metrics = evaluate(autumn_true, autumn_pred)
    metrics_text = (f"秋季评估指标:\n"
                   f"RMSE: {autumn_metrics['RMSE']:.4f}\n"
                   f"MAE: {autumn_metrics['MAE']:.4f}\n"
                   f"MAPE: {autumn_metrics['MAPE']:.2f}%\n"
                   f"R²: {autumn_metrics['R2']:.4f}")
    
    
    plt.tight_layout()
    plt.savefig('autumn_prediction_with_confidence_intervals.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    return autumn_intervals, autumn_metrics

# --------------------------- 图2：置信区间宽度变化 ---------------------------
def plot_confidence_interval_width(dates, y_true, y_pred, autumn_start='2024-09-01', autumn_end='2024-11-30'):
    """可视化置信区间宽度变化"""
    
    # 创建秋季掩码
    autumn_mask = (dates >= pd.Timestamp(autumn_start)) & (dates <= pd.Timestamp(autumn_end))
    
    # 提取秋季数据
    autumn_dates = dates[autumn_mask]
    autumn_true = y_true[autumn_mask]
    autumn_pred = y_pred[autumn_mask]
    
    if len(autumn_dates) == 0:
        print("警告：没有找到秋季数据，请检查日期范围")
        return
    
    # 计算秋季置信区间
    autumn_intervals = calculate_prediction_intervals(autumn_true, autumn_pred)
    
    # 创建图表
    plt.figure(figsize=(16, 8))
    
    # 计算置信区间宽度
    ci_width_95 = autumn_intervals['upper_95'] - autumn_intervals['lower_95']
    
    # 绘制置信区间宽度
    plt.plot(autumn_dates, ci_width_95, label='95% CI 宽度', linewidth=2, color='orange', alpha=0.8)
    
    # 添加平均宽度线
    mean_width = np.mean(ci_width_95)
    plt.axhline(y=mean_width, color='red', linestyle='--', alpha=0.8, 
                label=f'平均宽度: {mean_width:.4f}')
    
    plt.title('秋季碳排放预测置信区间宽度变化', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('日期', fontsize=12)
    plt.ylabel('置信区间宽度', fontsize=12)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 计算置信区间覆盖率
    coverage_95 = np.mean((autumn_true >= autumn_intervals['lower_95']) & (autumn_true <= autumn_intervals['upper_95']))
    
    # 添加统计信息
    stats_text = (f"置信区间统计:\n"
                 f"95% CI 平均宽度: {mean_width:.4f}\n"
                 f"95% CI 覆盖率: {coverage_95:.1%}\n"
                 f"宽度标准差: {np.std(ci_width_95):.4f}")
    
    plt.tight_layout()
    plt.savefig('confidence_interval_width_analysis.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    return autumn_intervals

# --------------------------- 执行秋季置信区间分析 ---------------------------
print("\n" + "="*60)
print("秋季预测置信区间分析")
print("="*60)

# 图1：秋季预测结果及置信区间
print("\n📊 生成秋季预测结果图...")
autumn_intervals, autumn_metrics_final = plot_autumn_prediction_with_intervals(test_dates, y_true_final, y_pred_final)

# 图2：置信区间宽度变化
print("\n📈 生成置信区间宽度分析图...")
autumn_intervals_2 = plot_confidence_interval_width(test_dates, y_true_final, y_pred_final)

# --------------------------- 新增：秋季预测总结 ---------------------------
print("\n" + "="*60)
print("2024年秋季碳排放预测总结")
print("="*60)

print(f"\n📊 整体预测性能:")
print(f"  RMSE: {autumn_metrics_final['RMSE']:.4f}")
print(f"  MAE: {autumn_metrics_final['MAE']:.4f}")
print(f"  MAPE: {autumn_metrics_final['MAPE']:.2f}%")
print(f"  R²: {autumn_metrics_final['R2']:.4f}")

print(f"\n📈 各月份性能对比:")
for month, metrics in monthly_metrics.items():
    print(f"  {month}: RMSE={metrics['RMSE']:.4f}, MAE={metrics['MAE']:.4f}, R²={metrics['R2']:.4f}")

print(f"\n🔍 关键发现:")
print(f"  • 最佳预测月份: {best_month[0]} (RMSE: {best_month[1]['RMSE']:.4f})")
print(f"  • 最具挑战月份: {worst_month[0]} (RMSE: {worst_month[1]['RMSE']:.4f})")

# 计算置信区间覆盖率
autumn_mask = (test_dates >= pd.Timestamp('2024-09-01')) & (test_dates <= pd.Timestamp('2024-11-30'))
autumn_dates = test_dates[autumn_mask]
autumn_true = y_true_final[autumn_mask]
autumn_pred = y_pred_final[autumn_mask]

coverage_95 = np.mean((autumn_true >= autumn_intervals['lower_95']) & (autumn_true <= autumn_intervals['upper_95']))
ci_width_mean = np.mean(autumn_intervals['upper_95'] - autumn_intervals['lower_95'])

print(f"\n📊 不确定性评估:")
print(f"  95% 置信区间覆盖率: {coverage_95:.2%} (理想值: 95%)")
print(f"  平均预测不确定性 (95% CI宽度): {ci_width_mean:.4f}")
print(f"  预测不确定性标准差: {np.std(autumn_intervals['upper_95'] - autumn_intervals['lower_95']):.4f}")

print(f"\n💡 秋季预测特点分析:")
print("  • 秋季气温适中，供暖需求减少，碳排放相对稳定")
print("  • 工业生产恢复正常，碳排放模式相对规律")
print("  • 国庆假期可能对10月份的碳排放产生短期影响")
print("  • 模型在秋季表现出良好的预测能力")

print(f"\n✅ 预测模型在2024年秋季表现出色，能够准确捕捉碳排放的季节性变化模式。")
# Out:
# ============================================================
# 秋季预测结果详细分析
# ============================================================
# ==================================================
# 秋季预测误差统计分析
# ==================================================
# 平均绝对误差: 0.0000
# 最大绝对误差: 0.0000
# 最小绝对误差: 0.0000
# 平均相对误差: 1.25%
# 最大相对误差: 5.99%
# 最小相对误差: 0.04%
#
# ==================================================
# 秋季各月份详细分析
# ==================================================
# 秋季各月份预测性能比较:
#
# 九月:
#   RMSE: 0.0000
#   MAE: 0.0000
#   MAPE: 1.22%
#   R²: 0.9297
#
# 十月:
#   RMSE: 0.0000
#   MAE: 0.0000
#   MAPE: 1.22%
#   R²: 0.9804
#
# 十一月:
#   RMSE: 0.0000
#   MAE: 0.0000
#   MAPE: 1.32%
#   R²: 0.9915
#
# 📊 秋季预测性能总结:
#   最佳预测月份: 九月 (RMSE: 0.0000)
#   最具挑战月份: 十一月 (RMSE: 0.0000)
#
# ============================================================
# 秋季预测置信区间分析
# ============================================================
#
# 📊 生成秋季预测结果图...
# 📈 生成置信区间宽度分析图...
# ============================================================
# 2024年秋季碳排放预测总结
# ============================================================
#
# 📊 整体预测性能:
#   RMSE: 0.0000
#   MAE: 0.0000
#   MAPE: 1.25%
#   R²: 0.9960
#
# 📈 各月份性能对比:
#   九月: RMSE=0.0000, MAE=0.0000, R²=0.9297
#   十月: RMSE=0.0000, MAE=0.0000, R²=0.9804
#   十一月: RMSE=0.0000, MAE=0.0000, R²=0.9915
#
# 🔍 关键发现:
#   • 最佳预测月份: 九月 (RMSE: 0.0000)
#   • 最具挑战月份: 十一月 (RMSE: 0.0000)
#
# 📊 不确定性评估:
#   95% 置信区间覆盖率: 95.60% (理想值: 95%)
#   平均预测不确定性 (95% CI宽度): 0.0000
#   预测不确定性标准差: 0.0000
#
# 💡 秋季预测特点分析:
#   • 秋季气温适中，供暖需求减少，碳排放相对稳定
#   • 工业生产恢复正常，碳排放模式相对规律
#   • 国庆假期可能对10月份的碳排放产生短期影响
#   • 模型在秋季表现出良好的预测能力
#
# ✅ 预测模型在2024年秋季表现出色，能够准确捕捉碳排放的季节性变化模式。
