# %%
import numpy as np
import pandas as pd
from PyEMD import CEEMDAN
from vmdpy import VMD
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Dropout
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial Unicode MS', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# --------------------------- 1. 数据加载与预处理 ---------------------------
def load_data(filepath):
    df = pd.read_excel(filepath, sheet_name='datas')
    df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', dayfirst=True)
    df.set_index('date', inplace=True)
    full_date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    return df.reindex(full_date_range).ffill()

df = load_data('C:/Users/18320/Desktop/carbon-Yunnan.xlsx')
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.values)

# --------------------------- 2. 固定参数设置 ---------------------------
# CEEMDAN参数
CEEMDAN_EPSILON = 0.01
CEEMDAN_ETA = 0.05

# VMD参数（用于高频模态二次分解）
VMD_ALPHA = 1200
VMD_K = 3

# BiLSTM参数
LSTM_UNITS = 128
GRU_UNITS = 128
DROPOUT_RATE = 0.3
LEARNING_RATE = 0.001
N_STEPS = 24
EPOCHS = 100
BATCH_SIZE = 32

# 聚类参数
N_CLUSTERS = 3

# --------------------------- 3. 分解函数 ---------------------------
def ceemdan_decomposition(signal, epsilon, eta):
    """CEEMDAN分解"""
    ceemdan = CEEMDAN(epsilon=epsilon, 
                     eta=eta,
                     noise_strength=0.05,
                     ensemble_size=50)
    imfs = ceemdan.ceemdan(signal.flatten())
    return np.array(imfs).T

def vmd_decomposition(signal, alpha, K):
    """VMD分解"""
    imfs, _, _ = VMD(signal.flatten(), alpha=alpha, K=K, tau=0, DC=0, init=1, tol=1e-6)
    return imfs

# --------------------------- 4. IMF聚类函数 ---------------------------
def cluster_imfs(imfs, n_clusters=3):
    """基于频率特性对IMF进行聚类"""
    n_imfs = imfs.shape[1]
    features = []
    
    for i in range(n_imfs):
        imf = imfs[:, i]
        # 计算过零率（高频特征）
        zero_crossings = np.sum(np.diff(np.sign(imf)) != 0) / len(imf)
        
        # 计算能量（幅值特征）
        energy = np.sum(imf**2)
        
        # 计算自相关第一个零点（周期性特征）
        autocorr = np.correlate(imf, imf, mode='full')
        autocorr = autocorr[len(autocorr)//2:]
        first_zero = np.argmax(autocorr < 0.1 * autocorr[0]) if np.any(autocorr < 0.1 * autocorr[0]) else len(autocorr)-1
        
        features.append([zero_crossings, energy, first_zero])
    
    features = np.array(features)
    
    # 标准化特征
    feature_scaler = MinMaxScaler()
    normalized_features = feature_scaler.fit_transform(features)
    
    # K-means聚类
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(normalized_features)
    
    return labels, features, kmeans

# --------------------------- 5. IMF合并函数（新增）---------------------------
def merge_imfs_by_cluster(imfs, labels):
    """将同一聚类内的IMF合并为一个分量"""
    n_clusters = np.max(labels) + 1
    merged_components = []
    
    for cluster_id in range(n_clusters):
        # 找到属于当前聚类的所有IMF索引
        cluster_indices = np.where(labels == cluster_id)[0]
        
        if len(cluster_indices) > 0:
            # 将同一聚类内的IMF相加合并
            merged_component = np.sum(imfs[:, cluster_indices], axis=1)
            merged_components.append(merged_component)
    
    return np.array(merged_components).T

# --------------------------- 6. 高频模态VMD二次分解 ---------------------------
def refine_high_frequency_components(merged_components, labels, original_imfs, vmd_alpha, vmd_k):
    """对高频聚类分量进行VMD二次分解"""
    # 找到高频聚类（过零率最高的聚类）
    cluster_features = []
    for i in range(np.max(labels)+1):
        cluster_indices = np.where(labels == i)[0]
        if len(cluster_indices) > 0:
            # 使用原始IMF计算过零率
            avg_zero_crossing = np.mean([np.sum(np.diff(np.sign(original_imfs[:, idx])) != 0) / len(original_imfs) for idx in cluster_indices])
            cluster_features.append(avg_zero_crossing)
        else:
            cluster_features.append(0)
    
    high_freq_cluster = np.argmax(cluster_features)
    
    # 对高频聚类分量进行VMD二次分解
    refined_components = []
    for i in range(merged_components.shape[1]):
        if i == high_freq_cluster:
            # 对高频分量进行VMD分解
            vmd_imfs = vmd_decomposition(merged_components[:, i], vmd_alpha, vmd_k)
            refined_components.extend(vmd_imfs)
        else:
            # 非高频分量保持不变
            refined_components.append(merged_components[:, i])
    
    return np.array(refined_components).T, high_freq_cluster

# --------------------------- 7. 评估函数 ---------------------------
def evaluate(y_true, y_pred):
    """评估函数，计算多个指标"""
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_true - y_pred) / np.maximum(np.abs(y_true), 1e-10))) * 100
    r2 = r2_score(y_true, y_pred)
    
    return {
        'MSE': mse,
        'MAE': mae,
        'RMSE': rmse,
        'MAPE': mape,
        'R2': r2
    }

# --------------------------- 8. 模型定义函数 ---------------------------
def create_bilstm_model(input_shape, units, dropout_rate, learning_rate):
    """创建BiLSTM模型"""
    model = Sequential([
        Bidirectional(LSTM(units, return_sequences=False), 
                     input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                 loss='mse',
                 metrics=['mae'])
    return model

def create_gru_model(input_shape, units, dropout_rate, learning_rate):
    """创建GRU模型"""
    model = Sequential([
        GRU(units, return_sequences=False, input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                 loss='mse',
                 metrics=['mae'])
    return model

# --------------------------- 9. 模型选择函数 ---------------------------
def select_best_model(y_true, y_pred_bilstm, y_pred_gru, metric='RMSE'):
    """根据评估指标选择最佳模型"""
    metrics_bilstm = evaluate(y_true, y_pred_bilstm)
    metrics_gru = evaluate(y_true, y_pred_gru)
    
    if metric == 'RMSE':
        if metrics_bilstm['RMSE'] <= metrics_gru['RMSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'MSE':
        if metrics_bilstm['MSE'] <= metrics_gru['MSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'MAE':
        if metrics_bilstm['MAE'] <= metrics_gru['MAE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    elif metric == 'R2':
        if metrics_bilstm['R2'] >= metrics_gru['R2']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru
    else:
        # 默认使用RMSE
        if metrics_bilstm['RMSE'] <= metrics_gru['RMSE']:
            return 'BiLSTM', metrics_bilstm, y_pred_bilstm
        else:
            return 'GRU', metrics_gru, y_pred_gru

# --------------------------- 10. 主程序 ---------------------------
# 使用固定参数进行分解和聚类
print("开始CEEMDAN分解...")
imfs = ceemdan_decomposition(scaled_data, CEEMDAN_EPSILON, CEEMDAN_ETA)
print(f"CEEMDAN分解完成，得到 {imfs.shape[1]} 个IMF分量")

print("开始K-means聚类...")
labels, features, kmeans = cluster_imfs(imfs, n_clusters=N_CLUSTERS)
print("K-means聚类完成")

# 新增：合并同一聚类的IMF
print("开始合并同一聚类的IMF...")
merged_components = merge_imfs_by_cluster(imfs, labels)
print(f"IMF合并完成，得到 {merged_components.shape[1]} 个聚类分量")

print("开始高频模态VMD二次分解...")
components, high_freq_cluster = refine_high_frequency_components(
    merged_components, labels, imfs, VMD_ALPHA, VMD_K
)
print(f"VMD二次分解完成，最终得到 {components.shape[1]} 个分量")

# 输出聚类结果分析
print("\nIMF聚类分析:")
for i in range(N_CLUSTERS):
    cluster_imf_indices = np.where(labels == i)[0]
    print(f"聚类 {i+1} 包含 {len(cluster_imf_indices)} 个IMF: {cluster_imf_indices}")
    if len(cluster_imf_indices) > 0:
        print(f"  平均过零率: {np.mean(features[cluster_imf_indices, 0]):.4f}")
        print(f"  平均能量: {np.mean(features[cluster_imf_indices, 1]):.4f}")
        print(f"  平均周期: {np.mean(features[cluster_imf_indices, 2]):.2f}")

print(f"\n高频聚类（进行VMD二次分解）: 聚类 {high_freq_cluster+1}")

# 准备数据
X, y = [], []
for i in range(N_STEPS, len(components)):
    X.append(components[i-N_STEPS:i])
    y.append(components[i])
X, y = np.array(X), np.array(y)

# --------------------------- 修改：按日期划分训练集和测试集 ---------------------------
print("\n按日期划分训练集和测试集...")

# 获取日期索引
dates = df.index[N_STEPS:]  # 注意：由于使用了N_STEPS，实际日期从第N_STEPS+1天开始

# 定义训练集和测试集的日期范围 - 修改为冬季（12月-2月）
train_start_date = pd.to_datetime('2019-09-01')
train_end_date = pd.to_datetime('2024-11-30')  # 训练到秋季结束
test_start_date = pd.to_datetime('2024-12-01')  # 冬季开始
test_end_date = pd.to_datetime('2025-02-28')    # 冬季结束

# 创建训练集和测试集的掩码
train_mask = (dates >= train_start_date) & (dates <= train_end_date)
test_mask = (dates >= test_start_date) & (dates <= test_end_date)

# 应用掩码划分数据
X_train, X_test = X[train_mask], X[test_mask]
y_train, y_test = y[train_mask], y[test_mask]

print(f"数据划分完成:")
print(f"训练集日期范围: {dates[train_mask].min().strftime('%Y-%m-%d')} 到 {dates[train_mask].max().strftime('%Y-%m-%d')}")
print(f"测试集日期范围: {dates[test_mask].min().strftime('%Y-%m-%d')} 到 {dates[test_mask].max().strftime('%Y-%m-%d')}")
print(f"训练集样本数: {X_train.shape[0]}")
print(f"测试集样本数: {X_test.shape[0]}")
print(f"每个样本的时间步长: {X_train.shape[1]}")
print(f"分量数量: {X_train.shape[2]}")

# 检查是否有数据
if X_train.shape[0] == 0:
    raise ValueError("训练集为空，请检查日期范围设置")
if X_test.shape[0] == 0:
    raise ValueError("测试集为空，请检查日期范围设置")

# --------------------------- 11. 模型训练与选择 ---------------------------
# 为每个分量训练BiLSTM和GRU模型，并选择最佳模型
print("\n开始训练模型并进行模型选择...")
best_models = []  # 存储每个分量的最佳模型
best_model_names = []  # 存储每个分量最佳模型的名称
train_histories_bilstm = []
train_histories_gru = []
component_validation_results = []

for i in range(components.shape[1]):
    print(f"\n训练分量 {i+1}/{components.shape[1]}...")
    
    # 准备数据
    X_component = X_train[:, :, i].reshape(X_train.shape[0], X_train.shape[1], 1)
    y_component = y_train[:, i].reshape(-1, 1)
    
    # 训练BiLSTM模型
    print(f"  训练BiLSTM模型...")
    bilstm_model = create_bilstm_model(
        input_shape=(N_STEPS, 1), 
        units=LSTM_UNITS, 
        dropout_rate=DROPOUT_RATE, 
        learning_rate=LEARNING_RATE
    )
    
    history_bilstm = bilstm_model.fit(
        X_component, y_component, 
        epochs=EPOCHS, 
        batch_size=BATCH_SIZE, 
        verbose=1,
        validation_split=0.2
    )
    train_histories_bilstm.append(history_bilstm)
    
    # 训练GRU模型
    print(f"  训练GRU模型...")
    gru_model = create_gru_model(
        input_shape=(N_STEPS, 1), 
        units=GRU_UNITS, 
        dropout_rate=DROPOUT_RATE, 
        learning_rate=LEARNING_RATE
    )
    
    history_gru = gru_model.fit(
        X_component, y_component, 
        epochs=EPOCHS, 
        batch_size=BATCH_SIZE, 
        verbose=1,
        validation_split=0.2
    )
    train_histories_gru.append(history_gru)
    
    # 在验证集上评估两个模型
    X_val_component = X_component[int(0.8 * len(X_component)):]
    y_val_component = y_component[int(0.8 * len(y_component)):]
    
    y_pred_bilstm = bilstm_model.predict(X_val_component, verbose=0).flatten()
    y_pred_gru = gru_model.predict(X_val_component, verbose=0).flatten()
    
    # 选择最佳模型
    best_model_name, best_metrics, _ = select_best_model(
        y_val_component.flatten(), 
        y_pred_bilstm, 
        y_pred_gru, 
        metric='RMSE'
    )
    
    if best_model_name == 'BiLSTM':
        best_models.append(bilstm_model)
    else:
        best_models.append(gru_model)
    
    best_model_names.append(best_model_name)
    
    component_validation_results.append({
        'component': i+1,
        'best_model': best_model_name,
        'validation_RMSE': best_metrics['RMSE'],
        'validation_MAE': best_metrics['MAE'],
        'validation_R2': best_metrics['R2']
    })
    
    print(f"  分量 {i+1} 最佳模型: {best_model_name}")
    print(f"  验证集RMSE: {best_metrics['RMSE']:.6f}")

print("\n所有分量模型训练和选择完成")

# 输出模型选择结果
print("\n各分量模型选择结果:")
for result in component_validation_results:
    print(f"分量 {result['component']}: 最佳模型={result['best_model']}, "
          f"验证集RMSE={result['validation_RMSE']:.6f}, "
          f"验证集R²={result['validation_R2']:.4f}")

# --------------------------- 12. 预测与评估 ---------------------------
def predict_components(models, X_data):
    """使用各个模型预测各分量"""
    predictions = []
    for i, model in enumerate(models):
        X_component = X_data[:, :, i].reshape(X_data.shape[0], X_data.shape[1], 1)
        pred = model.predict(X_component, verbose=0)
        predictions.append(pred.flatten())
    return np.array(predictions).T

print("\n开始预测...")
# 预测各分量
y_pred_components = predict_components(best_models, X_test)

# 同时分别用BiLSTM和GRU预测以进行对比
y_pred_components_bilstm = predict_components(
    [create_bilstm_model((N_STEPS, 1), LSTM_UNITS, DROPOUT_RATE, LEARNING_RATE) 
     for _ in range(components.shape[1])], X_test
)
y_pred_components_gru = predict_components(
    [create_gru_model((N_STEPS, 1), GRU_UNITS, DROPOUT_RATE, LEARNING_RATE) 
     for _ in range(components.shape[1])], X_test
)

# --------------------------- 新增：对每个分量进行单独评估 ---------------------------
print("\n各分量预测效果评估:")
component_metrics = []
component_comparison = []

for i in range(components.shape[1]):
    # 获取当前分量的真实值和预测值
    y_true_component = y_test[:, i]
    y_pred_component = y_pred_components[:, i]
    y_pred_bilstm_component = y_pred_components_bilstm[:, i]
    y_pred_gru_component = y_pred_components_gru[:, i]
    
    # 计算评估指标
    metrics_component = evaluate(y_true_component, y_pred_component)
    metrics_bilstm = evaluate(y_true_component, y_pred_bilstm_component)
    metrics_gru = evaluate(y_true_component, y_pred_gru_component)
    
    component_metrics.append(metrics_component)
    
    # 记录模型比较结果
    component_comparison.append({
        'component': i+1,
        'best_model': best_model_names[i],
        'BiLSTM_RMSE': metrics_bilstm['RMSE'],
        'GRU_RMSE': metrics_gru['RMSE'],
        'Selected_RMSE': metrics_component['RMSE'],
        'improvement_vs_BiLSTM': (metrics_bilstm['RMSE'] - metrics_component['RMSE']) / metrics_bilstm['RMSE'] * 100,
        'improvement_vs_GRU': (metrics_gru['RMSE'] - metrics_component['RMSE']) / metrics_gru['RMSE'] * 100
    })
    
    print(f"\n分量 {i+1} 预测效果 (最佳模型: {best_model_names[i]}):")
    print(f"  RMSE: {metrics_component['RMSE']:.6f}")
    print(f"  MAE: {metrics_component['MAE']:.6f}")
    print(f"  R²: {metrics_component['R2']:.4f}")
    print(f"  对比 - BiLSTM RMSE: {metrics_bilstm['RMSE']:.6f}, GRU RMSE: {metrics_gru['RMSE']:.6f}")

# 组合分量预测结果
y_pred_combined = np.sum(y_pred_components, axis=1)

# 反归一化
y_pred_final = scaler.inverse_transform(y_pred_combined.reshape(-1, 1)).flatten()
y_true_combined = np.sum(y_test, axis=1)
y_true_final = scaler.inverse_transform(y_true_combined.reshape(-1, 1)).flatten()

# 评估最终预测结果
metrics = evaluate(y_true_final, y_pred_final)
print("\n最终模型评估:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")

# --------------------------- 13. 可视化 ---------------------------
# 可视化IMF合并过程
plt.figure(figsize=(15, 12))

# 原始IMF可视化
plt.subplot(3, 1, 1)
for i in range(imfs.shape[1]):
    plt.plot(imfs[:, i] + i * 0.5, label=f'IMF{i+1}', linewidth=1)
plt.title('CEEMDAN分解的原始IMF分量')
plt.ylabel('幅值')
plt.legend()

# 聚类结果可视化（用不同颜色表示不同聚类）
plt.subplot(3, 1, 2)
colors = ['red', 'blue', 'green', 'orange', 'purple']
for i in range(imfs.shape[1]):
    cluster_color = colors[labels[i] % len(colors)]
    plt.plot(imfs[:, i] + i * 0.5, color=cluster_color, linewidth=1, label=f'聚类{labels[i]+1}' if i == 0 else "")
    if i == 0:
        plt.legend()
plt.title('IMF聚类结果（颜色表示聚类）')
plt.ylabel('幅值')

# 合并后的分量可视化
plt.subplot(3, 1, 3)
for i in range(merged_components.shape[1]):
    plt.plot(merged_components[:, i] + i * 0.8, label=f'合并分量{i+1}', linewidth=2)
plt.title('合并后的聚类分量')
plt.xlabel('时间点')
plt.ylabel('幅值')
plt.legend()

plt.tight_layout()
plt.savefig('imf_clustering_merging.png', dpi=300)
plt.show()

# 可视化各分量的预测效果
plt.figure(figsize=(15, 10))
n_components_to_plot = min(5, components.shape[1])
for i in range(n_components_to_plot):
    plt.subplot(n_components_to_plot, 1, i+1)
    plt.plot(y_test[:, i], label=f'真实分量{i+1}', linewidth=1.5)
    plt.plot(y_pred_components[:, i], label=f'预测分量{i+1}', linewidth=1.5, alpha=0.8)
    plt.legend()
    plt.ylabel(f'分量 {i+1}')

plt.xlabel('时间步')
plt.suptitle('各分量预测效果及评估指标')
plt.tight_layout()
plt.savefig('components_prediction.png', dpi=300)
plt.show()

# 可视化模型选择结果
plt.figure(figsize=(10, 6))
components_idx = list(range(1, len(best_model_names) + 1))
bilstm_count = best_model_names.count('BiLSTM')
gru_count = best_model_names.count('GRU')

plt.bar(['BiLSTM', 'GRU'], [bilstm_count, gru_count], color=['blue', 'orange'])
plt.title('各分量最佳模型选择分布')
plt.ylabel('分量数量')
for i, v in enumerate([bilstm_count, gru_count]):
    plt.text(i, v + 0.1, str(v), ha='center', va='bottom')
plt.savefig('model_selection_distribution.png', dpi=300)
plt.show()

# 可视化最终预测结果
plt.figure(figsize=(12, 6))
plt.plot(y_true_final, label='真实值', linewidth=2)
plt.plot(y_pred_final, label='预测值', linewidth=2, alpha=0.8)
plt.legend()
plt.title('碳排放预测结果 (2024年12月1日-2025年2月28日)')  # 修改为冬季
plt.xlabel('时间步')
plt.ylabel('碳排放量')
plt.grid(True, alpha=0.3)


plt.savefig('final_prediction.png', dpi=300)
plt.show()

# 可视化训练损失对比
plt.figure(figsize=(15, 10))
for i in range(min(5, len(train_histories_bilstm))):
    plt.subplot(2, 3, i+1)
    plt.plot(train_histories_bilstm[i].history['loss'], label='BiLSTM训练损失', color='blue')
    plt.plot(train_histories_bilstm[i].history['val_loss'], label='BiLSTM验证损失', color='blue', linestyle='--')
    plt.plot(train_histories_gru[i].history['loss'], label='GRU训练损失', color='orange')
    plt.plot(train_histories_gru[i].history['val_loss'], label='GRU验证损失', color='orange', linestyle='--')
    plt.title(f'分量 {i+1} 训练过程对比')
    plt.xlabel('训练轮次')
    plt.ylabel('损失值')
    plt.legend()
plt.tight_layout()
plt.savefig('training_history_comparison.png', dpi=300)
plt.show()

# --------------------------- 新增：冬季预测结果详细分析 ---------------------------
def plot_winter_performance(dates, y_true, y_pred, winter_start='2024-12-01', winter_end='2025-02-28'):
    """单独可视化冬季的预测结果"""
    
    # 创建冬季掩码
    winter_mask = (dates >= pd.Timestamp(winter_start)) & (dates <= pd.Timestamp(winter_end))
    
    # 提取冬季数据
    winter_dates = dates[winter_mask]
    winter_true = y_true[winter_mask]
    winter_pred = y_pred[winter_mask]
    
    if len(winter_dates) == 0:
        print("警告：没有找到冬季数据，请检查日期范围")
        return
    
    # 计算冬季评估指标
    winter_metrics = evaluate(winter_true, winter_pred)
    
    # 创建图表
    plt.figure(figsize=(15, 8))
    
    # 绘制冬季预测结果
    plt.plot(winter_dates, winter_true, label='真实值', linewidth=2.5, color='#2E86AB', marker='o', markersize=4)
    plt.plot(winter_dates, winter_pred, label='预测值', linewidth=2.5, color='#A23B72', linestyle='--', marker='s', markersize=4)
    
    # 美化图表
    plt.title('2024-2025年冬季碳排放预测结果 (12月-2月)', fontsize=16, fontweight='bold', pad=20)  # 修改为冬季
    plt.xlabel('日期', fontsize=12)
    plt.ylabel('碳排放量', fontsize=12)
    plt.legend(fontsize=12, loc='upper right')
    plt.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 添加评估指标框
    metrics_text = (f"冬季评估指标:\n"  # 修改为冬季
                   f"RMSE: {winter_metrics['RMSE']:.4f}\n"
                   f"MAE: {winter_metrics['MAE']:.4f}\n"
                   f"MAPE: {winter_metrics['MAPE']:.2f}%\n"
                   f"R²: {winter_metrics['R2']:.4f}")
    
    plt.annotate(metrics_text, xy=(0.02, 0.98), xycoords='axes fraction', 
                bbox=dict(boxstyle="round,pad=0.5", facecolor="lightyellow", alpha=0.8),
                fontsize=11, verticalalignment='top')
    
    # 添加月份分隔线
    january_start = pd.Timestamp('2025-01-01')
    february_start = pd.Timestamp('2025-02-01')
    
    if january_start in winter_dates:
        plt.axvline(january_start, color='gray', linestyle=':', alpha=0.7, label='1月开始')
    if february_start in winter_dates:
        plt.axvline(february_start, color='gray', linestyle=':', alpha=0.7, label='2月开始')
    
    plt.tight_layout()
    plt.savefig('winter_prediction_detailed.png', dpi=300, bbox_inches='tight')  # 修改文件名
    plt.show()
    
    return winter_metrics

# --------------------------- 新增：冬季预测误差分析 ---------------------------
def analyze_winter_errors(dates, y_true, y_pred):
    """分析冬季预测误差"""
    
    winter_mask = (dates >= pd.Timestamp('2024-12-01')) & (dates <= pd.Timestamp('2025-02-28'))  # 修改为冬季
    winter_dates = dates[winter_mask]
    winter_true = y_true[winter_mask]
    winter_pred = y_pred[winter_mask]
    
    # 计算绝对误差和相对误差
    absolute_errors = np.abs(winter_true - winter_pred)
    relative_errors = np.abs((winter_true - winter_pred) / np.maximum(np.abs(winter_true), 1e-10)) * 100
    
    # 创建误差分析图
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 10))
    
    # 子图1：绝对误差
    bars1 = ax1.bar(winter_dates, absolute_errors, alpha=0.7, color='#4682B4', edgecolor='darkblue')  # 冬季颜色
    ax1.set_title('冬季预测绝对误差分析', fontsize=14, fontweight='bold')  # 修改为冬季
    ax1.set_ylabel('绝对误差', fontsize=12)
    ax1.grid(True, alpha=0.3)
    
    # 在柱状图上标注最大误差点
    max_error_idx = np.argmax(absolute_errors)
    ax1.annotate(f'最大误差: {absolute_errors[max_error_idx]:.2f}', 
                xy=(winter_dates[max_error_idx], absolute_errors[max_error_idx]),
                xytext=(10, 10), textcoords='offset points',
                bbox=dict(boxstyle='round,pad=0.3', facecolor='red', alpha=0.3),
                arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0'))
    
    # 子图2：相对误差（百分比）
    bars2 = ax2.bar(winter_dates, relative_errors, alpha=0.7, color='#87CEEB', edgecolor='darkblue')  # 冬季颜色
    ax2.set_title('冬季预测相对误差分析', fontsize=14, fontweight='bold')  # 修改为冬季
    ax2.set_ylabel('相对误差 (%)', fontsize=12)
    ax2.set_xlabel('日期', fontsize=12)
    ax2.grid(True, alpha=0.3)
    
    # 设置x轴格式
    for ax in [ax1, ax2]:
        ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
        ax.xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
        plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
    
    plt.tight_layout()
    plt.savefig('winter_error_analysis.png', dpi=300, bbox_inches='tight')  # 修改文件名
    plt.show()
    
    # 输出误差统计
    print("\n" + "="*50)
    print("冬季预测误差统计分析")  # 修改为冬季
    print("="*50)
    print(f"平均绝对误差: {np.mean(absolute_errors):.4f}")
    print(f"最大绝对误差: {np.max(absolute_errors):.4f}")
    print(f"最小绝对误差: {np.min(absolute_errors):.4f}")
    print(f"平均相对误差: {np.mean(relative_errors):.2f}%")
    print(f"最大相对误差: {np.max(relative_errors):.2f}%")
    print(f"最小相对误差: {np.min(relative_errors):.2f}%")
    
    return absolute_errors, relative_errors

# --------------------------- 新增：冬季按月份细分分析 ---------------------------
def analyze_winter_by_month(dates, y_true, y_pred):
    """按月份分析冬季预测性能"""
    
    winter_months = {
        '十二月': (pd.Timestamp('2024-12-01'), pd.Timestamp('2024-12-31')),
        '一月': (pd.Timestamp('2025-01-01'), pd.Timestamp('2025-01-31')),
        '二月': (pd.Timestamp('2025-02-01'), pd.Timestamp('2025-02-28'))
    }
    
    monthly_metrics = {}
    
    plt.figure(figsize=(15, 10))
    
    for i, (month_name, (start_date, end_date)) in enumerate(winter_months.items()):
        month_mask = (dates >= start_date) & (dates <= end_date)
        month_dates = dates[month_mask]
        month_true = y_true[month_mask]
        month_pred = y_pred[month_mask]
        
        if len(month_dates) > 0:
            # 计算月度指标
            metrics = evaluate(month_true, month_pred)
            monthly_metrics[month_name] = metrics
            
            # 绘制月度子图
            plt.subplot(3, 1, i+1)
            plt.plot(month_dates, month_true, label='真实值', linewidth=2, color='#2E86AB')
            plt.plot(month_dates, month_pred, label='预测值', linewidth=2, color='#A23B72', linestyle='--')
            plt.title(f'{month_name}碳排放预测', fontsize=12, fontweight='bold')
            plt.ylabel('碳排放量')
            plt.legend()
            plt.grid(True, alpha=0.3)
            
    
    plt.xlabel('日期')
    plt.suptitle('2024-2025年冬季各月份碳排放预测分析', fontsize=16, fontweight='bold')  # 修改为冬季
    plt.tight_layout()
    plt.savefig('winter_monthly_analysis.png', dpi=300, bbox_inches='tight')  # 修改文件名
    plt.show()
    
    return monthly_metrics

# --------------------------- 执行冬季单独分析 ---------------------------
print("\n" + "="*60)
print("冬季预测结果详细分析")  # 修改为冬季
print("="*60)

# 获取测试集日期
test_dates = dates[test_mask]

# 绘制冬季预测结果
winter_metrics = plot_winter_performance(test_dates, y_true_final, y_pred_final)

# 进行冬季误差分析
absolute_errors, relative_errors = analyze_winter_errors(test_dates, y_true_final, y_pred_final)

# 执行月度分析
print("\n" + "="*50)
print("冬季各月份详细分析")  # 修改为冬季
print("="*50)

monthly_metrics = analyze_winter_by_month(test_dates, y_true_final, y_pred_final)

# 输出月度比较
print("\n冬季各月份预测性能比较:")  # 修改为冬季
for month, metrics in monthly_metrics.items():
    print(f"\n{month}:")
    print(f"  RMSE: {metrics['RMSE']:.4f}")
    print(f"  MAE: {metrics['MAE']:.4f}")
    print(f"  MAPE: {metrics['MAPE']:.2f}%")
    print(f"  R²: {metrics['R2']:.4f}")

# 找出最佳和最差预测月份
best_month = min(monthly_metrics.items(), key=lambda x: x[1]['RMSE'])
worst_month = max(monthly_metrics.items(), key=lambda x: x[1]['RMSE'])

print(f"\n📊 冬季预测性能总结:")  # 修改为冬季
print(f"  最佳预测月份: {best_month[0]} (RMSE: {best_month[1]['RMSE']:.4f})")
print(f"  最具挑战月份: {worst_month[0]} (RMSE: {worst_month[1]['RMSE']:.4f})")
# Out:
# 开始CEEMDAN分解...
# CEEMDAN分解完成，得到 9 个IMF分量
# 开始K-means聚类...
# K-means聚类完成
# 开始合并同一聚类的IMF...
# IMF合并完成，得到 3 个聚类分量
# 开始高频模态VMD二次分解...
# VMD二次分解完成，最终得到 5 个分量
#
# IMF聚类分析:
# 聚类 1 包含 7 个IMF: [1 2 3 4 5 6 7]
#   平均过零率: 0.0655
#   平均能量: 7.8691
#   平均周期: 97.29
# 聚类 2 包含 1 个IMF: [8]
#   平均过零率: 0.0000
#   平均能量: 84.1292
#   平均周期: 2005.00
# 聚类 3 包含 1 个IMF: [0]
#   平均过零率: 0.5196
#   平均能量: 0.9153
#   平均周期: 2.00
#
# 高频聚类（进行VMD二次分解）: 聚类 3
#
# 按日期划分训练集和测试集...
# 数据划分完成:
# 训练集日期范围: 2019-09-01 到 2024-11-30
# 测试集日期范围: 2024-12-01 到 2024-12-31
# 训练集样本数: 1918
# 测试集样本数: 31
# 每个样本的时间步长: 24
# 分量数量: 5
#
# 开始训练模型并进行模型选择...
#
# 训练分量 1/5...
#   训练BiLSTM模型...
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0082 - mae: 0.0546 - val_loss: 0.0021 - val_mae: 0.0279
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0029 - mae: 0.0281 - val_loss: 0.0010 - val_mae: 0.0222
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0023 - mae: 0.0255 - val_loss: 8.6948e-04 - val_mae: 0.0189
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0212 - val_loss: 7.6504e-04 - val_mae: 0.0193
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014 - mae: 0.0210 - val_loss: 6.4439e-04 - val_mae: 0.0192
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - mae: 0.0196 - val_loss: 7.3364e-04 - val_mae: 0.0200
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.8813e-04 - mae: 0.0184 - val_loss: 4.3560e-04 - val_mae: 0.0135
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.3242e-04 - mae: 0.0183 - val_loss: 4.6532e-04 - val_mae: 0.0161
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0013 - mae: 0.0188 - val_loss: 3.3954e-04 - val_mae: 0.0123
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.7942e-04 - mae: 0.0174 - val_loss: 3.2469e-04 - val_mae: 0.0121
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.9172e-04 - mae: 0.0166 - val_loss: 3.5492e-04 - val_mae: 0.0132
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3865e-04 - mae: 0.0161 - val_loss: 2.6901e-04 - val_mae: 0.0119
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6446e-04 - mae: 0.0146 - val_loss: 2.2537e-04 - val_mae: 0.0112
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5077e-04 - mae: 0.0134 - val_loss: 6.3457e-04 - val_mae: 0.0169
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.2594e-04 - mae: 0.0153 - val_loss: 1.9870e-04 - val_mae: 0.0101
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2441e-04 - mae: 0.0134 - val_loss: 1.8848e-04 - val_mae: 0.0088
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7968e-04 - mae: 0.0131 - val_loss: 1.7404e-04 - val_mae: 0.0087
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.5924e-04 - mae: 0.0140 - val_loss: 3.3319e-04 - val_mae: 0.0125
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5800e-04 - mae: 0.0136 - val_loss: 2.1146e-04 - val_mae: 0.0096
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8471e-04 - mae: 0.0130 - val_loss: 1.5439e-04 - val_mae: 0.0081
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1970e-04 - mae: 0.0134 - val_loss: 1.4297e-04 - val_mae: 0.0077
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0340e-04 - mae: 0.0115 - val_loss: 1.4541e-04 - val_mae: 0.0091
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5569e-04 - mae: 0.0130 - val_loss: 1.3946e-04 - val_mae: 0.0087
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5589e-04 - mae: 0.0118 - val_loss: 1.4627e-04 - val_mae: 0.0091
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0019e-04 - mae: 0.0121 - val_loss: 1.2445e-04 - val_mae: 0.0077
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9473e-04 - mae: 0.0119 - val_loss: 1.3784e-04 - val_mae: 0.0093
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6703e-04 - mae: 0.0123 - val_loss: 1.4033e-04 - val_mae: 0.0081
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4470e-04 - mae: 0.0113 - val_loss: 1.1282e-04 - val_mae: 0.0072
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6527e-04 - mae: 0.0126 - val_loss: 1.0910e-04 - val_mae: 0.0078
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.0261e-04 - mae: 0.0112 - val_loss: 9.7032e-05 - val_mae: 0.0064
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9366e-04 - mae: 0.0108 - val_loss: 9.3340e-05 - val_mae: 0.0065
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4469e-04 - mae: 0.0112 - val_loss: 9.7569e-05 - val_mae: 0.0067
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8504e-04 - mae: 0.0108 - val_loss: 9.4303e-05 - val_mae: 0.0068
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.2741e-04 - mae: 0.0116 - val_loss: 8.8661e-05 - val_mae: 0.0062
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.5512e-04 - mae: 0.0103 - val_loss: 8.5511e-05 - val_mae: 0.0064
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4690e-04 - mae: 0.0104 - val_loss: 1.0738e-04 - val_mae: 0.0068
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.6659e-04 - mae: 0.0103 - val_loss: 1.3679e-04 - val_mae: 0.0076
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.5306e-04 - mae: 0.0101 - val_loss: 7.3364e-05 - val_mae: 0.0058
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.6470e-04 - mae: 0.0103 - val_loss: 1.0201e-04 - val_mae: 0.0066
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.0189e-04 - mae: 0.0112 - val_loss: 7.3450e-05 - val_mae: 0.0064
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.9080e-04 - mae: 0.0096 - val_loss: 9.5351e-05 - val_mae: 0.0064
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.2935e-04 - mae: 0.0105 - val_loss: 6.4811e-05 - val_mae: 0.0054
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1213e-04 - mae: 0.0098 - val_loss: 7.8645e-05 - val_mae: 0.0060
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.0184e-04 - mae: 0.0095 - val_loss: 9.3865e-05 - val_mae: 0.0065
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4616e-04 - mae: 0.0104 - val_loss: 1.1911e-04 - val_mae: 0.0081
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7465e-04 - mae: 0.0091 - val_loss: 7.9051e-05 - val_mae: 0.0060
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8825e-04 - mae: 0.0101 - val_loss: 1.2143e-04 - val_mae: 0.0074
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.2353e-04 - mae: 0.0102 - val_loss: 5.7716e-05 - val_mae: 0.0057
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3131e-04 - mae: 0.0106 - val_loss: 5.2013e-05 - val_mae: 0.0047
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1533e-04 - mae: 0.0096 - val_loss: 6.6419e-05 - val_mae: 0.0053
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8971e-04 - mae: 0.0091 - val_loss: 5.2195e-05 - val_mae: 0.0048
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0002e-04 - mae: 0.0098 - val_loss: 7.1089e-05 - val_mae: 0.0056
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8323e-04 - mae: 0.0090 - val_loss: 7.0146e-05 - val_mae: 0.0068
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9666e-04 - mae: 0.0095 - val_loss: 6.0583e-05 - val_mae: 0.0053
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8581e-04 - mae: 0.0092 - val_loss: 5.0278e-05 - val_mae: 0.0047
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2743e-04 - mae: 0.0094 - val_loss: 6.8242e-05 - val_mae: 0.0057
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1245e-04 - mae: 0.0090 - val_loss: 4.6234e-05 - val_mae: 0.0046
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1562e-04 - mae: 0.0093 - val_loss: 7.1156e-05 - val_mae: 0.0062
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3019e-04 - mae: 0.0098 - val_loss: 5.4762e-05 - val_mae: 0.0048
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3905e-04 - mae: 0.0093 - val_loss: 4.2575e-05 - val_mae: 0.0044
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7657e-04 - mae: 0.0091 - val_loss: 4.6488e-05 - val_mae: 0.0052
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7998e-04 - mae: 0.0088 - val_loss: 4.4040e-05 - val_mae: 0.0043
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9997e-04 - mae: 0.0100 - val_loss: 4.8639e-05 - val_mae: 0.0045
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9592e-04 - mae: 0.0090 - val_loss: 4.9061e-05 - val_mae: 0.0047
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5459e-04 - mae: 0.0086 - val_loss: 6.6347e-05 - val_mae: 0.0051
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8850e-04 - mae: 0.0089 - val_loss: 4.5179e-05 - val_mae: 0.0046
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1649e-04 - mae: 0.0094 - val_loss: 6.2624e-05 - val_mae: 0.0059
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7867e-04 - mae: 0.0088 - val_loss: 4.3415e-05 - val_mae: 0.0052
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5673e-04 - mae: 0.0087 - val_loss: 4.6636e-05 - val_mae: 0.0055
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0108e-04 - mae: 0.0089 - val_loss: 4.8486e-05 - val_mae: 0.0047
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7026e-04 - mae: 0.0087 - val_loss: 4.2887e-05 - val_mae: 0.0046
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7934e-04 - mae: 0.0089 - val_loss: 3.9120e-05 - val_mae: 0.0047
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7679e-04 - mae: 0.0086 - val_loss: 4.3761e-05 - val_mae: 0.0054
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9651e-04 - mae: 0.0090 - val_loss: 4.0644e-05 - val_mae: 0.0047
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9313e-04 - mae: 0.0092 - val_loss: 3.3030e-05 - val_mae: 0.0038
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4539e-04 - mae: 0.0083 - val_loss: 3.8026e-05 - val_mae: 0.0041
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5689e-04 - mae: 0.0087 - val_loss: 3.4080e-05 - val_mae: 0.0042
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4769e-04 - mae: 0.0082 - val_loss: 3.2747e-05 - val_mae: 0.0038
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0944e-04 - mae: 0.0087 - val_loss: 4.7699e-05 - val_mae: 0.0052
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7430e-04 - mae: 0.0084 - val_loss: 4.3947e-05 - val_mae: 0.0045
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8180e-04 - mae: 0.0087 - val_loss: 4.3018e-05 - val_mae: 0.0045
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5212e-04 - mae: 0.0085 - val_loss: 8.6538e-05 - val_mae: 0.0079
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0877e-04 - mae: 0.0086 - val_loss: 3.3035e-05 - val_mae: 0.0041
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6551e-04 - mae: 0.0084 - val_loss: 3.1530e-05 - val_mae: 0.0037
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6411e-04 - mae: 0.0084 - val_loss: 2.9908e-05 - val_mae: 0.0037
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8843e-04 - mae: 0.0089 - val_loss: 5.8938e-05 - val_mae: 0.0055
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6649e-04 - mae: 0.0085 - val_loss: 3.5842e-05 - val_mae: 0.0045
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3162e-04 - mae: 0.0079 - val_loss: 3.0036e-05 - val_mae: 0.0040
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5164e-04 - mae: 0.0082 - val_loss: 2.8777e-05 - val_mae: 0.0036
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4146e-04 - mae: 0.0078 - val_loss: 3.1973e-05 - val_mae: 0.0038
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6424e-04 - mae: 0.0084 - val_loss: 2.7063e-05 - val_mae: 0.0035
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0030e-04 - mae: 0.0085 - val_loss: 3.8816e-05 - val_mae: 0.0040
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6290e-04 - mae: 0.0084 - val_loss: 3.2190e-05 - val_mae: 0.0046
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6472e-04 - mae: 0.0084 - val_loss: 5.0605e-05 - val_mae: 0.0047
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7265e-04 - mae: 0.0084 - val_loss: 4.3026e-05 - val_mae: 0.0042
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7590e-04 - mae: 0.0082 - val_loss: 2.5646e-05 - val_mae: 0.0034
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8292e-04 - mae: 0.0083 - val_loss: 4.8536e-05 - val_mae: 0.0047
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4158e-04 - mae: 0.0081 - val_loss: 3.1541e-05 - val_mae: 0.0039
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1598e-04 - mae: 0.0075 - val_loss: 2.5193e-05 - val_mae: 0.0033
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2258e-04 - mae: 0.0074 - val_loss: 2.4564e-05 - val_mae: 0.0033
#   训练GRU模型...
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0087 - mae: 0.0593 - val_loss: 7.0300e-04 - val_mae: 0.0180
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - mae: 0.0225 - val_loss: 5.6607e-04 - val_mae: 0.0158
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - mae: 0.0200 - val_loss: 5.0652e-04 - val_mae: 0.0144
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4437e-04 - mae: 0.0184 - val_loss: 4.7084e-04 - val_mae: 0.0142
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8329e-04 - mae: 0.0173 - val_loss: 3.0781e-04 - val_mae: 0.0120
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9261e-04 - mae: 0.0152 - val_loss: 2.4830e-04 - val_mae: 0.0113
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1543e-04 - mae: 0.0151 - val_loss: 2.0650e-04 - val_mae: 0.0112
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9499e-04 - mae: 0.0143 - val_loss: 1.9541e-04 - val_mae: 0.0091
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3801e-04 - mae: 0.0133 - val_loss: 1.7969e-04 - val_mae: 0.0089
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4823e-04 - mae: 0.0135 - val_loss: 1.5191e-04 - val_mae: 0.0087
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1237e-04 - mae: 0.0116 - val_loss: 1.3341e-04 - val_mae: 0.0083
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8243e-04 - mae: 0.0123 - val_loss: 1.0911e-04 - val_mae: 0.0069
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9946e-04 - mae: 0.0110 - val_loss: 1.1479e-04 - val_mae: 0.0078
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8399e-04 - mae: 0.0113 - val_loss: 1.1573e-04 - val_mae: 0.0080
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0406e-04 - mae: 0.0118 - val_loss: 1.1130e-04 - val_mae: 0.0075
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2190e-04 - mae: 0.0112 - val_loss: 1.3832e-04 - val_mae: 0.0090
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4925e-04 - mae: 0.0108 - val_loss: 9.1065e-05 - val_mae: 0.0068
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5221e-04 - mae: 0.0103 - val_loss: 1.3078e-04 - val_mae: 0.0087
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2352e-04 - mae: 0.0105 - val_loss: 8.4072e-05 - val_mae: 0.0066
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6381e-04 - mae: 0.0110 - val_loss: 7.6689e-05 - val_mae: 0.0059
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3913e-04 - mae: 0.0098 - val_loss: 8.5216e-05 - val_mae: 0.0069
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2340e-04 - mae: 0.0102 - val_loss: 6.6901e-05 - val_mae: 0.0055
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9182e-04 - mae: 0.0095 - val_loss: 6.3680e-05 - val_mae: 0.0052
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1595e-04 - mae: 0.0099 - val_loss: 6.3343e-05 - val_mae: 0.0052
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9814e-04 - mae: 0.0095 - val_loss: 7.9347e-05 - val_mae: 0.0075
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0364e-04 - mae: 0.0096 - val_loss: 5.5017e-05 - val_mae: 0.0054
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4408e-04 - mae: 0.0100 - val_loss: 4.8402e-05 - val_mae: 0.0046
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0660e-04 - mae: 0.0097 - val_loss: 6.4501e-05 - val_mae: 0.0059
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2617e-04 - mae: 0.0096 - val_loss: 4.7502e-05 - val_mae: 0.0048
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1477e-04 - mae: 0.0092 - val_loss: 6.4047e-05 - val_mae: 0.0053
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7159e-04 - mae: 0.0099 - val_loss: 4.1363e-05 - val_mae: 0.0042
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1336e-04 - mae: 0.0093 - val_loss: 4.1086e-05 - val_mae: 0.0045
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3730e-04 - mae: 0.0081 - val_loss: 4.2565e-05 - val_mae: 0.0044
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6881e-04 - mae: 0.0087 - val_loss: 4.0946e-05 - val_mae: 0.0045
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0088e-04 - mae: 0.0092 - val_loss: 4.1221e-05 - val_mae: 0.0043
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8125e-04 - mae: 0.0088 - val_loss: 4.4549e-05 - val_mae: 0.0044
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7171e-04 - mae: 0.0086 - val_loss: 5.5428e-05 - val_mae: 0.0047
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0013e-04 - mae: 0.0094 - val_loss: 3.3905e-05 - val_mae: 0.0039
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8708e-04 - mae: 0.0089 - val_loss: 3.3526e-05 - val_mae: 0.0038
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7516e-04 - mae: 0.0087 - val_loss: 4.1104e-05 - val_mae: 0.0043
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6441e-04 - mae: 0.0084 - val_loss: 3.4072e-05 - val_mae: 0.0038
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3354e-04 - mae: 0.0078 - val_loss: 3.5556e-05 - val_mae: 0.0043
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4093e-04 - mae: 0.0082 - val_loss: 9.4538e-05 - val_mae: 0.0073
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4770e-04 - mae: 0.0084 - val_loss: 3.5342e-05 - val_mae: 0.0048
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8641e-04 - mae: 0.0087 - val_loss: 3.7686e-05 - val_mae: 0.0047
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6020e-04 - mae: 0.0084 - val_loss: 4.2271e-05 - val_mae: 0.0043
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2865e-04 - mae: 0.0078 - val_loss: 2.9232e-05 - val_mae: 0.0041
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3603e-04 - mae: 0.0082 - val_loss: 2.5986e-05 - val_mae: 0.0034
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4959e-04 - mae: 0.0079 - val_loss: 3.4581e-05 - val_mae: 0.0045
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7084e-04 - mae: 0.0085 - val_loss: 3.4434e-05 - val_mae: 0.0039
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5126e-04 - mae: 0.0082 - val_loss: 4.6148e-05 - val_mae: 0.0053
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8573e-04 - mae: 0.0086 - val_loss: 2.8427e-05 - val_mae: 0.0042
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4090e-04 - mae: 0.0079 - val_loss: 2.2703e-05 - val_mae: 0.0031
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2845e-04 - mae: 0.0075 - val_loss: 2.5566e-05 - val_mae: 0.0036
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5123e-04 - mae: 0.0083 - val_loss: 2.8147e-05 - val_mae: 0.0038
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2954e-04 - mae: 0.0093 - val_loss: 2.4598e-05 - val_mae: 0.0034
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6671e-04 - mae: 0.0084 - val_loss: 2.1295e-05 - val_mae: 0.0031
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6808e-04 - mae: 0.0081 - val_loss: 5.4614e-05 - val_mae: 0.0049
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0694e-04 - mae: 0.0090 - val_loss: 2.4933e-05 - val_mae: 0.0037
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3969e-04 - mae: 0.0080 - val_loss: 2.1258e-05 - val_mae: 0.0032
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3168e-04 - mae: 0.0075 - val_loss: 2.4213e-05 - val_mae: 0.0039
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4705e-04 - mae: 0.0080 - val_loss: 5.8154e-05 - val_mae: 0.0061
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6992e-04 - mae: 0.0084 - val_loss: 1.9550e-05 - val_mae: 0.0030
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5390e-04 - mae: 0.0082 - val_loss: 3.0663e-05 - val_mae: 0.0037
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0997e-04 - mae: 0.0074 - val_loss: 4.1546e-05 - val_mae: 0.0042
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6427e-04 - mae: 0.0082 - val_loss: 5.2294e-05 - val_mae: 0.0049
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4016e-04 - mae: 0.0080 - val_loss: 2.0463e-05 - val_mae: 0.0030
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7117e-04 - mae: 0.0081 - val_loss: 2.6623e-05 - val_mae: 0.0041
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5383e-04 - mae: 0.0077 - val_loss: 2.0382e-05 - val_mae: 0.0033
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6033e-04 - mae: 0.0080 - val_loss: 2.0601e-05 - val_mae: 0.0035
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6339e-04 - mae: 0.0081 - val_loss: 2.1330e-05 - val_mae: 0.0036
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4312e-04 - mae: 0.0080 - val_loss: 2.9907e-05 - val_mae: 0.0044
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1950e-04 - mae: 0.0074 - val_loss: 2.3564e-05 - val_mae: 0.0033
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3240e-04 - mae: 0.0077 - val_loss: 4.0378e-05 - val_mae: 0.0046
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5018e-04 - mae: 0.0083 - val_loss: 2.5666e-05 - val_mae: 0.0041
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4451e-04 - mae: 0.0079 - val_loss: 3.0400e-05 - val_mae: 0.0044
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8515e-04 - mae: 0.0091 - val_loss: 1.8421e-05 - val_mae: 0.0032
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3041e-04 - mae: 0.0076 - val_loss: 2.6498e-05 - val_mae: 0.0040
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4755e-04 - mae: 0.0082 - val_loss: 1.8218e-05 - val_mae: 0.0033
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2547e-04 - mae: 0.0075 - val_loss: 2.4318e-05 - val_mae: 0.0042
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1887e-04 - mae: 0.0076 - val_loss: 3.9460e-05 - val_mae: 0.0049
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5551e-04 - mae: 0.0080 - val_loss: 2.7494e-05 - val_mae: 0.0045
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5372e-04 - mae: 0.0080 - val_loss: 2.7414e-05 - val_mae: 0.0041
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5628e-04 - mae: 0.0082 - val_loss: 2.5254e-05 - val_mae: 0.0037
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3959e-04 - mae: 0.0075 - val_loss: 1.8885e-05 - val_mae: 0.0030
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3119e-04 - mae: 0.0074 - val_loss: 1.4474e-05 - val_mae: 0.0026
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3547e-04 - mae: 0.0074 - val_loss: 2.4357e-05 - val_mae: 0.0041
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3191e-04 - mae: 0.0080 - val_loss: 2.3237e-05 - val_mae: 0.0040
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4313e-04 - mae: 0.0078 - val_loss: 5.5647e-05 - val_mae: 0.0051
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2492e-04 - mae: 0.0075 - val_loss: 3.6305e-05 - val_mae: 0.0050
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4070e-04 - mae: 0.0080 - val_loss: 2.6422e-05 - val_mae: 0.0042
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2373e-04 - mae: 0.0078 - val_loss: 2.1965e-05 - val_mae: 0.0035
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2071e-04 - mae: 0.0079 - val_loss: 1.4083e-05 - val_mae: 0.0029
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2061e-04 - mae: 0.0071 - val_loss: 1.3023e-05 - val_mae: 0.0025
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4008e-04 - mae: 0.0073 - val_loss: 4.5609e-05 - val_mae: 0.0053
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4698e-04 - mae: 0.0080 - val_loss: 1.8747e-05 - val_mae: 0.0036
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5757e-04 - mae: 0.0080 - val_loss: 1.5376e-05 - val_mae: 0.0032
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2179e-04 - mae: 0.0071 - val_loss: 1.9767e-05 - val_mae: 0.0032
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0253e-04 - mae: 0.0070 - val_loss: 1.6089e-05 - val_mae: 0.0028
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2712e-04 - mae: 0.0074 - val_loss: 1.7437e-05 - val_mae: 0.0030
#   分量 1 最佳模型: GRU
#   验证集RMSE: 0.004176
#
# 训练分量 2/5...
#   训练BiLSTM模型...
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0080 - mae: 0.0640 - val_loss: 3.6052e-05 - val_mae: 0.0058
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7566e-04 - mae: 0.0135 - val_loss: 2.8422e-05 - val_mae: 0.0052
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7236e-04 - mae: 0.0103 - val_loss: 6.7467e-06 - val_mae: 0.0024
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4759e-04 - mae: 0.0093 - val_loss: 1.3217e-05 - val_mae: 0.0036
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1346e-04 - mae: 0.0083 - val_loss: 1.2597e-05 - val_mae: 0.0035
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.7769e-05 - mae: 0.0078 - val_loss: 9.9682e-08 - val_mae: 2.5785e-04
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.9859e-05 - mae: 0.0075 - val_loss: 2.2221e-06 - val_mae: 0.0015
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3650e-05 - mae: 0.0069 - val_loss: 9.1587e-07 - val_mae: 9.4592e-04
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.8209e-05 - mae: 0.0069 - val_loss: 5.6473e-06 - val_mae: 0.0024
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.0516e-05 - mae: 0.0065 - val_loss: 3.4338e-05 - val_mae: 0.0059
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.9846e-05 - mae: 0.0069 - val_loss: 3.0290e-06 - val_mae: 0.0017
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.1886e-05 - mae: 0.0064 - val_loss: 2.3112e-06 - val_mae: 0.0015
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.5582e-05 - mae: 0.0069 - val_loss: 1.0427e-05 - val_mae: 0.0032
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.7762e-05 - mae: 0.0064 - val_loss: 2.6668e-07 - val_mae: 4.6908e-04
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.3300e-05 - mae: 0.0064 - val_loss: 1.4086e-05 - val_mae: 0.0037
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.0328e-05 - mae: 0.0066 - val_loss: 1.2755e-06 - val_mae: 0.0011
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.2361e-05 - mae: 0.0063 - val_loss: 1.2555e-07 - val_mae: 3.3112e-04
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.7007e-05 - mae: 0.0060 - val_loss: 9.0818e-06 - val_mae: 0.0030
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7613e-05 - mae: 0.0060 - val_loss: 1.4235e-06 - val_mae: 0.0012
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4148e-05 - mae: 0.0058 - val_loss: 6.2872e-06 - val_mae: 0.0025
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9748e-05 - mae: 0.0061 - val_loss: 2.0312e-07 - val_mae: 4.1157e-04
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0204e-05 - mae: 0.0057 - val_loss: 1.9874e-07 - val_mae: 3.8727e-04
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0871e-05 - mae: 0.0056 - val_loss: 1.6143e-06 - val_mae: 0.0013
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7085e-05 - mae: 0.0055 - val_loss: 4.8644e-06 - val_mae: 0.0022
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7613e-05 - mae: 0.0054 - val_loss: 1.6795e-05 - val_mae: 0.0041
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.3298e-05 - mae: 0.0062 - val_loss: 2.1727e-05 - val_mae: 0.0047
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6581e-05 - mae: 0.0060 - val_loss: 3.4286e-06 - val_mae: 0.0018
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3452e-05 - mae: 0.0052 - val_loss: 1.1714e-06 - val_mae: 0.0011
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7392e-05 - mae: 0.0055 - val_loss: 1.9112e-06 - val_mae: 0.0014
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5514e-05 - mae: 0.0052 - val_loss: 9.1996e-07 - val_mae: 9.4943e-04
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6746e-05 - mae: 0.0052 - val_loss: 4.3196e-06 - val_mae: 0.0021
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6497e-05 - mae: 0.0054 - val_loss: 5.2059e-06 - val_mae: 0.0023
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7353e-05 - mae: 0.0048 - val_loss: 5.7675e-08 - val_mae: 1.9848e-04
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4746e-05 - mae: 0.0053 - val_loss: 6.4169e-06 - val_mae: 0.0025
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9646e-05 - mae: 0.0049 - val_loss: 8.7885e-08 - val_mae: 2.5656e-04
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9148e-05 - mae: 0.0050 - val_loss: 6.4151e-06 - val_mae: 0.0025
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4145e-05 - mae: 0.0046 - val_loss: 3.3420e-07 - val_mae: 5.5911e-04
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3661e-05 - mae: 0.0053 - val_loss: 8.2610e-07 - val_mae: 8.9704e-04
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8233e-05 - mae: 0.0041 - val_loss: 1.1329e-05 - val_mae: 0.0034
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.3257e-05 - mae: 0.0045 - val_loss: 3.3334e-06 - val_mae: 0.0018
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.3077e-05 - mae: 0.0045 - val_loss: 4.5464e-06 - val_mae: 0.0021
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0783e-05 - mae: 0.0044 - val_loss: 2.5748e-06 - val_mae: 0.0016
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4266e-05 - mae: 0.0045 - val_loss: 6.6598e-06 - val_mae: 0.0026
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9473e-05 - mae: 0.0042 - val_loss: 5.7440e-07 - val_mae: 7.5452e-04
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7687e-05 - mae: 0.0040 - val_loss: 1.8939e-05 - val_mae: 0.0043
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0129e-05 - mae: 0.0043 - val_loss: 3.0984e-08 - val_mae: 1.4761e-04
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4108e-05 - mae: 0.0038 - val_loss: 3.1221e-06 - val_mae: 0.0018
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8019e-05 - mae: 0.0041 - val_loss: 5.8423e-07 - val_mae: 7.5512e-04
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8574e-05 - mae: 0.0041 - val_loss: 1.3427e-06 - val_mae: 0.0011
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3981e-05 - mae: 0.0038 - val_loss: 4.3869e-07 - val_mae: 6.5130e-04
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1896e-05 - mae: 0.0036 - val_loss: 1.5403e-08 - val_mae: 1.0771e-04
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2860e-05 - mae: 0.0037 - val_loss: 3.4779e-08 - val_mae: 1.6012e-04
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1771e-05 - mae: 0.0037 - val_loss: 1.0187e-06 - val_mae: 9.9756e-04
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.5916e-05 - mae: 0.0040 - val_loss: 3.2697e-06 - val_mae: 0.0018
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1026e-05 - mae: 0.0036 - val_loss: 6.3028e-06 - val_mae: 0.0025
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2943e-05 - mae: 0.0037 - val_loss: 5.2466e-06 - val_mae: 0.0023
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0000e-05 - mae: 0.0035 - val_loss: 3.6072e-07 - val_mae: 5.9187e-04
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7234e-05 - mae: 0.0033 - val_loss: 4.7436e-07 - val_mae: 6.6877e-04
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8148e-05 - mae: 0.0033 - val_loss: 1.2872e-06 - val_mae: 0.0011
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8035e-05 - mae: 0.0033 - val_loss: 6.8343e-08 - val_mae: 2.1482e-04
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5301e-05 - mae: 0.0030 - val_loss: 2.7593e-06 - val_mae: 0.0017
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5444e-05 - mae: 0.0031 - val_loss: 3.9485e-08 - val_mae: 1.6118e-04
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5951e-05 - mae: 0.0030 - val_loss: 1.0703e-06 - val_mae: 0.0010
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3551e-05 - mae: 0.0029 - val_loss: 1.7516e-06 - val_mae: 0.0013
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4026e-05 - mae: 0.0029 - val_loss: 1.8698e-08 - val_mae: 1.1871e-04
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2523e-05 - mae: 0.0028 - val_loss: 3.8389e-06 - val_mae: 0.0019
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5553e-05 - mae: 0.0031 - val_loss: 2.2213e-06 - val_mae: 0.0015
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3078e-05 - mae: 0.0027 - val_loss: 4.5452e-06 - val_mae: 0.0021
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4142e-05 - mae: 0.0029 - val_loss: 1.7322e-07 - val_mae: 3.8820e-04
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1881e-05 - mae: 0.0027 - val_loss: 9.7838e-07 - val_mae: 9.8026e-04
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1614e-05 - mae: 0.0026 - val_loss: 3.2850e-06 - val_mae: 0.0018
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2441e-05 - mae: 0.0027 - val_loss: 6.7136e-06 - val_mae: 0.0026
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1611e-05 - mae: 0.0026 - val_loss: 7.9110e-07 - val_mae: 8.7241e-04
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.9019e-06 - mae: 0.0022 - val_loss: 1.4130e-06 - val_mae: 0.0012
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.3262e-06 - mae: 0.0022 - val_loss: 6.4264e-07 - val_mae: 7.8617e-04
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.2386e-06 - mae: 0.0024 - val_loss: 1.0585e-07 - val_mae: 2.6541e-04
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.5890e-06 - mae: 0.0024 - val_loss: 1.9596e-06 - val_mae: 0.0014
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.1206e-06 - mae: 0.0021 - val_loss: 7.8256e-06 - val_mae: 0.0028
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.8396e-06 - mae: 0.0023 - val_loss: 7.0817e-07 - val_mae: 8.2189e-04
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.5592e-06 - mae: 0.0022 - val_loss: 1.0395e-06 - val_mae: 0.0010
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.9832e-06 - mae: 0.0020 - val_loss: 2.9227e-07 - val_mae: 5.2974e-04
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.1869e-06 - mae: 0.0019 - val_loss: 6.2092e-07 - val_mae: 7.6865e-04
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.7570e-06 - mae: 0.0019 - val_loss: 8.5710e-06 - val_mae: 0.0029
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.3012e-06 - mae: 0.0020 - val_loss: 2.3057e-07 - val_mae: 4.4907e-04
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6353e-06 - mae: 0.0019 - val_loss: 1.9728e-06 - val_mae: 0.0014
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.3347e-06 - mae: 0.0017 - val_loss: 3.6942e-07 - val_mae: 5.9025e-04
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.6762e-06 - mae: 0.0017 - val_loss: 1.3974e-06 - val_mae: 0.0012
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8207e-06 - mae: 0.0016 - val_loss: 4.4304e-07 - val_mae: 6.4348e-04
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7666e-06 - mae: 0.0016 - val_loss: 2.9073e-06 - val_mae: 0.0017
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.2885e-06 - mae: 0.0017 - val_loss: 4.2830e-08 - val_mae: 1.8595e-04
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.3432e-06 - mae: 0.0017 - val_loss: 2.1357e-06 - val_mae: 0.0015
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.2065e-06 - mae: 0.0017 - val_loss: 4.4765e-06 - val_mae: 0.0021
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9405e-06 - mae: 0.0018 - val_loss: 3.8704e-08 - val_mae: 1.6515e-04
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0072e-06 - mae: 0.0014 - val_loss: 2.8016e-08 - val_mae: 1.3773e-04
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.8575e-06 - mae: 0.0016 - val_loss: 9.7610e-07 - val_mae: 9.7740e-04
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8064e-06 - mae: 0.0014 - val_loss: 1.4856e-08 - val_mae: 1.0613e-04
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1571e-06 - mae: 0.0013 - val_loss: 4.9902e-07 - val_mae: 6.8840e-04
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6485e-06 - mae: 0.0014 - val_loss: 2.4705e-07 - val_mae: 4.7185e-04
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4951e-06 - mae: 0.0014 - val_loss: 1.4758e-07 - val_mae: 3.3973e-04
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2956e-06 - mae: 0.0013 - val_loss: 1.7333e-07 - val_mae: 3.9244e-04
#   训练GRU模型...
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0073 - mae: 0.0630 - val_loss: 4.7073e-05 - val_mae: 0.0066
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8548e-04 - mae: 0.0157 - val_loss: 9.3524e-05 - val_mae: 0.0095
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0256e-04 - mae: 0.0136 - val_loss: 7.6386e-05 - val_mae: 0.0087
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4667e-04 - mae: 0.0123 - val_loss: 3.4862e-05 - val_mae: 0.0059
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6720e-04 - mae: 0.0104 - val_loss: 1.3059e-07 - val_mae: 3.1442e-04
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5025e-04 - mae: 0.0097 - val_loss: 1.3658e-06 - val_mae: 0.0012
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3658e-04 - mae: 0.0091 - val_loss: 1.5698e-05 - val_mae: 0.0040
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5125e-04 - mae: 0.0098 - val_loss: 3.4514e-06 - val_mae: 0.0019
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2251e-04 - mae: 0.0089 - val_loss: 7.5651e-08 - val_mae: 2.3303e-04
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1206e-04 - mae: 0.0084 - val_loss: 1.0473e-07 - val_mae: 2.9756e-04
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2127e-04 - mae: 0.0087 - val_loss: 2.6461e-05 - val_mae: 0.0051
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1553e-04 - mae: 0.0086 - val_loss: 2.1034e-07 - val_mae: 4.4807e-04
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1085e-04 - mae: 0.0084 - val_loss: 2.3730e-06 - val_mae: 0.0015
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0012e-04 - mae: 0.0078 - val_loss: 8.6323e-06 - val_mae: 0.0029
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0358e-04 - mae: 0.0080 - val_loss: 9.1716e-06 - val_mae: 0.0030
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8927e-05 - mae: 0.0079 - val_loss: 8.2477e-06 - val_mae: 0.0029
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0929e-05 - mae: 0.0075 - val_loss: 1.9477e-06 - val_mae: 0.0014
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8595e-05 - mae: 0.0075 - val_loss: 5.8658e-06 - val_mae: 0.0024
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5811e-05 - mae: 0.0068 - val_loss: 7.3944e-06 - val_mae: 0.0027
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0202e-04 - mae: 0.0081 - val_loss: 4.1775e-05 - val_mae: 0.0065
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3536e-05 - mae: 0.0077 - val_loss: 2.2437e-06 - val_mae: 0.0015
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7908e-05 - mae: 0.0070 - val_loss: 2.3190e-05 - val_mae: 0.0048
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6326e-05 - mae: 0.0068 - val_loss: 5.5074e-06 - val_mae: 0.0023
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4507e-05 - mae: 0.0068 - val_loss: 3.8854e-06 - val_mae: 0.0020
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7315e-05 - mae: 0.0069 - val_loss: 8.3890e-06 - val_mae: 0.0029
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4979e-05 - mae: 0.0063 - val_loss: 4.5170e-07 - val_mae: 6.6800e-04
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6598e-05 - mae: 0.0064 - val_loss: 8.5370e-06 - val_mae: 0.0029
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5192e-05 - mae: 0.0064 - val_loss: 9.7011e-08 - val_mae: 2.9259e-04
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6259e-05 - mae: 0.0058 - val_loss: 2.3987e-06 - val_mae: 0.0015
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1970e-05 - mae: 0.0061 - val_loss: 8.3593e-06 - val_mae: 0.0029
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8817e-05 - mae: 0.0059 - val_loss: 1.8204e-06 - val_mae: 0.0013
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6939e-05 - mae: 0.0058 - val_loss: 5.2500e-06 - val_mae: 0.0023
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4085e-05 - mae: 0.0057 - val_loss: 1.0926e-06 - val_mae: 0.0010
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7370e-05 - mae: 0.0054 - val_loss: 4.2157e-06 - val_mae: 0.0021
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9506e-05 - mae: 0.0056 - val_loss: 1.4306e-05 - val_mae: 0.0038
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8636e-05 - mae: 0.0055 - val_loss: 1.7382e-06 - val_mae: 0.0013
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3101e-05 - mae: 0.0050 - val_loss: 7.9064e-07 - val_mae: 8.8721e-04
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0443e-05 - mae: 0.0049 - val_loss: 4.3128e-06 - val_mae: 0.0021
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0054e-05 - mae: 0.0048 - val_loss: 2.9382e-06 - val_mae: 0.0017
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6215e-05 - mae: 0.0047 - val_loss: 2.9970e-06 - val_mae: 0.0017
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5890e-05 - mae: 0.0046 - val_loss: 8.7156e-07 - val_mae: 9.2982e-04
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1778e-05 - mae: 0.0044 - val_loss: 3.1502e-06 - val_mae: 0.0018
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0754e-05 - mae: 0.0043 - val_loss: 2.5724e-08 - val_mae: 1.5558e-04
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7624e-05 - mae: 0.0040 - val_loss: 1.5881e-05 - val_mae: 0.0040
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2782e-05 - mae: 0.0044 - val_loss: 1.0486e-05 - val_mae: 0.0032
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5303e-05 - mae: 0.0038 - val_loss: 5.2568e-07 - val_mae: 7.2369e-04
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7765e-05 - mae: 0.0041 - val_loss: 1.0029e-06 - val_mae: 0.0010
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4134e-05 - mae: 0.0037 - val_loss: 1.3013e-06 - val_mae: 0.0011
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4013e-05 - mae: 0.0038 - val_loss: 6.6942e-07 - val_mae: 8.1718e-04
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3754e-05 - mae: 0.0037 - val_loss: 3.7917e-06 - val_mae: 0.0019
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9735e-05 - mae: 0.0034 - val_loss: 3.9005e-06 - val_mae: 0.0020
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9658e-05 - mae: 0.0034 - val_loss: 1.4432e-05 - val_mae: 0.0038
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0259e-05 - mae: 0.0033 - val_loss: 3.0881e-07 - val_mae: 5.5382e-04
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7287e-05 - mae: 0.0032 - val_loss: 3.2571e-07 - val_mae: 5.6867e-04
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4057e-05 - mae: 0.0028 - val_loss: 7.4306e-07 - val_mae: 8.6133e-04
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4056e-05 - mae: 0.0028 - val_loss: 2.1392e-06 - val_mae: 0.0015
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3300e-05 - mae: 0.0028 - val_loss: 8.2721e-09 - val_mae: 8.0252e-05
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2177e-05 - mae: 0.0026 - val_loss: 4.3181e-06 - val_mae: 0.0021
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3413e-05 - mae: 0.0026 - val_loss: 4.1280e-07 - val_mae: 6.4104e-04
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0748e-05 - mae: 0.0025 - val_loss: 3.6025e-07 - val_mae: 6.0019e-04
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0566e-05 - mae: 0.0023 - val_loss: 1.1651e-07 - val_mae: 3.3991e-04
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2213e-05 - mae: 0.0025 - val_loss: 5.0239e-06 - val_mae: 0.0022
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1187e-05 - mae: 0.0024 - val_loss: 9.8926e-07 - val_mae: 9.9329e-04
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0242e-06 - mae: 0.0021 - val_loss: 6.0595e-06 - val_mae: 0.0025
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2846e-05 - mae: 0.0028 - val_loss: 2.2371e-08 - val_mae: 1.4459e-04
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8667e-06 - mae: 0.0020 - val_loss: 1.1548e-07 - val_mae: 3.3326e-04
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9496e-06 - mae: 0.0019 - val_loss: 1.2166e-07 - val_mae: 3.4711e-04
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1788e-06 - mae: 0.0018 - val_loss: 3.2337e-07 - val_mae: 5.6491e-04
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5219e-06 - mae: 0.0017 - val_loss: 5.4974e-06 - val_mae: 0.0023
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.6492e-06 - mae: 0.0022 - val_loss: 7.8299e-07 - val_mae: 8.8399e-04
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0893e-06 - mae: 0.0018 - val_loss: 1.7028e-07 - val_mae: 4.0963e-04
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4785e-06 - mae: 0.0019 - val_loss: 2.3059e-06 - val_mae: 0.0015
# Epoch 73/100
# ...
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3349e-05 - mae: 0.0034 - val_loss: 1.1772e-05 - val_mae: 0.0023
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4688e-05 - mae: 0.0032 - val_loss: 8.4468e-06 - val_mae: 0.0019
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2977e-05 - mae: 0.0026 - val_loss: 4.2555e-06 - val_mae: 0.0015
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3084e-05 - mae: 0.0018 - val_loss: 2.6243e-06 - val_mae: 0.0013
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4380e-06 - mae: 0.0013 - val_loss: 2.4882e-06 - val_mae: 0.0013
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2052e-06 - mae: 0.0011 - val_loss: 1.5121e-06 - val_mae: 8.1073e-04
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5199e-06 - mae: 0.0012 - val_loss: 3.4554e-06 - val_mae: 0.0016
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4564e-06 - mae: 0.0018 - val_loss: 2.1782e-06 - val_mae: 0.0012
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6833e-06 - mae: 0.0012 - val_loss: 1.7029e-06 - val_mae: 9.6700e-04
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6288e-06 - mae: 0.0014 - val_loss: 1.7124e-06 - val_mae: 9.5019e-04
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7007e-06 - mae: 0.0012 - val_loss: 1.5386e-06 - val_mae: 8.6507e-04
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7807e-06 - mae: 0.0013 - val_loss: 1.6811e-06 - val_mae: 9.7596e-04
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5076e-06 - mae: 0.0012 - val_loss: 1.4860e-06 - val_mae: 8.7389e-04
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9559e-06 - mae: 0.0012 - val_loss: 2.0760e-06 - val_mae: 0.0012
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7348e-06 - mae: 0.0012 - val_loss: 2.0012e-06 - val_mae: 0.0011
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9752e-06 - mae: 0.0013 - val_loss: 1.3872e-06 - val_mae: 8.2363e-04
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3840e-06 - mae: 0.0013 - val_loss: 3.1209e-06 - val_mae: 0.0015
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3679e-06 - mae: 0.0015 - val_loss: 1.4565e-06 - val_mae: 8.6830e-04
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3024e-06 - mae: 0.0013 - val_loss: 1.7303e-06 - val_mae: 0.0010
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7472e-06 - mae: 0.0012 - val_loss: 1.9722e-06 - val_mae: 0.0011
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4807e-06 - mae: 0.0015 - val_loss: 4.2948e-06 - val_mae: 0.0018
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3851e-06 - mae: 0.0014 - val_loss: 1.1648e-06 - val_mae: 7.0623e-04
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3065e-06 - mae: 0.0012 - val_loss: 1.1892e-06 - val_mae: 7.1297e-04
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7315e-06 - mae: 0.0014 - val_loss: 1.6056e-06 - val_mae: 9.9098e-04
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7845e-06 - mae: 9.8945e-04 - val_loss: 1.2714e-06 - val_mae: 8.2421e-04
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5208e-06 - mae: 0.0013 - val_loss: 2.3830e-06 - val_mae: 0.0013
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6974e-06 - mae: 0.0012 - val_loss: 1.4474e-06 - val_mae: 9.3323e-04
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2771e-06 - mae: 0.0012 - val_loss: 1.1386e-06 - val_mae: 7.1301e-04
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4278e-06 - mae: 9.6499e-04 - val_loss: 9.7045e-07 - val_mae: 6.3437e-04
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8349e-06 - mae: 0.0011 - val_loss: 1.5056e-06 - val_mae: 9.7810e-04
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4088e-06 - mae: 0.0012 - val_loss: 1.1235e-06 - val_mae: 7.7815e-04
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9524e-06 - mae: 0.0010 - val_loss: 1.4597e-06 - val_mae: 9.7213e-04
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5182e-06 - mae: 0.0011 - val_loss: 9.9218e-07 - val_mae: 7.1983e-04
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6877e-06 - mae: 0.0012 - val_loss: 1.1700e-06 - val_mae: 8.3398e-04
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6292e-06 - mae: 0.0010 - val_loss: 3.0060e-06 - val_mae: 0.0016
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7816e-06 - mae: 0.0012 - val_loss: 8.3388e-07 - val_mae: 6.0047e-04
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6989e-06 - mae: 9.8461e-04 - val_loss: 1.6458e-06 - val_mae: 0.0011
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2924e-06 - mae: 0.0011 - val_loss: 1.0441e-06 - val_mae: 7.8855e-04
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9572e-06 - mae: 0.0011 - val_loss: 2.3006e-06 - val_mae: 0.0013
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2771e-06 - mae: 0.0012 - val_loss: 9.3821e-07 - val_mae: 7.2657e-04
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4769e-06 - mae: 9.3661e-04 - val_loss: 1.2650e-06 - val_mae: 9.1860e-04
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0672e-06 - mae: 0.0011 - val_loss: 7.2182e-07 - val_mae: 5.5857e-04
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1761e-06 - mae: 8.8552e-04 - val_loss: 9.3463e-07 - val_mae: 7.2746e-04
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5009e-06 - mae: 9.7578e-04 - val_loss: 1.0081e-06 - val_mae: 7.8374e-04
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8260e-06 - mae: 0.0012 - val_loss: 1.0869e-06 - val_mae: 8.3173e-04
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0342e-06 - mae: 9.6684e-04 - val_loss: 9.4875e-07 - val_mae: 7.4392e-04
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1196e-06 - mae: 0.0010 - val_loss: 8.9807e-07 - val_mae: 7.0567e-04
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5618e-06 - mae: 0.0010 - val_loss: 7.5825e-07 - val_mae: 6.0618e-04
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1827e-06 - mae: 9.3235e-04 - val_loss: 6.7393e-07 - val_mae: 5.6691e-04
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7891e-06 - mae: 8.3321e-04 - val_loss: 9.6439e-07 - val_mae: 7.6474e-04
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4864e-06 - mae: 0.0010 - val_loss: 1.2212e-06 - val_mae: 9.1099e-04
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8301e-06 - mae: 9.0136e-04 - val_loss: 8.4308e-07 - val_mae: 7.0703e-04
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4707e-06 - mae: 9.4744e-04 - val_loss: 9.1486e-07 - val_mae: 7.4258e-04
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7959e-06 - mae: 0.0011 - val_loss: 7.2805e-07 - val_mae: 5.7277e-04
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7655e-06 - mae: 8.8751e-04 - val_loss: 7.7195e-07 - val_mae: 6.6413e-04
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6114e-06 - mae: 9.8969e-04 - val_loss: 7.5882e-07 - val_mae: 6.2770e-04
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9619e-06 - mae: 9.2588e-04 - val_loss: 6.0891e-07 - val_mae: 4.9924e-04
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3632e-06 - mae: 9.1190e-04 - val_loss: 7.3601e-07 - val_mae: 6.4144e-04
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0934e-06 - mae: 8.9598e-04 - val_loss: 5.8635e-07 - val_mae: 4.9620e-04
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4878e-06 - mae: 7.6735e-04 - val_loss: 8.8109e-07 - val_mae: 7.4654e-04
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9215e-06 - mae: 9.8742e-04 - val_loss: 5.8167e-07 - val_mae: 4.9176e-04
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9928e-06 - mae: 0.0010 - val_loss: 7.6941e-07 - val_mae: 6.6710e-04
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8928e-06 - mae: 8.6562e-04 - val_loss: 1.0571e-06 - val_mae: 8.4393e-04
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2936e-06 - mae: 0.0011 - val_loss: 8.9270e-07 - val_mae: 7.4791e-04
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5750e-06 - mae: 0.0010 - val_loss: 7.5323e-07 - val_mae: 6.0883e-04
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2538e-06 - mae: 9.2603e-04 - val_loss: 6.6261e-07 - val_mae: 5.5587e-04
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5117e-06 - mae: 9.9590e-04 - val_loss: 1.0721e-06 - val_mae: 8.4224e-04
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1568e-06 - mae: 0.0011 - val_loss: 5.6491e-07 - val_mae: 4.8845e-04
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8677e-06 - mae: 8.7279e-04 - val_loss: 6.7608e-07 - val_mae: 6.0574e-04
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8940e-06 - mae: 0.0010 - val_loss: 7.0775e-07 - val_mae: 6.0658e-04
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7932e-06 - mae: 0.0011 - val_loss: 1.0166e-06 - val_mae: 8.1933e-04
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2783e-06 - mae: 9.6563e-04 - val_loss: 9.2963e-07 - val_mae: 7.8129e-04
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3346e-06 - mae: 9.4087e-04 - val_loss: 6.3909e-07 - val_mae: 5.1785e-04
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1126e-06 - mae: 0.0013 - val_loss: 6.1189e-07 - val_mae: 5.0671e-04
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2469e-06 - mae: 8.9483e-04 - val_loss: 6.2958e-07 - val_mae: 5.5673e-04
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1697e-06 - mae: 8.9926e-04 - val_loss: 5.9275e-07 - val_mae: 5.0296e-04
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4143e-06 - mae: 9.5066e-04 - val_loss: 5.6357e-07 - val_mae: 4.8343e-04
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9941e-06 - mae: 8.9737e-04 - val_loss: 1.2281e-06 - val_mae: 9.3811e-04
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3712e-06 - mae: 9.2930e-04 - val_loss: 2.7583e-06 - val_mae: 0.0015
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6816e-06 - mae: 0.0015 - val_loss: 2.2183e-06 - val_mae: 0.0013
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0177e-06 - mae: 0.0011 - val_loss: 7.2225e-07 - val_mae: 6.3894e-04
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4573e-06 - mae: 9.6225e-04 - val_loss: 6.0544e-07 - val_mae: 5.0506e-04
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6569e-06 - mae: 7.7726e-04 - val_loss: 1.0806e-06 - val_mae: 8.2262e-04
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4700e-06 - mae: 9.9178e-04 - val_loss: 7.1743e-07 - val_mae: 6.4132e-04
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5768e-06 - mae: 8.2825e-04 - val_loss: 7.1369e-07 - val_mae: 6.3545e-04
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0937e-06 - mae: 8.4918e-04 - val_loss: 6.2588e-07 - val_mae: 5.4422e-04
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5713e-06 - mae: 9.9540e-04 - val_loss: 7.2822e-07 - val_mae: 6.6111e-04
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5647e-06 - mae: 7.8128e-04 - val_loss: 5.5378e-07 - val_mae: 5.1244e-04
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6063e-06 - mae: 9.8562e-04 - val_loss: 6.9834e-07 - val_mae: 6.2569e-04
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6025e-06 - mae: 9.5977e-04 - val_loss: 6.2837e-07 - val_mae: 5.0673e-04
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0437e-06 - mae: 8.3575e-04 - val_loss: 1.1593e-06 - val_mae: 9.1140e-04
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8771e-06 - mae: 9.0654e-04 - val_loss: 5.3366e-07 - val_mae: 4.9186e-04
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4953e-06 - mae: 8.9838e-04 - val_loss: 1.2337e-06 - val_mae: 9.4816e-04
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1832e-06 - mae: 0.0012 - val_loss: 7.0471e-07 - val_mae: 6.3334e-04
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5834e-06 - mae: 8.5483e-04 - val_loss: 5.5988e-07 - val_mae: 5.1323e-04
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7724e-06 - mae: 8.0043e-04 - val_loss: 5.5452e-07 - val_mae: 5.1411e-04
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9292e-06 - mae: 9.1183e-04 - val_loss: 2.0626e-06 - val_mae: 0.0013
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0071e-06 - mae: 9.5465e-04 - val_loss: 7.2689e-07 - val_mae: 6.5672e-04
#   分量 5 最佳模型: BiLSTM
#   验证集RMSE: 0.000840
#
# 所有分量模型训练和选择完成
#
# 各分量模型选择结果:
# 分量 1: 最佳模型=GRU, 验证集RMSE=0.004176, 验证集R²=0.9987
# 分量 2: 最佳模型=GRU, 验证集RMSE=0.000066, 验证集R²=0.9997
# 分量 3: 最佳模型=GRU, 验证集RMSE=0.000642, 验证集R²=0.9768
# 分量 4: 最佳模型=BiLSTM, 验证集RMSE=0.000825, 验证集R²=0.9874
# 分量 5: 最佳模型=BiLSTM, 验证集RMSE=0.000840, 验证集R²=0.9582
#
# 开始预测...
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000028A705E3BA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000028A756D4540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# 各分量预测效果评估:
#
# 分量 1 预测效果 (最佳模型: GRU):
#   RMSE: 0.006233
#   MAE: 0.005331
#   R²: 0.9643
#   对比 - BiLSTM RMSE: 0.137731, GRU RMSE: 0.121999
#
# 分量 2 预测效果 (最佳模型: GRU):
#   RMSE: 0.000141
#   MAE: 0.000141
#   R²: 0.8407
#   对比 - BiLSTM RMSE: 0.152384, GRU RMSE: 0.165690
#
# 分量 3 预测效果 (最佳模型: GRU):
#   RMSE: 0.000534
#   MAE: 0.000467
#   R²: 0.9716
#   对比 - BiLSTM RMSE: 0.003158, GRU RMSE: 0.003360
#
# 分量 4 预测效果 (最佳模型: BiLSTM):
#   RMSE: 0.000636
#   MAE: 0.000512
#   R²: 0.9683
#   对比 - BiLSTM RMSE: 0.003590, GRU RMSE: 0.003569
#
# 分量 5 预测效果 (最佳模型: BiLSTM):
#   RMSE: 0.000689
#   MAE: 0.000531
#   R²: 0.9638
#   对比 - BiLSTM RMSE: 0.003542, GRU RMSE: 0.003612
#
# 最终模型评估:
# MSE: 0.0000
# MAE: 0.0000
# RMSE: 0.0000
# MAPE: 1.2900
# R2: 0.9689
# ============================================================
# 冬季预测结果详细分析
# ============================================================
# ==================================================
# 冬季预测误差统计分析
# ==================================================
# 平均绝对误差: 0.0000
# 最大绝对误差: 0.0000
# 最小绝对误差: 0.0000
# 平均相对误差: 1.29%
# 最大相对误差: 3.69%
# 最小相对误差: 0.18%
#
# ==================================================
# 冬季各月份详细分析
# ==================================================
# 冬季各月份预测性能比较:
#
# 十二月:
#   RMSE: 0.0000
#   MAE: 0.0000
#   MAPE: 1.29%
#   R²: 0.9689
#
# 📊 冬季预测性能总结:
#   最佳预测月份: 十二月 (RMSE: 0.0000)
#   最具挑战月份: 十二月 (RMSE: 0.0000)

# %%
# --------------------------- 新增：置信区间计算函数 ---------------------------
def calculate_prediction_intervals(y_true, y_pred, n_bootstraps=1000):
    """使用自助法计算预测置信区间"""
    residuals = y_true - y_pred
    n_samples = len(y_true)
    
    # 存储自助法采样结果
    bootstrap_predictions = []
    
    for _ in range(n_bootstraps):
        # 对残差进行有放回抽样
        bootstrap_residuals = np.random.choice(residuals, size=n_samples, replace=True)
        # 生成自助法预测值
        bootstrap_pred = y_pred + bootstrap_residuals
        bootstrap_predictions.append(bootstrap_pred)
    
    bootstrap_predictions = np.array(bootstrap_predictions)
    
    # 计算95%置信区间分位数
    lower_95 = np.percentile(bootstrap_predictions, 2.5, axis=0)
    upper_95 = np.percentile(bootstrap_predictions, 97.5, axis=0)
    
    return {
        'lower_95': lower_95,
        'upper_95': upper_95,
        'bootstrap_predictions': bootstrap_predictions
    }

# --------------------------- 图1：冬季预测结果及置信区间 ---------------------------
def plot_winter_prediction_with_intervals(dates, y_true, y_pred, winter_start='2024-12-01', winter_end='2025-02-28'):
    """可视化冬季预测结果及置信区间"""
    
    # 创建冬季掩码
    winter_mask = (dates >= pd.Timestamp(winter_start)) & (dates <= pd.Timestamp(winter_end))
    
    # 提取冬季数据
    winter_dates = dates[winter_mask]
    winter_true = y_true[winter_mask]
    winter_pred = y_pred[winter_mask]
    
    if len(winter_dates) == 0:
        print("警告：没有找到冬季数据，请检查日期范围")
        return
    
    # 计算冬季置信区间
    winter_intervals = calculate_prediction_intervals(winter_true, winter_pred)
    
    # 创建图表
    plt.figure(figsize=(16, 8))
    
    # 绘制95%置信区间
    plt.fill_between(winter_dates, winter_intervals['lower_95'], winter_intervals['upper_95'], 
                     alpha=0.3, color='red', label='95% Confidence interval')
    
    # 绘制真实值和预测值
    plt.plot(winter_dates, winter_true, label='True value', linewidth=3, color='#2E86AB', marker='o', markersize=6)
    plt.plot(winter_dates, winter_pred, label='Predicted value', linewidth=2, color='#A23B72', linestyle='--', marker='s', markersize=4)
    
    plt.title('Winter', fontsize=24, fontweight='bold', pad=20)
    plt.xlabel('Data', fontsize=12)
    plt.ylabel('Carbon emissions', fontsize=12)
    plt.legend(fontsize=11, loc='upper right')
    plt.grid(True, alpha=0.3)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 添加评估指标
    winter_metrics = evaluate(winter_true, winter_pred)
    metrics_text = (f"冬季评估指标:\n"
                   f"RMSE: {winter_metrics['RMSE']:.4f}\n"
                   f"MAE: {winter_metrics['MAE']:.4f}\n"
                   f"MAPE: {winter_metrics['MAPE']:.2f}%\n"
                   f"R²: {winter_metrics['R2']:.4f}")  
    plt.tight_layout()
    plt.savefig('winter_prediction_with_confidence_intervals.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    return winter_intervals, winter_metrics

# --------------------------- 图2：置信区间宽度变化 ---------------------------
def plot_confidence_interval_width(dates, y_true, y_pred, winter_start='2024-12-01', winter_end='2025-02-28'):
    """可视化置信区间宽度变化"""
    
    # 创建冬季掩码
    winter_mask = (dates >= pd.Timestamp(winter_start)) & (dates <= pd.Timestamp(winter_end))
    
    # 提取冬季数据
    winter_dates = dates[winter_mask]
    winter_true = y_true[winter_mask]
    winter_pred = y_pred[winter_mask]
    
    if len(winter_dates) == 0:
        print("警告：没有找到冬季数据，请检查日期范围")
        return
    
    # 计算冬季置信区间
    winter_intervals = calculate_prediction_intervals(winter_true, winter_pred)
    
    # 创建图表
    plt.figure(figsize=(16, 8))
    
    # 计算置信区间宽度
    ci_width_95 = winter_intervals['upper_95'] - winter_intervals['lower_95']
    
    # 绘制置信区间宽度
    plt.plot(winter_dates, ci_width_95, label='95% CI 宽度', linewidth=2, color='blue', alpha=0.8)
    
    # 添加平均宽度线
    mean_width = np.mean(ci_width_95)
    plt.axhline(y=mean_width, color='red', linestyle='--', alpha=0.8, 
                label=f'平均宽度: {mean_width:.4f}')
    
    plt.title('冬季碳排放预测置信区间宽度变化', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('日期', fontsize=12)
    plt.ylabel('置信区间宽度', fontsize=12)
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.WeekdayLocator(interval=1))
    plt.xticks(rotation=45)
    
    # 计算置信区间覆盖率
    coverage_95 = np.mean((winter_true >= winter_intervals['lower_95']) & (winter_true <= winter_intervals['upper_95']))
    
    # 添加统计信息
    stats_text = (f"置信区间统计:\n"
                 f"95% CI 平均宽度: {mean_width:.4f}\n"
                 f"95% CI 覆盖率: {coverage_95:.1%}\n"
                 f"宽度标准差: {np.std(ci_width_95):.4f}")
    
    plt.text(0.02, 0.98, stats_text, transform=plt.gca().transAxes, 
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8),
             fontsize=10)
    
    plt.tight_layout()
    plt.savefig('confidence_interval_width_analysis.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    return winter_intervals

# --------------------------- 执行冬季置信区间分析 ---------------------------
print("\n" + "="*60)
print("冬季预测置信区间分析")
print("="*60)

# 图1：冬季预测结果及置信区间
print("\n📊 生成冬季预测结果图...")
winter_intervals, winter_metrics_final = plot_winter_prediction_with_intervals(test_dates, y_true_final, y_pred_final)

# 图2：置信区间宽度变化
print("\n📈 生成置信区间宽度分析图...")
winter_intervals_2 = plot_confidence_interval_width(test_dates, y_true_final, y_pred_final)

# --------------------------- 新增：冬季预测总结 ---------------------------
print("\n" + "="*60)
print("2024-2025年冬季碳排放预测总结")
print("="*60)

print(f"\n📊 整体预测性能:")
print(f"  RMSE: {winter_metrics_final['RMSE']:.4f}")
print(f"  MAE: {winter_metrics_final['MAE']:.4f}")
print(f"  MAPE: {winter_metrics_final['MAPE']:.2f}%")
print(f"  R²: {winter_metrics_final['R2']:.4f}")

print(f"\n📈 各月份性能对比:")
for month, metrics in monthly_metrics.items():
    print(f"  {month}: RMSE={metrics['RMSE']:.4f}, MAE={metrics['MAE']:.4f}, R²={metrics['R2']:.4f}")

print(f"\n🔍 关键发现:")
print(f"  • 最佳预测月份: {best_month[0]} (RMSE: {best_month[1]['RMSE']:.4f})")
print(f"  • 最具挑战月份: {worst_month[0]} (RMSE: {worst_month[1]['RMSE']:.4f})")

# 计算置信区间覆盖率
winter_mask = (test_dates >= pd.Timestamp('2024-12-01')) & (test_dates <= pd.Timestamp('2025-02-28'))
winter_dates = test_dates[winter_mask]
winter_true = y_true_final[winter_mask]
winter_pred = y_pred_final[winter_mask]

coverage_95 = np.mean((winter_true >= winter_intervals['lower_95']) & (winter_true <= winter_intervals['upper_95']))
ci_width_mean = np.mean(winter_intervals['upper_95'] - winter_intervals['lower_95'])

print(f"\n📊 不确定性评估:")
print(f"  95% 置信区间覆盖率: {coverage_95:.2%} (理想值: 95%)")
print(f"  平均预测不确定性 (95% CI宽度): {ci_width_mean:.4f}")
print(f"  预测不确定性标准差: {np.std(winter_intervals['upper_95'] - winter_intervals['lower_95']):.4f}")

print(f"\n💡 冬季预测特点分析:")
print("  • 冬季气温低，供暖需求增加，碳排放可能上升")
print("  • 工业生产可能受节假日影响，碳排放模式变化")
print("  • 春节假期可能对2月份的碳排放产生显著影响")
print("  • 模型在冬季表现出良好的预测能力")

print(f"\n✅ 预测模型在2024-2025年冬季表现出色，能够准确捕捉碳排放的季节性变化模式。")
# Out:
# ============================================================
# 冬季预测置信区间分析
# ============================================================
#
# 📊 生成冬季预测结果图...
# 📈 生成置信区间宽度分析图...
# ============================================================
# 2024-2025年冬季碳排放预测总结
# ============================================================
#
# 📊 整体预测性能:
#   RMSE: 0.0000
#   MAE: 0.0000
#   MAPE: 1.29%
#   R²: 0.9689
#
# 📈 各月份性能对比:
#   十二月: RMSE=0.0000, MAE=0.0000, R²=0.9689
#
# 🔍 关键发现:
#   • 最佳预测月份: 十二月 (RMSE: 0.0000)
#   • 最具挑战月份: 十二月 (RMSE: 0.0000)
#
# 📊 不确定性评估:
#   95% 置信区间覆盖率: 96.77% (理想值: 95%)
#   平均预测不确定性 (95% CI宽度): 0.0000
#   预测不确定性标准差: 0.0000
#
# 💡 冬季预测特点分析:
#   • 冬季气温低，供暖需求增加，碳排放可能上升
#   • 工业生产可能受节假日影响，碳排放模式变化
#   • 春节假期可能对2月份的碳排放产生显著影响
#   • 模型在冬季表现出良好的预测能力
#
# ✅ 预测模型在2024-2025年冬季表现出色，能够准确捕捉碳排放的季节性变化模式。
